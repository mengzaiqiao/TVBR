# %% [markdown]
# ### Install Beta-recsys

# %% [markdown]
# ## Loading dataset

# %%
import sys

sys.path.append("../")

import random

import numpy as np

from beta_rec.data.grocery_data import GroceryData
from beta_rec.datasets.instacart import Instacart_25

seed = 2021
random.seed(seed)  # Fix random seeds for reproducibility
np.random.seed(seed)

# make sure that you have already download the Instacart data from this link: https://www.kaggle.com/c/instacart-market-basket-analysis#
# uncompressed them and put them in this folder: ../datasets/instacart_25/raw/*.csv


dataset = Instacart_25(
    min_u_c=20, min_i_c=30, min_o_c=10
)  # Specifying the filtering conditions.

# Split the data
split_dataset = dataset.load_temporal_basket_split(test_rate=0.2, n_test=10)
data = GroceryData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 3857794    | 3857794    | 3857794      | 3857794         | 3857794     |
# | nunique | 23093      | 14565      | 1            | 3857794         | 373719      |
# +---------+------------+------------+--------------+-----------------+-------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table
# Execute [__init__] method costing 97185.35 ms
# Execute [__init__] method costing 0.00 ms

# %% [markdown]
# ### Model config

# %%
config = {"config_file": "../configs/tvbr_default.json"}
config["n_sample"] = 1000000  # To reduce the test running time
config["max_epoch"] = 80
config["emb_dim"] = 64
config["time_step"] = 50
config["batch_size"] = 10000
# config["tunable"] = [
#     {"name": "lr", "type": "choice", "values": [0.5, 0.05, 0.025, 0.001, 0.005]},
# ]
# config["tune"] = True
# the 'config_file' key is required, that is used load a default config.
# Other keys can be specified to replace the default settings.

# %% [markdown]
# ### Model intialization and training

# %%
from beta_rec.recommenders import TVBR

for item_fea_type in [
    "random",
    "cate",
    "cate_word2vec",
    "cate_bert",
    "cate_one_hot",
    "random_word2vec",
    "random_bert",
#     "random_one_hot",
#     "random_bert_word2vec_one_hot",
#     "random_cate_word2vec",
#     "random_cate_bert",
#     "random_cate_one_hot",
#     "random_cate_bert_word2vec_one_hot",
]:
    config["item_fea_type"] = item_fea_type
    lr = 0.001
    time_step = 20
    config["lr"] = lr
    config["time_step"] = time_step
    config["root_dir"] = "/home/zm324/workspace/beta-recsys/"
    config["dataset"] = "instacart_25"
    model = TVBR(config)
    model.train(data)
    model.test(data.test)
    # @To be discussed
# model.train(train_df)
# Case 1, without validation, stop training by loss or max_epoch

# model.train(train_df,valid_df[0])
# Case 2, with validation, stop training by performance on validation set

# model.train(train_df,valid_df[0],test_df[0])
# Case 3, same as Case 2, but also evaluate performance for each epoch on test set.

# Note that the best model will be save automatically, and record the model-save-dir.
# Out:
# Search default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# Found default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# loading config file /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +----+-----------------------+------------------------------------+
# |    | keys                  | values                             |
# |----+-----------------------+------------------------------------|
# |  0 | system:root_dir       | /home/zm324/workspace/beta-recsys/ |
# |  1 | model:n_sample        | 1000000                            |
# |  2 | model:max_epoch       | 80                                 |
# |  3 | model:emb_dim         | 64                                 |
# |  4 | model:time_step       | 20                                 |
# |  5 | model:batch_size      | 10000                              |
# |  6 | model:lr              | 0.001                              |
# |  7 | dataset:item_fea_type | random                             |
# |  8 | dataset:dataset       | instacart_25                       |
# +----+-----------------------+------------------------------------+
# --------------------------------------------------------------------------------
# logs will save in file: /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211210_202430_murihu .stdout.log .stderr.log
# 2021-12-10 20:24:30 [INFO]-
# Python version: 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0
# 2021-12-10 20:24:30 [INFO]-
# 2021-12-10 20:24:30 [INFO]-Pytorch version: 1.7.1
# 2021-12-10 20:24:30 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211210_202430_murihu
# 2021-12-10 20:24:30 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211210_202430_murihu
# 2021-12-10 20:24:30 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/tvbr_result.csv
# 2021-12-10 20:24:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:24:30 [INFO]-System configs
# 2021-12-10 20:24:30 [INFO]-
# +----+----------------+-----------------------------------------------------------------------------------+
# |    | keys           | values                                                                            |
# |----+----------------+-----------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                 |
# |  1 | log_dir        | logs/                                                                             |
# |  2 | result_dir     | results/                                                                          |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                      |
# |  4 | checkpoint_dir | checkpoints/                                                                      |
# |  5 | dataset_dir    | datasets/                                                                         |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211210_202430_murihu        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                   |
# |  8 | device         | gpu                                                                               |
# |  9 | seed           | 2020                                                                              |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                            |
# | 11 | k              | [5, 10, 20]                                                                       |
# | 12 | valid_metric   | ndcg                                                                              |
# | 13 | valid_k        | 10                                                                                |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/tvbr_result.csv                         |
# | 15 | save_mode      | average                                                                           |
# | 16 | model_run_id   | TVBR_default_20211210_202430_murihu                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211210_202430_murihu        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211210_202430_murihu |
# +----+----------------+-----------------------------------------------------------------------------------
# 2021-12-10 20:24:30 [INFO]-
# 2021-12-10 20:24:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:24:30 [ERROR]-Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# 2021-12-10 20:24:30 [ERROR]-wandb: Currently logged in as: mengzaiqiao (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/mengzaiqiao/TVBR/runs/18kls0no" target="_blank">fancy-dew-53</a></strong> to <a href="https://wandb.ai/mengzaiqiao/TVBR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 2021-12-10 20:24:31 [INFO]-Get a gpu with the most available memory : 2
# 2021-12-10 20:24:31 [INFO]-Initializing test engine ...
# 2021-12-10 20:24:31 [INFO]-Get a gpu with the most available memory : 2
# 2021-12-10 20:24:34 [INFO]-Setting device for torch_engine cuda:2
# 2021-12-10 20:24:34 [INFO]-
# TVBR(
#   (user_emb): Embedding(23093, 64)
#   (item_emb): Embedding(14565, 64)
#   (time_embdding): Embedding(21, 21)
#   (user_mean): Embedding(23093, 64)
#   (user_std): Embedding(23093, 64)
#   (item_mean): Embedding(14565, 64)
#   (item_std): Embedding(14565, 64)
#   (time2mean_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2mean_i): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_i): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#
# 2021-12-10 20:24:34 [INFO]-
# 2021-12-10 20:24:35 [INFO]-Initialize Sampler!
# 2021-12-10 20:24:35 [INFO]-preparing training triples ...
# 2021-12-10 20:24:36 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:36 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:36 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:37 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:37 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 100%|##########| 20/20 [01:43<00:00,  5.17s/it]
#   0%|          | 0/80 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-12-10 20:27:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:29:28 [INFO]-[Training Epoch 0], log_like_loss 0.43700700998306274 kl_loss: -0.0024199087638407946 alpha: 0.001 lr: 0.001
# 2021-12-10 20:29:28 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:29:28 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:29:28 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:29:28 [INFO]-Execute [train_an_epoch] method costing 130308.76 ms
#   1%|1         | 1/80 [02:10<2:51:34, 130.31s/it]Epoch 1 starts !
# 2021-12-10 20:29:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:31:42 [INFO]-[Training Epoch 1], log_like_loss 0.38425156474113464 kl_loss: -0.001088663237169385 alpha: 0.001 lr: 0.001
# 2021-12-10 20:31:42 [INFO]-Execute [train_an_epoch] method costing 134121.37 ms
#   2%|2         | 2/80 [04:24<2:50:54, 131.47s/it]Epoch 2 starts !
# 2021-12-10 20:31:42 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:33:55 [INFO]-[Training Epoch 2], log_like_loss 0.37814658880233765 kl_loss: -0.0009509126539342105 alpha: 0.001 lr: 0.001
# 2021-12-10 20:33:55 [INFO]-Execute [train_an_epoch] method costing 132973.67 ms
#   4%|3         | 3/80 [06:37<2:49:19, 131.94s/it]Epoch 3 starts !
# 2021-12-10 20:33:55 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:36:14 [INFO]-[Training Epoch 3], log_like_loss 0.375060498714447 kl_loss: -0.001008749008178711 alpha: 0.001 lr: 0.001
# 2021-12-10 20:36:14 [INFO]-Execute [train_an_epoch] method costing 138677.13 ms
#   5%|5         | 4/80 [08:56<2:49:42, 133.98s/it]Epoch 4 starts !
# 2021-12-10 20:36:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:38:44 [INFO]-[Training Epoch 4], log_like_loss 0.37241703271865845 kl_loss: -0.0012750874739140272 alpha: 0.001 lr: 0.001
# 2021-12-10 20:38:44 [INFO]-Execute [train_an_epoch] method costing 150380.32 ms
#   6%|6         | 5/80 [11:26<2:53:39, 138.92s/it]Epoch 5 starts !
# 2021-12-10 20:38:44 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:41:14 [INFO]-[Training Epoch 5], log_like_loss 0.369710773229599 kl_loss: -0.0020638727582991123 alpha: 0.001 lr: 0.001
# 2021-12-10 20:41:14 [INFO]-Execute [train_an_epoch] method costing 149666.48 ms
#   8%|7         | 6/80 [13:56<2:55:19, 142.16s/it]Epoch 6 starts !
# 2021-12-10 20:41:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:43:44 [INFO]-[Training Epoch 6], log_like_loss 0.367564857006073 kl_loss: -0.004053408745676279 alpha: 0.001 lr: 0.001
# 2021-12-10 20:43:44 [INFO]-Execute [train_an_epoch] method costing 149630.08 ms
#   9%|8         | 7/80 [16:26<2:55:42, 144.42s/it]Epoch 7 starts !
# 2021-12-10 20:43:44 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:46:11 [INFO]-[Training Epoch 7], log_like_loss 0.3653264343738556 kl_loss: -0.007759557105600834 alpha: 0.001 lr: 0.001
# 2021-12-10 20:46:11 [INFO]-Execute [train_an_epoch] method costing 147679.10 ms
#  10%|#         | 8/80 [18:53<2:54:30, 145.42s/it]Epoch 8 starts !
# 2021-12-10 20:46:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:48:41 [INFO]-[Training Epoch 8], log_like_loss 0.36331087350845337 kl_loss: -0.012860781513154507 alpha: 0.001 lr: 0.001
# 2021-12-10 20:48:41 [INFO]-Execute [train_an_epoch] method costing 150009.68 ms
#  11%|#1        | 9/80 [21:23<2:53:44, 146.82s/it]Epoch 9 starts !
# 2021-12-10 20:48:41 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:51:10 [INFO]-[Training Epoch 9], log_like_loss 0.3612547218799591 kl_loss: -0.018604431301355362 alpha: 0.001 lr: 0.001
# 2021-12-10 20:51:10 [INFO]-Execute [train_an_epoch] method costing 148961.41 ms
#  12%|#2        | 10/80 [23:52<2:52:03, 147.48s/it]Epoch 10 starts !
# 2021-12-10 20:51:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:53:39 [INFO]-[Training Epoch 10], log_like_loss 0.3597152531147003 kl_loss: -0.0241245087236166 alpha: 0.001 lr: 0.001
# 2021-12-10 20:53:39 [INFO]-Execute [train_an_epoch] method costing 148082.17 ms
#  14%|#3        | 11/80 [26:21<2:49:50, 147.68s/it]Epoch 11 starts !
# 2021-12-10 20:53:39 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:56:09 [INFO]-[Training Epoch 11], log_like_loss 0.3582583963871002 kl_loss: -0.029101843014359474 alpha: 0.001 lr: 0.001
# 2021-12-10 20:56:09 [INFO]-Execute [train_an_epoch] method costing 150353.08 ms
#  15%|#5        | 12/80 [28:51<2:48:18, 148.51s/it]Epoch 12 starts !
# 2021-12-10 20:56:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:58:38 [INFO]-[Training Epoch 12], log_like_loss 0.35640719532966614 kl_loss: -0.03371024876832962 alpha: 0.001 lr: 0.001
# 2021-12-10 20:58:38 [INFO]-Execute [train_an_epoch] method costing 148738.00 ms
#  16%|#6        | 13/80 [31:20<2:45:55, 148.59s/it]Epoch 13 starts !
# 2021-12-10 20:58:38 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:01:07 [INFO]-[Training Epoch 13], log_like_loss 0.3552309274673462 kl_loss: -0.03852732107043266 alpha: 0.001 lr: 0.001
# 2021-12-10 21:01:07 [INFO]-Execute [train_an_epoch] method costing 149635.24 ms
#  18%|#7        | 14/80 [33:50<2:43:48, 148.92s/it]Epoch 14 starts !
# 2021-12-10 21:01:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:03:36 [INFO]-[Training Epoch 14], log_like_loss 0.3537865877151489 kl_loss: -0.04363218694925308 alpha: 0.001 lr: 0.001
# 2021-12-10 21:03:36 [INFO]-Execute [train_an_epoch] method costing 148419.64 ms
#  19%|#8        | 15/80 [36:18<2:41:11, 148.79s/it]Epoch 15 starts !
# 2021-12-10 21:03:36 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:06:05 [INFO]-[Training Epoch 15], log_like_loss 0.35258620977401733 kl_loss: -0.04867515712976456 alpha: 0.001 lr: 0.001
# 2021-12-10 21:06:05 [INFO]-Execute [train_an_epoch] method costing 148963.94 ms
#  20%|##        | 16/80 [38:47<2:38:47, 148.86s/it]Epoch 16 starts !
# 2021-12-10 21:06:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:08:35 [INFO]-[Training Epoch 16], log_like_loss 0.35174673795700073 kl_loss: -0.05395834147930145 alpha: 0.001 lr: 0.001
# 2021-12-10 21:08:35 [INFO]-Execute [train_an_epoch] method costing 149649.57 ms
#  21%|##1       | 17/80 [41:17<2:36:34, 149.12s/it]Epoch 17 starts !
# 2021-12-10 21:08:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:11:05 [INFO]-[Training Epoch 17], log_like_loss 0.3508983850479126 kl_loss: -0.05968782678246498 alpha: 0.001 lr: 0.001
# 2021-12-10 21:11:05 [INFO]-Execute [train_an_epoch] method costing 149990.74 ms
#  22%|##2       | 18/80 [43:47<2:34:22, 149.40s/it]Epoch 18 starts !
# 2021-12-10 21:11:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:13:35 [INFO]-[Training Epoch 18], log_like_loss 0.3497604727745056 kl_loss: -0.0655198022723198 alpha: 0.001 lr: 0.001
# 2021-12-10 21:13:35 [INFO]-Execute [train_an_epoch] method costing 149821.49 ms
#  24%|##3       | 19/80 [46:17<2:32:02, 149.55s/it]Epoch 19 starts !
# 2021-12-10 21:13:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:16:04 [INFO]-[Training Epoch 19], log_like_loss 0.3489099144935608 kl_loss: -0.07045989483594894 alpha: 0.001 lr: 0.001
# 2021-12-10 21:16:04 [INFO]-Execute [train_an_epoch] method costing 149487.94 ms
#  25%|##5       | 20/80 [48:46<2:29:32, 149.55s/it]Epoch 20 starts !
# 2021-12-10 21:16:04 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:18:34 [INFO]-[Training Epoch 20], log_like_loss 0.34816136956214905 kl_loss: -0.07585112005472183 alpha: 0.001 lr: 0.001
# 2021-12-10 21:18:34 [INFO]-Execute [train_an_epoch] method costing 149596.00 ms
#  26%|##6       | 21/80 [51:16<2:27:05, 149.58s/it]Epoch 21 starts !
# 2021-12-10 21:18:34 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:21:04 [INFO]-[Training Epoch 21], log_like_loss 0.3475947082042694 kl_loss: -0.08087915927171707 alpha: 0.001 lr: 0.001
# 2021-12-10 21:21:04 [INFO]-Execute [train_an_epoch] method costing 150462.13 ms
#  28%|##7       | 22/80 [53:46<2:24:51, 149.86s/it]Epoch 22 starts !
# 2021-12-10 21:21:04 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:23:36 [INFO]-[Training Epoch 22], log_like_loss 0.3471924662590027 kl_loss: -0.08562495559453964 alpha: 0.001 lr: 0.001
# 2021-12-10 21:23:36 [INFO]-Execute [train_an_epoch] method costing 151970.78 ms
#  29%|##8       | 23/80 [56:18<2:22:59, 150.51s/it]Epoch 23 starts !
# 2021-12-10 21:23:36 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:26:05 [INFO]-[Training Epoch 23], log_like_loss 0.346434623003006 kl_loss: -0.09011229872703552 alpha: 0.001 lr: 0.001
# 2021-12-10 21:26:05 [INFO]-Execute [train_an_epoch] method costing 148885.80 ms
#  30%|###       | 24/80 [58:47<2:20:02, 150.05s/it]Epoch 24 starts !
# 2021-12-10 21:26:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:28:35 [INFO]-[Training Epoch 24], log_like_loss 0.3459664583206177 kl_loss: -0.09407941997051239 alpha: 0.001 lr: 0.001
# 2021-12-10 21:28:35 [INFO]-Execute [train_an_epoch] method costing 149109.46 ms
#  31%|###1      | 25/80 [1:01:17<2:17:18, 149.79s/it]Epoch 25 starts !
# 2021-12-10 21:28:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:31:05 [INFO]-[Training Epoch 25], log_like_loss 0.3454269766807556 kl_loss: -0.0981706753373146 alpha: 0.001 lr: 0.001
# 2021-12-10 21:31:05 [INFO]-Execute [train_an_epoch] method costing 150481.25 ms
#  32%|###2      | 26/80 [1:03:47<2:15:00, 150.02s/it]Epoch 26 starts !
# 2021-12-10 21:31:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:33:35 [INFO]-[Training Epoch 26], log_like_loss 0.3446214199066162 kl_loss: -0.10212325304746628 alpha: 0.001 lr: 0.001
# 2021-12-10 21:33:35 [INFO]-Execute [train_an_epoch] method costing 149582.38 ms
#  34%|###3      | 27/80 [1:06:17<2:12:24, 149.90s/it]Epoch 27 starts !
# 2021-12-10 21:33:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:36:05 [INFO]-[Training Epoch 27], log_like_loss 0.3444058895111084 kl_loss: -0.10533739626407623 alpha: 0.001 lr: 0.001
# 2021-12-10 21:36:05 [INFO]-Execute [train_an_epoch] method costing 149908.90 ms
#  35%|###5      | 28/80 [1:08:47<2:09:56, 149.92s/it]Epoch 28 starts !
# 2021-12-10 21:36:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:38:34 [INFO]-[Training Epoch 28], log_like_loss 0.343911737203598 kl_loss: -0.1089002937078476 alpha: 0.001 lr: 0.001
# 2021-12-10 21:38:34 [INFO]-Execute [train_an_epoch] method costing 149434.48 ms
#  36%|###6      | 29/80 [1:11:16<2:07:19, 149.80s/it]Epoch 29 starts !
# 2021-12-10 21:38:34 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:41:04 [INFO]-[Training Epoch 29], log_like_loss 0.34333452582359314 kl_loss: -0.11248991638422012 alpha: 0.001 lr: 0.001
# 2021-12-10 21:41:04 [INFO]-Execute [train_an_epoch] method costing 149804.23 ms
#  38%|###7      | 30/80 [1:13:46<2:04:51, 149.82s/it]Epoch 30 starts !
# 2021-12-10 21:41:04 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:43:33 [INFO]-[Training Epoch 30], log_like_loss 0.3430793881416321 kl_loss: -0.11563670635223389 alpha: 0.001 lr: 0.001
# 2021-12-10 21:43:33 [INFO]-Execute [train_an_epoch] method costing 149115.09 ms
#  39%|###8      | 31/80 [1:16:15<2:02:11, 149.63s/it]Epoch 31 starts !
# 2021-12-10 21:43:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:46:04 [INFO]-[Training Epoch 31], log_like_loss 0.34252578020095825 kl_loss: -0.11856164038181305 alpha: 0.001 lr: 0.001
# 2021-12-10 21:46:04 [INFO]-Execute [train_an_epoch] method costing 150704.01 ms
#  40%|####      | 32/80 [1:18:46<1:59:58, 149.97s/it]Epoch 32 starts !
# 2021-12-10 21:46:04 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:48:35 [INFO]-[Training Epoch 32], log_like_loss 0.34225761890411377 kl_loss: -0.12145776301622391 alpha: 0.001 lr: 0.001
# 2021-12-10 21:48:35 [INFO]-Execute [train_an_epoch] method costing 150695.89 ms
#  41%|####1     | 33/80 [1:21:17<1:57:39, 150.21s/it]Epoch 33 starts !
# 2021-12-10 21:48:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:51:04 [INFO]-[Training Epoch 33], log_like_loss 0.3419599235057831 kl_loss: -0.12396740168333054 alpha: 0.001 lr: 0.001
# 2021-12-10 21:51:04 [INFO]-Execute [train_an_epoch] method costing 148844.86 ms
#  42%|####2     | 34/80 [1:23:46<1:54:51, 149.82s/it]Epoch 34 starts !
# 2021-12-10 21:51:04 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:53:36 [INFO]-[Training Epoch 34], log_like_loss 0.3416554927825928 kl_loss: -0.12609781324863434 alpha: 0.001 lr: 0.001
# 2021-12-10 21:53:36 [INFO]-Execute [train_an_epoch] method costing 152293.49 ms
#  44%|####3     | 35/80 [1:26:18<1:52:56, 150.58s/it]Epoch 35 starts !
# 2021-12-10 21:53:36 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:56:07 [INFO]-[Training Epoch 35], log_like_loss 0.3412046432495117 kl_loss: -0.12858042120933533 alpha: 0.001 lr: 0.001
# 2021-12-10 21:56:07 [INFO]-Execute [train_an_epoch] method costing 151297.78 ms
#  45%|####5     | 36/80 [1:28:50<1:50:35, 150.81s/it]Epoch 36 starts !
# 2021-12-10 21:56:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:58:37 [INFO]-[Training Epoch 36], log_like_loss 0.3408830761909485 kl_loss: -0.13023033738136292 alpha: 0.001 lr: 0.001
# 2021-12-10 21:58:37 [INFO]-Execute [train_an_epoch] method costing 149753.85 ms
#  46%|####6     | 37/80 [1:31:19<1:47:52, 150.52s/it]Epoch 37 starts !
# 2021-12-10 21:58:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:01:08 [INFO]-[Training Epoch 37], log_like_loss 0.3404872417449951 kl_loss: -0.13237352669239044 alpha: 0.001 lr: 0.001
# 2021-12-10 22:01:08 [INFO]-Execute [train_an_epoch] method costing 150238.34 ms
#  48%|####7     | 38/80 [1:33:50<1:45:19, 150.46s/it]Epoch 38 starts !
# 2021-12-10 22:01:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:03:37 [INFO]-[Training Epoch 38], log_like_loss 0.34035027027130127 kl_loss: -0.1343688666820526 alpha: 0.001 lr: 0.001
# 2021-12-10 22:03:37 [INFO]-Execute [train_an_epoch] method costing 149564.58 ms
#  49%|####8     | 39/80 [1:36:19<1:42:38, 150.22s/it]Epoch 39 starts !
# 2021-12-10 22:03:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:06:07 [INFO]-[Training Epoch 39], log_like_loss 0.34008967876434326 kl_loss: -0.13606514036655426 alpha: 0.001 lr: 0.001
# 2021-12-10 22:06:07 [INFO]-Execute [train_an_epoch] method costing 149671.92 ms
#  50%|#####     | 40/80 [1:38:49<1:40:03, 150.08s/it]Epoch 40 starts !
# 2021-12-10 22:06:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:08:34 [INFO]-[Training Epoch 40], log_like_loss 0.33980637788772583 kl_loss: -0.13768424093723297 alpha: 0.001 lr: 0.001
# 2021-12-10 22:08:34 [INFO]-Execute [train_an_epoch] method costing 146755.91 ms
#  51%|#####1    | 41/80 [1:41:18<1:37:14, 149.61s/it]Epoch 41 starts !
# 2021-12-10 22:08:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:10:35 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 22:10:35 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 22:10:35 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 22:10:35 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 22:10:35 [INFO]-Current testEngine.best_valid_performance 0
# 2021-12-10 22:10:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:10:35 [INFO]-performance on validation at epoch 40
# 2021-12-10 22:10:35 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.672518 |
# |  1 | precision@10 | 0.623617 |
# |  2 | recall@10    | 0.232667 |
# |  3 | map@10       | 0.184884 |
# +----+--------------+----------
# 2021-12-10 22:10:35 [INFO]-
# 2021-12-10 22:10:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:10:35 [INFO]-Execute [train_eval_worker] method costing 119794.23 ms
# 2021-12-10 22:12:22 [INFO]-[Training Epoch 41], log_like_loss 0.339236319065094 kl_loss: -0.13918694853782654 alpha: 0.001 lr: 0.001
# 2021-12-10 22:12:22 [INFO]-Execute [train_an_epoch] method costing 226020.19 ms
#  52%|#####2    | 42/80 [1:45:06<1:49:37, 173.10s/it]Epoch 42 starts !
# 2021-12-10 22:12:23 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:14:15 [INFO]-Current testEngine.best_valid_performance 0.6725177515033478
# 2021-12-10 22:14:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:14:15 [INFO]-performance on validation at epoch 41
# 2021-12-10 22:14:15 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.680868 |
# |  1 | precision@10 | 0.630545 |
# |  2 | recall@10    | 0.235482 |
# |  3 | map@10       | 0.188381 |
# +----+--------------+----------
# 2021-12-10 22:14:15 [INFO]-
# 2021-12-10 22:14:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:14:15 [INFO]-Execute [train_eval_worker] method costing 111127.12 ms
# 2021-12-10 22:16:06 [INFO]-[Training Epoch 42], log_like_loss 0.3391946852207184 kl_loss: -0.1414303332567215 alpha: 0.001 lr: 0.001
# 2021-12-10 22:16:06 [INFO]-Execute [train_an_epoch] method costing 222338.13 ms
#  54%|#####3    | 43/80 [1:48:50<1:56:19, 188.63s/it]Epoch 43 starts !
# 2021-12-10 22:16:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:17:58 [INFO]-Current testEngine.best_valid_performance 0.680867948338969
# 2021-12-10 22:17:58 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:17:58 [INFO]-performance on validation at epoch 42
# 2021-12-10 22:17:58 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.681745 |
# |  1 | precision@10 | 0.631648 |
# |  2 | recall@10    | 0.236032 |
# |  3 | map@10       | 0.188959 |
# +----+--------------+----------
# 2021-12-10 22:17:58 [INFO]-
# 2021-12-10 22:17:58 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:17:58 [INFO]-Execute [train_eval_worker] method costing 109970.85 ms
# 2021-12-10 22:19:51 [INFO]-[Training Epoch 43], log_like_loss 0.33859962224960327 kl_loss: -0.14299710094928741 alpha: 0.001 lr: 0.001
# 2021-12-10 22:19:51 [INFO]-Execute [train_an_epoch] method costing 221877.80 ms
#  55%|#####5    | 44/80 [1:52:35<1:59:40, 199.46s/it]Epoch 44 starts !
# 2021-12-10 22:19:53 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:21:47 [INFO]-Current testEngine.best_valid_performance 0.6817454458220845
# 2021-12-10 22:21:47 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:21:47 [INFO]-performance on validation at epoch 43
# 2021-12-10 22:21:47 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.685552 |
# |  1 | precision@10 | 0.634665 |
# |  2 | recall@10    | 0.237175 |
# |  3 | map@10       | 0.190688 |
# +----+--------------+----------
# 2021-12-10 22:21:47 [INFO]-
# 2021-12-10 22:21:47 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:21:47 [INFO]-Execute [train_eval_worker] method costing 114303.75 ms
# 2021-12-10 22:23:36 [INFO]-[Training Epoch 44], log_like_loss 0.3386246860027313 kl_loss: -0.14506281912326813 alpha: 0.001 lr: 0.001
# 2021-12-10 22:23:36 [INFO]-Execute [train_an_epoch] method costing 219797.40 ms
#  56%|#####6    | 45/80 [1:56:19<2:00:42, 206.94s/it]Epoch 45 starts !
# 2021-12-10 22:23:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:25:35 [INFO]-Current testEngine.best_valid_performance 0.6855523332921982
# 2021-12-10 22:25:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:25:35 [INFO]-performance on validation at epoch 44
# 2021-12-10 22:25:35 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.68556  |
# |  1 | precision@10 | 0.635786 |
# |  2 | recall@10    | 0.237497 |
# |  3 | map@10       | 0.190911 |
# +----+--------------+----------
# 2021-12-10 22:25:35 [INFO]-
# 2021-12-10 22:25:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:25:35 [INFO]-Execute [train_eval_worker] method costing 117926.09 ms
# 2021-12-10 22:27:25 [INFO]-[Training Epoch 45], log_like_loss 0.33819398283958435 kl_loss: -0.14650645852088928 alpha: 0.001 lr: 0.001
# 2021-12-10 22:27:25 [INFO]-Execute [train_an_epoch] method costing 226381.73 ms
#  57%|#####7    | 46/80 [2:00:09<2:01:08, 213.78s/it]Epoch 46 starts !
# 2021-12-10 22:27:27 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:29:20 [INFO]-Current testEngine.best_valid_performance 0.6855595679557293
# 2021-12-10 22:29:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:29:20 [INFO]-performance on validation at epoch 45
# 2021-12-10 22:29:20 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.686879 |
# |  1 | precision@10 | 0.637037 |
# |  2 | recall@10    | 0.238088 |
# |  3 | map@10       | 0.191578 |
# +----+--------------+----------
# 2021-12-10 22:29:20 [INFO]-
# 2021-12-10 22:29:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:29:20 [INFO]-Execute [train_eval_worker] method costing 112542.44 ms
# 2021-12-10 22:31:14 [INFO]-[Training Epoch 46], log_like_loss 0.3380109667778015 kl_loss: -0.14754758775234222 alpha: 0.001 lr: 0.001
# 2021-12-10 22:31:14 [INFO]-Execute [train_an_epoch] method costing 226570.57 ms
#  59%|#####8    | 47/80 [2:03:58<2:00:00, 218.21s/it]Epoch 47 starts !
# 2021-12-10 22:31:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:33:17 [INFO]-Current testEngine.best_valid_performance 0.686878810099224
# 2021-12-10 22:33:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:33:17 [INFO]-performance on validation at epoch 46
# 2021-12-10 22:33:17 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.690647 |
# |  1 | precision@10 | 0.640227 |
# |  2 | recall@10    | 0.239641 |
# |  3 | map@10       | 0.193417 |
# +----+--------------+----------
# 2021-12-10 22:33:17 [INFO]-
# 2021-12-10 22:33:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:33:17 [INFO]-Execute [train_eval_worker] method costing 120916.20 ms
# 2021-12-10 22:35:06 [INFO]-[Training Epoch 47], log_like_loss 0.3379681408405304 kl_loss: -0.14866290986537933 alpha: 0.001 lr: 0.001
# 2021-12-10 22:35:06 [INFO]-Execute [train_an_epoch] method costing 228303.35 ms
#  60%|######    | 48/80 [2:07:50<1:58:33, 222.30s/it]Epoch 48 starts !
# 2021-12-10 22:35:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:36:55 [INFO]-Current testEngine.best_valid_performance 0.6906469315523553
# 2021-12-10 22:36:55 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:36:55 [INFO]-performance on validation at epoch 47
# 2021-12-10 22:36:55 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.695584 |
# |  1 | precision@10 | 0.644049 |
# |  2 | recall@10    | 0.240849 |
# |  3 | map@10       | 0.195581 |
# +----+--------------+----------
# 2021-12-10 22:36:55 [INFO]-
# 2021-12-10 22:36:55 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:36:55 [INFO]-Execute [train_eval_worker] method costing 107211.18 ms
# 2021-12-10 22:38:53 [INFO]-[Training Epoch 48], log_like_loss 0.3374350965023041 kl_loss: -0.15087023377418518 alpha: 0.001 lr: 0.001
# 2021-12-10 22:38:53 [INFO]-Execute [train_an_epoch] method costing 223105.18 ms
#  61%|######1   | 49/80 [2:11:37<1:55:35, 223.72s/it]Epoch 49 starts !
# 2021-12-10 22:38:55 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:40:47 [INFO]-number of epochs that have no update 1
# 2021-12-10 22:40:47 [INFO]-Execute [train_eval_worker] method costing 112283.88 ms
# 2021-12-10 22:42:41 [INFO]-[Training Epoch 49], log_like_loss 0.3372074067592621 kl_loss: -0.15203723311424255 alpha: 0.001 lr: 0.001
# 2021-12-10 22:42:41 [INFO]-Execute [train_an_epoch] method costing 224349.14 ms
#  62%|######2   | 50/80 [2:15:25<1:52:29, 224.98s/it]Epoch 50 starts !
# 2021-12-10 22:42:42 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:44:34 [INFO]-Current testEngine.best_valid_performance 0.6955842027002337
# 2021-12-10 22:44:34 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:44:34 [INFO]-performance on validation at epoch 49
# 2021-12-10 22:44:34 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.699322 |
# |  1 | precision@10 | 0.64832  |
# |  2 | recall@10    | 0.242684 |
# |  3 | map@10       | 0.197356 |
# +----+--------------+----------
# 2021-12-10 22:44:34 [INFO]-
# 2021-12-10 22:44:34 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:44:34 [INFO]-Execute [train_eval_worker] method costing 111868.68 ms
# 2021-12-10 22:46:27 [INFO]-[Training Epoch 50], log_like_loss 0.33724963665008545 kl_loss: -0.15386316180229187 alpha: 0.001 lr: 0.001
# 2021-12-10 22:46:27 [INFO]-Execute [train_an_epoch] method costing 224552.10 ms
#  64%|######3   | 51/80 [2:19:11<1:48:55, 225.35s/it]Epoch 51 starts !
# 2021-12-10 22:46:29 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:48:20 [INFO]-number of epochs that have no update 1
# 2021-12-10 22:48:20 [INFO]-Execute [train_eval_worker] method costing 111666.48 ms
# 2021-12-10 22:50:18 [INFO]-[Training Epoch 51], log_like_loss 0.3367633521556854 kl_loss: -0.15484854578971863 alpha: 0.001 lr: 0.001
# 2021-12-10 22:50:18 [INFO]-Execute [train_an_epoch] method costing 227970.56 ms
#  65%|######5   | 52/80 [2:23:02<1:45:58, 227.09s/it]Epoch 52 starts !
# 2021-12-10 22:50:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:52:06 [INFO]-Current testEngine.best_valid_performance 0.6993215531379714
# 2021-12-10 22:52:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:52:06 [INFO]-performance on validation at epoch 51
# 2021-12-10 22:52:06 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.704032 |
# |  1 | precision@10 | 0.652903 |
# |  2 | recall@10    | 0.244596 |
# |  3 | map@10       | 0.199688 |
# +----+--------------+----------
# 2021-12-10 22:52:06 [INFO]-
# 2021-12-10 22:52:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:52:06 [INFO]-Execute [train_eval_worker] method costing 105869.71 ms
# 2021-12-10 22:54:04 [INFO]-[Training Epoch 52], log_like_loss 0.3364822566509247 kl_loss: -0.15601438283920288 alpha: 0.001 lr: 0.001
# 2021-12-10 22:54:04 [INFO]-Execute [train_an_epoch] method costing 224468.91 ms
#  66%|######6   | 53/80 [2:26:48<1:42:04, 226.82s/it]Epoch 53 starts !
# 2021-12-10 22:54:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:55:58 [INFO]-number of epochs that have no update 1
# 2021-12-10 22:55:58 [INFO]-Execute [train_eval_worker] method costing 112025.11 ms
# 2021-12-10 22:57:55 [INFO]-[Training Epoch 53], log_like_loss 0.3367440700531006 kl_loss: -0.1569412350654602 alpha: 0.001 lr: 0.001
# 2021-12-10 22:57:55 [INFO]-Execute [train_an_epoch] method costing 227694.34 ms
#  68%|######7   | 54/80 [2:30:39<1:38:47, 227.98s/it]Epoch 54 starts !
# 2021-12-10 22:57:57 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:59:48 [INFO]-Current testEngine.best_valid_performance 0.7040324333808895
# 2021-12-10 22:59:48 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:59:48 [INFO]-performance on validation at epoch 53
# 2021-12-10 22:59:48 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.70801  |
# |  1 | precision@10 | 0.656663 |
# |  2 | recall@10    | 0.246168 |
# |  3 | map@10       | 0.201556 |
# +----+--------------+----------
# 2021-12-10 22:59:48 [INFO]-
# 2021-12-10 22:59:48 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:59:48 [INFO]-Execute [train_eval_worker] method costing 111737.38 ms
# 2021-12-10 23:01:41 [INFO]-[Training Epoch 54], log_like_loss 0.33623605966567993 kl_loss: -0.1581428498029709 alpha: 0.001 lr: 0.001
# 2021-12-10 23:01:41 [INFO]-Execute [train_an_epoch] method costing 224664.49 ms
#  69%|######8   | 55/80 [2:34:25<1:34:47, 227.51s/it]Epoch 55 starts !
# 2021-12-10 23:01:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:03:36 [INFO]-number of epochs that have no update 1
# 2021-12-10 23:03:36 [INFO]-Execute [train_eval_worker] method costing 113323.28 ms
# 2021-12-10 23:05:31 [INFO]-[Training Epoch 55], log_like_loss 0.3360675573348999 kl_loss: -0.158965066075325 alpha: 0.001 lr: 0.001
# 2021-12-10 23:05:31 [INFO]-Execute [train_an_epoch] method costing 226039.33 ms
#  70%|#######   | 56/80 [2:38:15<1:31:19, 228.29s/it]Epoch 56 starts !
# 2021-12-10 23:05:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:07:26 [INFO]-Current testEngine.best_valid_performance 0.7080100709348512
# 2021-12-10 23:07:26 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:07:26 [INFO]-performance on validation at epoch 55
# 2021-12-10 23:07:26 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.711349 |
# |  1 | precision@10 | 0.66     |
# |  2 | recall@10    | 0.247428 |
# |  3 | map@10       | 0.20324  |
# +----+--------------+----------
# 2021-12-10 23:07:26 [INFO]-
# 2021-12-10 23:07:26 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:07:26 [INFO]-Execute [train_eval_worker] method costing 112448.41 ms
# 2021-12-10 23:09:24 [INFO]-[Training Epoch 56], log_like_loss 0.33586838841438293 kl_loss: -0.16026268899440765 alpha: 0.001 lr: 0.001
# 2021-12-10 23:09:24 [INFO]-Execute [train_an_epoch] method costing 230364.64 ms
#  71%|#######1  | 57/80 [2:42:08<1:27:57, 229.47s/it]Epoch 57 starts !
# 2021-12-10 23:09:25 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:11:12 [INFO]-Current testEngine.best_valid_performance 0.7113485325959664
# 2021-12-10 23:11:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:11:12 [INFO]-performance on validation at epoch 56
# 2021-12-10 23:11:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.712216 |
# |  1 | precision@10 | 0.661019 |
# |  2 | recall@10    | 0.248026 |
# |  3 | map@10       | 0.203717 |
# +----+--------------+----------
# 2021-12-10 23:11:12 [INFO]-
# 2021-12-10 23:11:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:11:12 [INFO]-Execute [train_eval_worker] method costing 106446.19 ms
# 2021-12-10 23:13:12 [INFO]-[Training Epoch 57], log_like_loss 0.3353746831417084 kl_loss: -0.16201132535934448 alpha: 0.001 lr: 0.001
# 2021-12-10 23:13:12 [INFO]-Execute [train_an_epoch] method costing 224399.18 ms
#  72%|#######2  | 58/80 [2:45:56<1:24:03, 229.23s/it]Epoch 58 starts !
# 2021-12-10 23:13:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:15:05 [INFO]-Current testEngine.best_valid_performance 0.712215618743704
# 2021-12-10 23:15:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:15:05 [INFO]-performance on validation at epoch 57
# 2021-12-10 23:15:05 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.715233 |
# |  1 | precision@10 | 0.663453 |
# |  2 | recall@10    | 0.248996 |
# |  3 | map@10       | 0.205258 |
# +----+--------------+----------
# 2021-12-10 23:15:05 [INFO]-
# 2021-12-10 23:15:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:15:05 [INFO]-Execute [train_eval_worker] method costing 110768.12 ms
# 2021-12-10 23:17:00 [INFO]-[Training Epoch 58], log_like_loss 0.33517131209373474 kl_loss: -0.16339701414108276 alpha: 0.001 lr: 0.001
# 2021-12-10 23:17:00 [INFO]-Execute [train_an_epoch] method costing 223478.59 ms
#  74%|#######3  | 59/80 [2:49:43<1:20:01, 228.64s/it]Epoch 59 starts !
# 2021-12-10 23:17:01 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:18:54 [INFO]-number of epochs that have no update 1
# 2021-12-10 23:18:54 [INFO]-Execute [train_eval_worker] method costing 112543.84 ms
# 2021-12-10 23:20:51 [INFO]-[Training Epoch 59], log_like_loss 0.3351443409919739 kl_loss: -0.16419143974781036 alpha: 0.001 lr: 0.001
# 2021-12-10 23:20:51 [INFO]-Execute [train_an_epoch] method costing 229206.79 ms
#  75%|#######5  | 60/80 [2:53:35<1:16:27, 229.38s/it]Epoch 60 starts !
# 2021-12-10 23:20:52 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:22:34 [INFO]-Current testEngine.best_valid_performance 0.7152325773184656
# 2021-12-10 23:22:34 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:22:34 [INFO]-performance on validation at epoch 59
# 2021-12-10 23:22:34 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.718264 |
# |  1 | precision@10 | 0.666603 |
# |  2 | recall@10    | 0.250359 |
# |  3 | map@10       | 0.206773 |
# +----+--------------+----------
# 2021-12-10 23:22:34 [INFO]-
# 2021-12-10 23:22:34 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:22:34 [INFO]-Execute [train_eval_worker] method costing 101375.81 ms
# 2021-12-10 23:24:36 [INFO]-[Training Epoch 60], log_like_loss 0.33469146490097046 kl_loss: -0.1652553230524063 alpha: 0.001 lr: 0.001
# 2021-12-10 23:24:36 [INFO]-Execute [train_an_epoch] method costing 223165.12 ms
#  76%|#######6  | 61/80 [2:57:20<1:12:13, 228.06s/it]Epoch 61 starts !
# 2021-12-10 23:24:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:26:31 [INFO]-number of epochs that have no update 1
# 2021-12-10 23:26:31 [INFO]-Execute [train_eval_worker] method costing 113303.48 ms
# 2021-12-10 23:28:25 [INFO]-[Training Epoch 61], log_like_loss 0.3348277807235718 kl_loss: -0.1663234978914261 alpha: 0.001 lr: 0.001
# 2021-12-10 23:28:25 [INFO]-Execute [train_an_epoch] method costing 226371.66 ms
#  78%|#######7  | 62/80 [3:01:09<1:08:31, 228.43s/it]Epoch 62 starts !
# 2021-12-10 23:28:27 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:30:12 [INFO]-Current testEngine.best_valid_performance 0.718263512662519
# 2021-12-10 23:30:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:30:12 [INFO]-performance on validation at epoch 61
# 2021-12-10 23:30:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.720552 |
# |  1 | precision@10 | 0.668707 |
# |  2 | recall@10    | 0.251248 |
# |  3 | map@10       | 0.208028 |
# +----+--------------+----------
# 2021-12-10 23:30:12 [INFO]-
# 2021-12-10 23:30:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:30:12 [INFO]-Execute [train_eval_worker] method costing 105640.49 ms
# 2021-12-10 23:32:14 [INFO]-[Training Epoch 62], log_like_loss 0.33468639850616455 kl_loss: -0.16725093126296997 alpha: 0.001 lr: 0.001
# 2021-12-10 23:32:14 [INFO]-Execute [train_an_epoch] method costing 226910.20 ms
#  79%|#######8  | 63/80 [3:04:57<1:04:44, 228.47s/it]Epoch 63 starts !
# 2021-12-10 23:32:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:34:06 [INFO]-Current testEngine.best_valid_performance 0.7205517638922435
# 2021-12-10 23:34:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:34:06 [INFO]-performance on validation at epoch 62
# 2021-12-10 23:34:06 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.721187 |
# |  1 | precision@10 | 0.670033 |
# |  2 | recall@10    | 0.252147 |
# |  3 | map@10       | 0.208458 |
# +----+--------------+----------
# 2021-12-10 23:34:06 [INFO]-
# 2021-12-10 23:34:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:34:06 [INFO]-Execute [train_eval_worker] method costing 110729.37 ms
# 2021-12-10 23:36:01 [INFO]-[Training Epoch 63], log_like_loss 0.33433106541633606 kl_loss: -0.16801874339580536 alpha: 0.001 lr: 0.001
# 2021-12-10 23:36:01 [INFO]-Execute [train_an_epoch] method costing 223672.14 ms
#  80%|########  | 64/80 [3:08:45<1:00:50, 228.17s/it]Epoch 64 starts !
# 2021-12-10 23:36:03 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:37:56 [INFO]-Current testEngine.best_valid_performance 0.7211866613114017
# 2021-12-10 23:37:56 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:37:56 [INFO]-performance on validation at epoch 63
# ...
# 2021-12-11 00:57:18 [INFO]-Execute [test_eval_worker] method costing 181690.09 ms
# 2021-12-11 01:00:21 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:00:21 [INFO]-performance on test
# 2021-12-11 01:00:21 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.798129 |
# |  1 | precision@5  | 0.770741 |
# |  2 | recall@5     | 0.154047 |
# |  3 | map@5        | 0.1388   |
# |  4 | ndcg@10      | 0.743122 |
# |  5 | precision@10 | 0.691446 |
# |  6 | recall@10    | 0.260765 |
# |  7 | map@10       | 0.218928 |
# |  8 | ndcg@20      | 0.699061 |
# |  9 | precision@20 | 0.597058 |
# | 10 | recall@20    | 0.419971 |
# | 11 | map@20       | 0.323735 |
# +----+--------------+----------
# 2021-12-11 01:00:21 [INFO]-
# 2021-12-11 01:00:21 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:00:21 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 01:00:21 [INFO]-Execute [test_eval_worker] method costing 180808.28 ms
# 2021-12-11 01:03:23 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:03:23 [INFO]-performance on test
# 2021-12-11 01:03:23 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.798275 |
# |  1 | precision@5  | 0.771427 |
# |  2 | recall@5     | 0.154017 |
# |  3 | map@5        | 0.13856  |
# |  4 | ndcg@10      | 0.743078 |
# |  5 | precision@10 | 0.691687 |
# |  6 | recall@10    | 0.260657 |
# |  7 | map@10       | 0.218643 |
# |  8 | ndcg@20      | 0.698773 |
# |  9 | precision@20 | 0.597018 |
# | 10 | recall@20    | 0.419549 |
# | 11 | map@20       | 0.323311 |
# +----+--------------+----------
# 2021-12-11 01:03:23 [INFO]-
# 2021-12-11 01:03:23 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:03:23 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 01:03:23 [INFO]-Execute [test_eval_worker] method costing 181150.61 ms
# 2021-12-11 01:06:25 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:06:25 [INFO]-performance on test
# 2021-12-11 01:06:25 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.797226 |
# |  1 | precision@5  | 0.770295 |
# |  2 | recall@5     | 0.153719 |
# |  3 | map@5        | 0.138288 |
# |  4 | ndcg@10      | 0.742177 |
# |  5 | precision@10 | 0.6908   |
# |  6 | recall@10    | 0.260402 |
# |  7 | map@10       | 0.218311 |
# |  8 | ndcg@20      | 0.698295 |
# |  9 | precision@20 | 0.596695 |
# | 10 | recall@20    | 0.419493 |
# | 11 | map@20       | 0.32291  |
# +----+--------------+----------
# 2021-12-11 01:06:25 [INFO]-
# 2021-12-11 01:06:25 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:06:25 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 01:06:25 [INFO]-Execute [test_eval_worker] method costing 180144.90 ms
# 2021-12-11 01:09:31 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:09:31 [INFO]-performance on test
# 2021-12-11 01:09:31 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.799454 |
# |  1 | precision@5  | 0.772622 |
# |  2 | recall@5     | 0.154126 |
# |  3 | map@5        | 0.13907  |
# |  4 | ndcg@10      | 0.743476 |
# |  5 | precision@10 | 0.691767 |
# |  6 | recall@10    | 0.260365 |
# |  7 | map@10       | 0.219218 |
# |  8 | ndcg@20      | 0.699079 |
# |  9 | precision@20 | 0.596811 |
# | 10 | recall@20    | 0.419648 |
# | 11 | map@20       | 0.323759 |
# +----+--------------+----------
# 2021-12-11 01:09:31 [INFO]-
# 2021-12-11 01:09:31 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:09:31 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 01:09:31 [INFO]-Execute [test_eval_worker] method costing 184302.48 ms
# 2021-12-11 01:09:31 [INFO]-Execute [test_eval] method costing 1903844.05 ms
# 2021-12-11 01:09:31 [INFO]-Search default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# 2021-12-11 01:09:31 [INFO]-Found default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# 2021-12-11 01:09:31 [INFO]-loading config file /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# 2021-12-11 01:09:31 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:09:31 [INFO]-Received parameters from command line (or default):
# 2021-12-11 01:09:31 [INFO]-
# +----+-----------------------+------------------------------------+
# |    | keys                  | values                             |
# |----+-----------------------+------------------------------------|
# |  0 | system:root_dir       | /home/zm324/workspace/beta-recsys/ |
# |  1 | model:n_sample        | 1000000                            |
# |  2 | model:max_epoch       | 80                                 |
# |  3 | model:emb_dim         | 64                                 |
# |  4 | model:time_step       | 20                                 |
# |  5 | model:batch_size      | 10000                              |
# |  6 | model:lr              | 0.001                              |
# |  7 | dataset:item_fea_type | cate                               |
# |  8 | dataset:dataset       | instacart_25                       |
# +----+-----------------------+------------------------------------
# 2021-12-11 01:09:31 [INFO]-
# 2021-12-11 01:09:31 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:09:31 [INFO]-logs will save in file: /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211211_010931_ttfvyo .stdout.log .stderr.log
# 2021-12-11 01:09:31 [INFO]-
# 2021-12-11 01:09:31 [INFO]-
# Python version: 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0
# 2021-12-11 01:09:31 [INFO]-2021-12-11 01:09:31 [INFO]-
# 2021-12-11 01:09:31 [INFO]-2021-12-11 01:09:31 [INFO]-Pytorch version: 1.7.1
# 2021-12-11 01:09:31 [INFO]-2021-12-11 01:09:31 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211211_010931_ttfvyo
# 2021-12-11 01:09:31 [INFO]-2021-12-11 01:09:31 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211211_010931_ttfvyo
# 2021-12-11 01:09:31 [INFO]-2021-12-11 01:09:31 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/tvbr_result.csv
# 2021-12-11 01:09:31 [INFO]-2021-12-11 01:09:31 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:09:31 [INFO]-2021-12-11 01:09:31 [INFO]-System configs
# 2021-12-11 01:09:31 [INFO]-
# 2021-12-11 01:09:31 [INFO]-
# +----+----------------+-----------------------------------------------------------------------------------+
# |    | keys           | values                                                                            |
# |----+----------------+-----------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                 |
# |  1 | log_dir        | logs/                                                                             |
# |  2 | result_dir     | results/                                                                          |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                      |
# |  4 | checkpoint_dir | checkpoints/                                                                      |
# |  5 | dataset_dir    | datasets/                                                                         |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211211_010931_ttfvyo        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                   |
# |  8 | device         | gpu                                                                               |
# |  9 | seed           | 2020                                                                              |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                            |
# | 11 | k              | [5, 10, 20]                                                                       |
# | 12 | valid_metric   | ndcg                                                                              |
# | 13 | valid_k        | 10                                                                                |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/tvbr_result.csv                         |
# | 15 | save_mode      | average                                                                           |
# | 16 | model_run_id   | TVBR_default_20211211_010931_ttfvyo                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211211_010931_ttfvyo        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211211_010931_ttfvyo |
# +----+----------------+-----------------------------------------------------------------------------------
# 2021-12-11 01:09:31 [INFO]-2021-12-11 01:09:31 [INFO]-
# 2021-12-11 01:09:31 [INFO]-2021-12-11 01:09:31 [INFO]---------------------------------------------------------------------------------
# Finishing last run (ID:18kls0no) before initializing another...
# <br/>Waiting for W&B process to finish, PID 14060... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.72MB of 0.72MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# </div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>TVBR_default_20211210_202430_murihu/device/GPU/GPU_load (%)</td><td>7.0</td></tr><tr><td>TVBR_default_20211210_202430_murihu/device/GPU/GPU_load (%)/global_step</td><td>7941</td></tr><tr><td>TVBR_default_20211210_202430_murihu/device/GPU/GPU_memory_free (%)</td><td>25472.2207</td></tr><tr><td>TVBR_default_20211210_202430_murihu/device/GPU/GPU_memory_free (%)/global_step</td><td>7941</td></tr><tr><td>TVBR_default_20211210_202430_murihu/device/GPU/GPU_memory_used (%)</td><td>76927.78125</td></tr><tr><td>TVBR_default_20211210_202430_murihu/device/GPU/GPU_memory_used (%)/global_step</td><td>7941</td></tr><tr><td>TVBR_default_20211210_202430_murihu/device/cpu/CPU_load (%)</td><td>102.7</td></tr><tr><td>TVBR_default_20211210_202430_murihu/device/cpu/CPU_load (%)/global_step</td><td>7941</td></tr><tr><td>TVBR_default_20211210_202430_murihu/device/mem/memory_used (GB)</td><td>9.78522</td></tr><tr><td>TVBR_default_20211210_202430_murihu/device/mem/memory_used (GB)/global_step</td><td>7941</td></tr><tr><td>TVBR_default_20211210_202430_murihu/model/loss/kl_loss</td><td>-0.1771</td></tr><tr><td>TVBR_default_20211210_202430_murihu/model/loss/kl_loss/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202430_murihu/model/loss/rec_loss</td><td>0.50866</td></tr><tr><td>TVBR_default_20211210_202430_murihu/model/loss/rec_loss/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202430_murihu/model/loss/total_loss</td><td>0.33156</td></tr><tr><td>TVBR_default_20211210_202430_murihu/model/loss/total_loss/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202430_murihu/performance/map/valid</td><td>0.21929</td></tr><tr><td>TVBR_default_20211210_202430_murihu/performance/map/valid/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202430_murihu/performance/ndcg/valid</td><td>0.74176</td></tr><tr><td>TVBR_default_20211210_202430_murihu/performance/ndcg/valid/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202430_murihu/performance/precision/valid</td><td>0.68999</td></tr><tr><td>TVBR_default_20211210_202430_murihu/performance/precision/valid/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202430_murihu/performance/recall/valid</td><td>0.26039</td></tr><tr><td>TVBR_default_20211210_202430_murihu/performance/recall/valid/global_step</td><td>79</td></tr><tr><td>epoch</td><td>79</td></tr><tr><td>global_step</td><td>7941</td></tr><tr><td>valid_map@10</td><td>0.21929</td></tr><tr><td>valid_ndcg@10</td><td>0.74176</td></tr><tr><td>valid_precision@10</td><td>0.68999</td></tr><tr><td>valid_recall@10</td><td>0.26039</td></tr></table>
# </div></div>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 7 other file(s)
# <br/>Synced <strong style="color:#cdcd00">fancy-dew-53</strong>: <a href="https://wandb.ai/mengzaiqiao/TVBR/runs/18kls0no" target="_blank">https://wandb.ai/mengzaiqiao/TVBR/runs/18kls0no</a><br/>
# Find logs at: <code>./wandb/run-20211210_202430-18kls0no/logs</code><br/>
# Successfully finished last run (ID:18kls0no). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/mengzaiqiao/TVBR/runs/1zicm8f2" target="_blank">desert-frog-56</a></strong> to <a href="https://wandb.ai/mengzaiqiao/TVBR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 2021-12-11 01:09:44 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 01:09:44 [INFO]-Initializing test engine ...
# 2021-12-11 01:09:44 [INFO]-load basic item featrue for dataset: instacart_25  type: cate
# 2021-12-11 01:09:51 [INFO]-Setting device for torch_engine cpu
# 2021-12-11 01:09:51 [INFO]-
# TVBR(
#   (user_emb): Embedding(23093, 64)
#   (item_emb): Embedding(14565, 64)
#   (time_embdding): Embedding(21, 21)
#   (user_mean): Embedding(23093, 64)
#   (user_std): Embedding(23093, 64)
#   (item_mean): Embedding(14565, 64)
#   (item_std): Embedding(14565, 64)
#   (time2mean_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2mean_i): Sequential(
#     (0): Linear(in_features=240, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_i): Sequential(
#     (0): Linear(in_features=240, out_features=64, bias=True)
#     (1): Tanh()
#   )
#
# 2021-12-11 01:09:51 [INFO]-
# 2021-12-11 01:09:51 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 01:09:51 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 01:09:53 [INFO]-Initialize Sampler!
# 2021-12-11 01:09:53 [INFO]-preparing training triples ...
# 2021-12-11 01:09:54 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 01:09:54 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 100%|##########| 20/20 [02:03<00:00,  6.15s/it]
#   0%|          | 0/80 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-12-11 01:13:06 [INFO]---------------------------------------------------------------------------------
