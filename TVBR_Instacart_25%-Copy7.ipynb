# %% [markdown]
# ### Install Beta-recsys

# %% [markdown]
# ## Loading dataset

# %%
import sys

sys.path.append("../")

import random

import numpy as np

from beta_rec.data.grocery_data import GroceryData
from beta_rec.datasets.instacart import Instacart_25

seed = 2021
random.seed(seed)  # Fix random seeds for reproducibility
np.random.seed(seed)

# make sure that you have already download the Instacart data from this link: https://www.kaggle.com/c/instacart-market-basket-analysis#
# uncompressed them and put them in this folder: ../datasets/instacart_25/raw/*.csv


dataset = Instacart_25(
    min_u_c=20, min_i_c=30, min_o_c=10
)  # Specifying the filtering conditions.

# Split the data
split_dataset = dataset.load_temporal_basket_split(test_rate=0.2, n_test=10)
data = GroceryData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 3857794    | 3857794    | 3857794      | 3857794         | 3857794     |
# | nunique | 23093      | 14565      | 1            | 3857794         | 373719      |
# +---------+------------+------------+--------------+-----------------+-------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table

# %% [markdown]
# ### Model config

# %%
config = {"config_file": "../configs/tvbr_default.json"}
config["n_sample"] = 1000000  # To reduce the test running time
config["max_epoch"] = 80
config["emb_dim"] = 64
config["time_step"] = 50
config["batch_size"] = 1024
# config["tunable"] = [
#     {"name": "lr", "type": "choice", "values": [0.5, 0.05, 0.025, 0.001, 0.005]},
# ]
# config["tune"] = True
# the 'config_file' key is required, that is used load a default config.
# Other keys can be specified to replace the default settings.

# %% [markdown]
# ### Model intialization and training

# %%
from beta_rec.recommenders import TVBR

lr = 0.001
time_step = 100
config["lr"] = lr
config["time_step"] = time_step
config["item_fea_type"] = "random_word2vec"
config["root_dir"] = "/home/zm324/workspace/beta-recsys/"
config["dataset"] = "instacart_25"
model = TVBR(config)
model.train(data)
model.test(data.test[0])
# @To be discussed
# model.train(train_df)
# Case 1, without validation, stop training by loss or max_epoch

# model.train(train_df,valid_df[0])
# Case 2, with validation, stop training by performance on validation set

# model.train(train_df,valid_df[0],test_df[0])
# Case 3, same as Case 2, but also evaluate performance for each epoch on test set.

# Note that the best model will be save automatically, and record the model-save-dir.
# Out:
# Search default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# Found default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# loading config file /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +----+-----------------------+------------------------------------+
# |    | keys                  | values                             |
# |----+-----------------------+------------------------------------|
# |  0 | system:root_dir       | /home/zm324/workspace/beta-recsys/ |
# |  1 | model:n_sample        | 1000000                            |
# |  2 | model:max_epoch       | 80                                 |
# |  3 | model:emb_dim         | 64                                 |
# |  4 | model:time_step       | 100                                |
# |  5 | model:batch_size      | 1024                               |
# |  6 | model:lr              | 0.001                              |
# |  7 | dataset:item_fea_type | random_word2vec                    |
# |  8 | dataset:dataset       | instacart_25                       |
# +----+-----------------------+------------------------------------+
# --------------------------------------------------------------------------------
# logs will save in file: /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211203_131118_murihu .stdout.log .stderr.log
# 2021-12-03 13:11:18 [INFO]-
# Python version: 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0
# 2021-12-03 13:11:18 [INFO]-
# 2021-12-03 13:11:18 [INFO]-Pytorch version: 1.7.1
# 2021-12-03 13:11:18 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211203_131118_murihu
# 2021-12-03 13:11:18 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211203_131118_murihu
# 2021-12-03 13:11:18 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/tvbr_result.csv
# 2021-12-03 13:11:18 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:11:18 [INFO]-System configs
# 2021-12-03 13:11:18 [INFO]-
# +----+----------------+-----------------------------------------------------------------------------------+
# |    | keys           | values                                                                            |
# |----+----------------+-----------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                 |
# |  1 | log_dir        | logs/                                                                             |
# |  2 | result_dir     | results/                                                                          |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                      |
# |  4 | checkpoint_dir | checkpoints/                                                                      |
# |  5 | dataset_dir    | datasets/                                                                         |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211203_131118_murihu        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                   |
# |  8 | device         | gpu                                                                               |
# |  9 | seed           | 2020                                                                              |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                            |
# | 11 | k              | [5, 10, 20]                                                                       |
# | 12 | valid_metric   | ndcg                                                                              |
# | 13 | valid_k        | 10                                                                                |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/tvbr_result.csv                         |
# | 15 | save_mode      | average                                                                           |
# | 16 | model_run_id   | TVBR_default_20211203_131118_murihu                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211203_131118_murihu        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211203_131118_murihu |
# +----+----------------+-----------------------------------------------------------------------------------
# 2021-12-03 13:11:18 [INFO]-
# 2021-12-03 13:11:18 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:11:18 [ERROR]-Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# 2021-12-03 13:11:19 [ERROR]-wandb: Currently logged in as: mengzaiqiao (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/mengzaiqiao/TVBR/runs/1d7bnpb8" target="_blank">splendid-lake-28</a></strong> to <a href="https://wandb.ai/mengzaiqiao/TVBR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 2021-12-03 13:11:20 [INFO]-Get a gpu with the most available memory : 1
# 2021-12-03 13:11:20 [INFO]-Initializing test engine ...
# 2021-12-03 13:11:20 [INFO]-Get a gpu with the most available memory : 1
# 2021-12-03 13:11:20 [INFO]-load basic item featrue for dataset: instacart_25  type: word2vec
# 2021-12-03 13:11:29 [INFO]-Setting device for torch_engine cuda:1
# 2021-12-03 13:11:29 [INFO]-
# TVBR(
#   (user_emb): Embedding(23093, 64)
#   (item_emb): Embedding(14565, 64)
#   (time_embdding): Embedding(101, 101)
#   (user_mean): Embedding(23093, 64)
#   (user_std): Embedding(23093, 64)
#   (item_mean): Embedding(14565, 64)
#   (item_std): Embedding(14565, 64)
#   (time2mean_u): Sequential(
#     (0): Linear(in_features=677, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_u): Sequential(
#     (0): Linear(in_features=677, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2mean_i): Sequential(
#     (0): Linear(in_features=977, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_i): Sequential(
#     (0): Linear(in_features=977, out_features=64, bias=True)
#     (1): Tanh()
#   )
#
# 2021-12-03 13:11:29 [INFO]-
# 2021-12-03 13:11:32 [INFO]-Initialize Sampler!
# 2021-12-03 13:11:32 [INFO]-preparing training triples ...
# 2021-12-03 13:11:33 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:11:33 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:11:33 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:11:33 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:11:33 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 100%|##########| 100/100 [01:39<00:00,  1.01it/s]
#   0%|          | 0/80 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-12-03 13:14:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:15:56 [INFO]-[Training Epoch 0], log_like_loss 34.861000061035156 kl_loss: -0.16928361356258392 alpha: 0.001 lr: 0.001
# 2021-12-03 13:15:56 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:15:56 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:15:56 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:15:56 [INFO]-Execute [train_an_epoch] method costing 110007.06 ms
#   1%|1         | 1/80 [02:12<2:54:01, 132.17s/it]Epoch 1 starts !
# 2021-12-03 13:16:18 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:18:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:18:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:18:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:18:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:18:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:18:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:18:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:18:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-03 13:18:20 [INFO]-Current testEngine.best_valid_performance 0
# 2021-12-03 13:18:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:18:20 [INFO]-performance on validation at epoch 0
# 2021-12-03 13:18:20 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.317771  |
# |  1 | precision@10 | 0.305504  |
# |  2 | recall@10    | 0.0997504 |
# |  3 | map@10       | 0.0534481 |
# +----+--------------+-----------
# 2021-12-03 13:18:20 [INFO]-
# 2021-12-03 13:18:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:18:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:18:20 [INFO]-performance on testing at epoch 0
# 2021-12-03 13:18:20 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.318223  |
# |  1 | precision@10 | 0.30579   |
# |  2 | recall@10    | 0.0995045 |
# |  3 | map@10       | 0.0536512 |
# +----+--------------+-----------
# 2021-12-03 13:18:20 [INFO]-
# 2021-12-03 13:18:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:18:20 [INFO]-Execute [train_eval_worker] method costing 122401.99 ms
# 2021-12-03 13:20:02 [INFO]-[Training Epoch 1], log_like_loss 33.64385986328125 kl_loss: -0.06562970578670502 alpha: 0.001 lr: 0.001
# 2021-12-03 13:20:03 [INFO]-Execute [train_an_epoch] method costing 224610.35 ms
#   2%|2         | 2/80 [06:18<3:36:11, 166.30s/it]Epoch 2 starts !
# 2021-12-03 13:20:24 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:22:29 [INFO]-Current testEngine.best_valid_performance 0.3177705894596855
# 2021-12-03 13:22:29 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:22:29 [INFO]-performance on validation at epoch 1
# 2021-12-03 13:22:29 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.431491  |
# |  1 | precision@10 | 0.40214   |
# |  2 | recall@10    | 0.13739   |
# |  3 | map@10       | 0.0878147 |
# +----+--------------+-----------
# 2021-12-03 13:22:29 [INFO]-
# 2021-12-03 13:22:29 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:22:29 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:22:29 [INFO]-performance on testing at epoch 1
# 2021-12-03 13:22:29 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.432428  |
# |  1 | precision@10 | 0.403566  |
# |  2 | recall@10    | 0.137193  |
# |  3 | map@10       | 0.0876681 |
# +----+--------------+-----------
# 2021-12-03 13:22:29 [INFO]-
# 2021-12-03 13:22:29 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:22:29 [INFO]-Execute [train_eval_worker] method costing 124919.86 ms
# 2021-12-03 13:24:12 [INFO]-[Training Epoch 2], log_like_loss 33.30105972290039 kl_loss: -0.1309572011232376 alpha: 0.001 lr: 0.001
# 2021-12-03 13:24:12 [INFO]-Execute [train_an_epoch] method costing 225824.56 ms
#   4%|3         | 3/80 [10:26<4:05:10, 191.05s/it]Epoch 3 starts !
# 2021-12-03 13:24:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:26:37 [INFO]-Current testEngine.best_valid_performance 0.43149085908046003
# 2021-12-03 13:26:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:26:37 [INFO]-performance on validation at epoch 2
# 2021-12-03 13:26:37 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.487202 |
# |  1 | precision@10 | 0.453597 |
# |  2 | recall@10    | 0.158663 |
# |  3 | map@10       | 0.106858 |
# +----+--------------+----------
# 2021-12-03 13:26:37 [INFO]-
# 2021-12-03 13:26:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:26:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:26:37 [INFO]-performance on testing at epoch 2
# 2021-12-03 13:26:37 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.487083 |
# |  1 | precision@10 | 0.453178 |
# |  2 | recall@10    | 0.157709 |
# |  3 | map@10       | 0.106221 |
# +----+--------------+----------
# 2021-12-03 13:26:37 [INFO]-
# 2021-12-03 13:26:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:26:37 [INFO]-Execute [train_eval_worker] method costing 124778.06 ms
# 2021-12-03 13:28:21 [INFO]-[Training Epoch 3], log_like_loss 32.96014404296875 kl_loss: -0.879331648349762 alpha: 0.001 lr: 0.001
# 2021-12-03 13:28:21 [INFO]-Execute [train_an_epoch] method costing 226392.40 ms
#   5%|5         | 4/80 [14:35<4:23:57, 208.39s/it]Epoch 4 starts !
# 2021-12-03 13:28:42 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:30:48 [INFO]-Current testEngine.best_valid_performance 0.48720184254110466
# 2021-12-03 13:30:48 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:30:48 [INFO]-performance on validation at epoch 3
# 2021-12-03 13:30:48 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.514718 |
# |  1 | precision@10 | 0.479542 |
# |  2 | recall@10    | 0.170564 |
# |  3 | map@10       | 0.117515 |
# +----+--------------+----------
# 2021-12-03 13:30:48 [INFO]-
# 2021-12-03 13:30:48 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:30:48 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:30:48 [INFO]-performance on testing at epoch 3
# 2021-12-03 13:30:48 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.514981 |
# |  1 | precision@10 | 0.479865 |
# |  2 | recall@10    | 0.169421 |
# |  3 | map@10       | 0.116997 |
# +----+--------------+----------
# 2021-12-03 13:30:48 [INFO]-
# 2021-12-03 13:30:48 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:30:48 [INFO]-Execute [train_eval_worker] method costing 126418.52 ms
# 2021-12-03 13:32:31 [INFO]-[Training Epoch 4], log_like_loss 32.64369583129883 kl_loss: -1.2271709442138672 alpha: 0.001 lr: 0.001
# 2021-12-03 13:32:31 [INFO]-Execute [train_an_epoch] method costing 227707.41 ms
#   6%|6         | 5/80 [18:45<4:35:55, 220.74s/it]Epoch 5 starts !
# 2021-12-03 13:32:51 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:34:57 [INFO]-Current testEngine.best_valid_performance 0.5147182435127982
# 2021-12-03 13:34:57 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:34:57 [INFO]-performance on validation at epoch 4
# 2021-12-03 13:34:57 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.538401 |
# |  1 | precision@10 | 0.500111 |
# |  2 | recall@10    | 0.179323 |
# |  3 | map@10       | 0.126246 |
# +----+--------------+----------
# 2021-12-03 13:34:57 [INFO]-
# 2021-12-03 13:34:57 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:34:57 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:34:57 [INFO]-performance on testing at epoch 4
# 2021-12-03 13:34:57 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.538345 |
# |  1 | precision@10 | 0.500423 |
# |  2 | recall@10    | 0.177978 |
# |  3 | map@10       | 0.1255   |
# +----+--------------+----------
# 2021-12-03 13:34:57 [INFO]-
# 2021-12-03 13:34:57 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:34:57 [INFO]-Execute [train_eval_worker] method costing 125552.43 ms
# 2021-12-03 13:36:37 [INFO]-[Training Epoch 5], log_like_loss 32.3841438293457 kl_loss: -1.2552375793457031 alpha: 0.001 lr: 0.001
# 2021-12-03 13:36:37 [INFO]-Execute [train_an_epoch] method costing 224029.13 ms
#   8%|7         | 6/80 [22:51<4:41:44, 228.44s/it]Epoch 6 starts !
# 2021-12-03 13:36:57 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:39:00 [INFO]-Current testEngine.best_valid_performance 0.5384005325521357
# 2021-12-03 13:39:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:39:00 [INFO]-performance on validation at epoch 5
# 2021-12-03 13:39:00 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.556367 |
# |  1 | precision@10 | 0.515956 |
# |  2 | recall@10    | 0.186496 |
# |  3 | map@10       | 0.133518 |
# +----+--------------+----------
# 2021-12-03 13:39:00 [INFO]-
# 2021-12-03 13:39:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:39:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:39:00 [INFO]-performance on testing at epoch 5
# 2021-12-03 13:39:00 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.557714 |
# |  1 | precision@10 | 0.517246 |
# |  2 | recall@10    | 0.1857   |
# |  3 | map@10       | 0.133159 |
# +----+--------------+----------
# 2021-12-03 13:39:00 [INFO]-
# 2021-12-03 13:39:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:39:00 [INFO]-Execute [train_eval_worker] method costing 122977.25 ms
# 2021-12-03 13:40:41 [INFO]-[Training Epoch 6], log_like_loss 32.19607925415039 kl_loss: -1.257351040840149 alpha: 0.001 lr: 0.001
# 2021-12-03 13:40:41 [INFO]-Execute [train_an_epoch] method costing 223358.98 ms
#   9%|8         | 7/80 [26:55<4:43:32, 233.05s/it]Epoch 7 starts !
# 2021-12-03 13:41:01 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:43:05 [INFO]-Current testEngine.best_valid_performance 0.5563668694761802
# 2021-12-03 13:43:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:43:05 [INFO]-performance on validation at epoch 6
# 2021-12-03 13:43:05 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.571857 |
# |  1 | precision@10 | 0.529646 |
# |  2 | recall@10    | 0.192024 |
# |  3 | map@10       | 0.139692 |
# +----+--------------+----------
# 2021-12-03 13:43:05 [INFO]-
# 2021-12-03 13:43:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:43:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:43:05 [INFO]-performance on testing at epoch 6
# 2021-12-03 13:43:05 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.571733 |
# |  1 | precision@10 | 0.529576 |
# |  2 | recall@10    | 0.190548 |
# |  3 | map@10       | 0.138755 |
# +----+--------------+----------
# 2021-12-03 13:43:05 [INFO]-
# 2021-12-03 13:43:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:43:05 [INFO]-Execute [train_eval_worker] method costing 123272.61 ms
# 2021-12-03 13:44:45 [INFO]-[Training Epoch 7], log_like_loss 32.02825927734375 kl_loss: -1.2573928833007812 alpha: 0.001 lr: 0.001
# 2021-12-03 13:44:45 [INFO]-Execute [train_an_epoch] method costing 222483.26 ms
#  10%|#         | 8/80 [30:59<4:43:34, 236.31s/it]Epoch 8 starts !
# 2021-12-03 13:45:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:47:07 [INFO]-Current testEngine.best_valid_performance 0.5718573664235856
# 2021-12-03 13:47:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:47:07 [INFO]-performance on validation at epoch 7
# 2021-12-03 13:47:07 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.586381 |
# |  1 | precision@10 | 0.543097 |
# |  2 | recall@10    | 0.197445 |
# |  3 | map@10       | 0.145361 |
# +----+--------------+----------
# 2021-12-03 13:47:07 [INFO]-
# 2021-12-03 13:47:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:47:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:47:07 [INFO]-performance on testing at epoch 7
# 2021-12-03 13:47:07 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.587934 |
# |  1 | precision@10 | 0.543621 |
# |  2 | recall@10    | 0.196251 |
# |  3 | map@10       | 0.145012 |
# +----+--------------+----------
# 2021-12-03 13:47:07 [INFO]-
# 2021-12-03 13:47:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:47:07 [INFO]-Execute [train_eval_worker] method costing 122157.69 ms
# 2021-12-03 13:48:47 [INFO]-[Training Epoch 8], log_like_loss 31.863759994506836 kl_loss: -1.259650707244873 alpha: 0.001 lr: 0.001
# 2021-12-03 13:48:47 [INFO]-Execute [train_an_epoch] method costing 219920.53 ms
#  11%|#1        | 9/80 [35:01<4:41:39, 238.02s/it]Epoch 9 starts !
# 2021-12-03 13:49:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:51:10 [INFO]-Current testEngine.best_valid_performance 0.5863812318332422
# 2021-12-03 13:51:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:51:10 [INFO]-performance on validation at epoch 8
# 2021-12-03 13:51:10 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.601322 |
# |  1 | precision@10 | 0.556316 |
# |  2 | recall@10    | 0.203245 |
# |  3 | map@10       | 0.151589 |
# +----+--------------+----------
# 2021-12-03 13:51:10 [INFO]-
# 2021-12-03 13:51:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:51:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:51:10 [INFO]-performance on testing at epoch 8
# 2021-12-03 13:51:10 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.601972 |
# |  1 | precision@10 | 0.556535 |
# |  2 | recall@10    | 0.201809 |
# |  3 | map@10       | 0.150814 |
# +----+--------------+----------
# 2021-12-03 13:51:10 [INFO]-
# 2021-12-03 13:51:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:51:10 [INFO]-Execute [train_eval_worker] method costing 122824.28 ms
# 2021-12-03 13:52:48 [INFO]-[Training Epoch 9], log_like_loss 31.740602493286133 kl_loss: -2.3853728771209717 alpha: 0.001 lr: 0.001
# 2021-12-03 13:52:48 [INFO]-Execute [train_an_epoch] method costing 219589.68 ms
#  12%|#2        | 10/80 [39:03<4:38:55, 239.08s/it]Epoch 10 starts !
# 2021-12-03 13:53:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:55:12 [INFO]-Current testEngine.best_valid_performance 0.6013215470066874
# 2021-12-03 13:55:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:55:12 [INFO]-performance on validation at epoch 9
# 2021-12-03 13:55:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.613527 |
# |  1 | precision@10 | 0.567364 |
# |  2 | recall@10    | 0.20777  |
# |  3 | map@10       | 0.156757 |
# +----+--------------+----------
# 2021-12-03 13:55:12 [INFO]-
# 2021-12-03 13:55:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:55:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:55:12 [INFO]-performance on testing at epoch 9
# 2021-12-03 13:55:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.613001 |
# |  1 | precision@10 | 0.56676  |
# |  2 | recall@10    | 0.206507 |
# |  3 | map@10       | 0.155582 |
# +----+--------------+----------
# 2021-12-03 13:55:12 [INFO]-
# 2021-12-03 13:55:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:55:12 [INFO]-Execute [train_eval_worker] method costing 122889.93 ms
# 2021-12-03 13:56:49 [INFO]-[Training Epoch 10], log_like_loss 31.62272834777832 kl_loss: -3.7162232398986816 alpha: 0.001 lr: 0.001
# 2021-12-03 13:56:49 [INFO]-Execute [train_an_epoch] method costing 218758.82 ms
#  14%|#3        | 11/80 [43:03<4:35:30, 239.58s/it]Epoch 11 starts !
# 2021-12-03 13:57:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:59:13 [INFO]-Current testEngine.best_valid_performance 0.6135272752166379
# 2021-12-03 13:59:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:59:13 [INFO]-performance on validation at epoch 10
# 2021-12-03 13:59:13 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.623883 |
# |  1 | precision@10 | 0.576521 |
# |  2 | recall@10    | 0.211603 |
# |  3 | map@10       | 0.161164 |
# +----+--------------+----------
# 2021-12-03 13:59:13 [INFO]-
# 2021-12-03 13:59:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:59:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:59:13 [INFO]-performance on testing at epoch 10
# 2021-12-03 13:59:13 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.625084 |
# |  1 | precision@10 | 0.577784 |
# |  2 | recall@10    | 0.2104   |
# |  3 | map@10       | 0.160575 |
# +----+--------------+----------
# 2021-12-03 13:59:13 [INFO]-
# 2021-12-03 13:59:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 13:59:13 [INFO]-Execute [train_eval_worker] method costing 123581.26 ms
# 2021-12-03 14:00:48 [INFO]-[Training Epoch 11], log_like_loss 31.498802185058594 kl_loss: -3.729743003845215 alpha: 0.001 lr: 0.001
# 2021-12-03 14:00:48 [INFO]-Execute [train_an_epoch] method costing 216670.47 ms
#  15%|#5        | 12/80 [47:01<4:31:03, 239.17s/it]Epoch 12 starts !
# 2021-12-03 14:01:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:03:14 [INFO]-Current testEngine.best_valid_performance 0.6238828782533822
# 2021-12-03 14:03:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:03:14 [INFO]-performance on validation at epoch 11
# 2021-12-03 14:03:14 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.633376 |
# |  1 | precision@10 | 0.586238 |
# |  2 | recall@10    | 0.215686 |
# |  3 | map@10       | 0.165604 |
# +----+--------------+----------
# 2021-12-03 14:03:14 [INFO]-
# 2021-12-03 14:03:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:03:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:03:14 [INFO]-performance on testing at epoch 11
# 2021-12-03 14:03:14 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.633723 |
# |  1 | precision@10 | 0.586284 |
# |  2 | recall@10    | 0.214501 |
# |  3 | map@10       | 0.164646 |
# +----+--------------+----------
# 2021-12-03 14:03:14 [INFO]-
# 2021-12-03 14:03:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:03:14 [INFO]-Execute [train_eval_worker] method costing 126018.20 ms
# 2021-12-03 14:04:49 [INFO]-[Training Epoch 12], log_like_loss 31.421274185180664 kl_loss: -3.7337496280670166 alpha: 0.001 lr: 0.001
# 2021-12-03 14:04:49 [INFO]-Execute [train_an_epoch] method costing 219505.86 ms
#  16%|#6        | 13/80 [51:02<4:27:32, 239.59s/it]Epoch 13 starts !
# 2021-12-03 14:05:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:07:14 [INFO]-Current testEngine.best_valid_performance 0.6333755067131099
# 2021-12-03 14:07:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:07:14 [INFO]-performance on validation at epoch 12
# 2021-12-03 14:07:14 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.643402 |
# |  1 | precision@10 | 0.595088 |
# |  2 | recall@10    | 0.219518 |
# |  3 | map@10       | 0.170178 |
# +----+--------------+----------
# 2021-12-03 14:07:14 [INFO]-
# 2021-12-03 14:07:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:07:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:07:14 [INFO]-performance on testing at epoch 12
# 2021-12-03 14:07:14 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.643726 |
# |  1 | precision@10 | 0.595645 |
# |  2 | recall@10    | 0.218094 |
# |  3 | map@10       | 0.169085 |
# +----+--------------+----------
# 2021-12-03 14:07:14 [INFO]-
# 2021-12-03 14:07:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:07:14 [INFO]-Execute [train_eval_worker] method costing 125909.97 ms
# 2021-12-03 14:08:48 [INFO]-[Training Epoch 13], log_like_loss 31.325031280517578 kl_loss: -3.741532325744629 alpha: 0.001 lr: 0.001
# 2021-12-03 14:08:48 [INFO]-Execute [train_an_epoch] method costing 218332.61 ms
#  18%|#7        | 14/80 [55:01<4:23:28, 239.53s/it]Epoch 14 starts !
# 2021-12-03 14:09:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:11:17 [INFO]-Current testEngine.best_valid_performance 0.6434016956856997
# 2021-12-03 14:11:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:11:17 [INFO]-performance on validation at epoch 13
# 2021-12-03 14:11:17 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.651287 |
# |  1 | precision@10 | 0.603106 |
# |  2 | recall@10    | 0.223034 |
# |  3 | map@10       | 0.173653 |
# +----+--------------+----------
# 2021-12-03 14:11:17 [INFO]-
# 2021-12-03 14:11:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:11:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:11:17 [INFO]-performance on testing at epoch 13
# 2021-12-03 14:11:17 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.651783 |
# |  1 | precision@10 | 0.603767 |
# |  2 | recall@10    | 0.221312 |
# |  3 | map@10       | 0.172924 |
# +----+--------------+----------
# 2021-12-03 14:11:17 [INFO]-
# 2021-12-03 14:11:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:11:17 [INFO]-Execute [train_eval_worker] method costing 129225.81 ms
# 2021-12-03 14:12:51 [INFO]-[Training Epoch 14], log_like_loss 31.263519287109375 kl_loss: -3.7752561569213867 alpha: 0.001 lr: 0.001
# 2021-12-03 14:12:51 [INFO]-Execute [train_an_epoch] method costing 221571.82 ms
#  19%|#8        | 15/80 [59:03<4:20:18, 240.29s/it]Epoch 15 starts !
# 2021-12-03 14:13:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:15:13 [INFO]-Current testEngine.best_valid_performance 0.6512865060115484
# 2021-12-03 14:15:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:15:13 [INFO]-performance on validation at epoch 14
# 2021-12-03 14:15:13 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.658909 |
# |  1 | precision@10 | 0.609695 |
# |  2 | recall@10    | 0.225712 |
# |  3 | map@10       | 0.177143 |
# +----+--------------+----------
# 2021-12-03 14:15:13 [INFO]-
# 2021-12-03 14:15:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:15:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:15:13 [INFO]-performance on testing at epoch 14
# 2021-12-03 14:15:13 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.659042 |
# |  1 | precision@10 | 0.610306 |
# |  2 | recall@10    | 0.224623 |
# |  3 | map@10       | 0.176227 |
# +----+--------------+----------
# 2021-12-03 14:15:13 [INFO]-
# 2021-12-03 14:15:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:15:13 [INFO]-Execute [train_eval_worker] method costing 123034.66 ms
# 2021-12-03 14:16:47 [INFO]-[Training Epoch 15], log_like_loss 31.195329666137695 kl_loss: -3.84896183013916 alpha: 0.001 lr: 0.001
# 2021-12-03 14:16:47 [INFO]-Execute [train_an_epoch] method costing 215888.95 ms
#  20%|##        | 16/80 [1:03:02<4:15:35, 239.61s/it]Epoch 16 starts !
# 2021-12-03 14:17:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:19:12 [INFO]-Current testEngine.best_valid_performance 0.65890917262954
# 2021-12-03 14:19:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:19:12 [INFO]-performance on validation at epoch 15
# 2021-12-03 14:19:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.665813 |
# |  1 | precision@10 | 0.616449 |
# |  2 | recall@10    | 0.228397 |
# |  3 | map@10       | 0.180475 |
# +----+--------------+----------
# 2021-12-03 14:19:12 [INFO]-
# 2021-12-03 14:19:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:19:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:19:12 [INFO]-performance on testing at epoch 15
# 2021-12-03 14:19:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.665666 |
# |  1 | precision@10 | 0.616506 |
# |  2 | recall@10    | 0.227181 |
# |  3 | map@10       | 0.17928  |
# +----+--------------+----------
# 2021-12-03 14:19:12 [INFO]-
# 2021-12-03 14:19:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:19:12 [INFO]-Execute [train_eval_worker] method costing 123967.56 ms
# 2021-12-03 14:20:48 [INFO]-[Training Epoch 16], log_like_loss 31.09868812561035 kl_loss: -3.9468138217926025 alpha: 0.001 lr: 0.001
# 2021-12-03 14:20:48 [INFO]-Execute [train_an_epoch] method costing 218554.49 ms
#  21%|##1       | 17/80 [1:07:01<4:11:32, 239.56s/it]Epoch 17 starts !
# 2021-12-03 14:21:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:23:11 [INFO]-Current testEngine.best_valid_performance 0.6658127338339993
# 2021-12-03 14:23:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:23:11 [INFO]-performance on validation at epoch 16
# 2021-12-03 14:23:11 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.672666 |
# |  1 | precision@10 | 0.623195 |
# |  2 | recall@10    | 0.231251 |
# |  3 | map@10       | 0.183713 |
# +----+--------------+----------
# 2021-12-03 14:23:11 [INFO]-
# 2021-12-03 14:23:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:23:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:23:11 [INFO]-performance on testing at epoch 16
# 2021-12-03 14:23:11 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.673623 |
# |  1 | precision@10 | 0.624369 |
# |  2 | recall@10    | 0.230606 |
# |  3 | map@10       | 0.183086 |
# +----+--------------+----------
# 2021-12-03 14:23:11 [INFO]-
# 2021-12-03 14:23:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:23:11 [INFO]-Execute [train_eval_worker] method costing 124253.16 ms
# 2021-12-03 14:24:48 [INFO]-[Training Epoch 17], log_like_loss 31.05029296875 kl_loss: -4.1305623054504395 alpha: 0.001 lr: 0.001
# 2021-12-03 14:24:49 [INFO]-Execute [train_an_epoch] method costing 219757.65 ms
#  22%|##2       | 18/80 [1:11:01<4:07:50, 239.84s/it]Epoch 18 starts !
# 2021-12-03 14:25:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:27:12 [INFO]-Current testEngine.best_valid_performance 0.6726660154506416
# 2021-12-03 14:27:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:27:12 [INFO]-performance on validation at epoch 17
# 2021-12-03 14:27:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.678946 |
# |  1 | precision@10 | 0.629197 |
# |  2 | recall@10    | 0.234001 |
# |  3 | map@10       | 0.186702 |
# +----+--------------+----------
# 2021-12-03 14:27:12 [INFO]-
# 2021-12-03 14:27:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:27:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:27:12 [INFO]-performance on testing at epoch 17
# 2021-12-03 14:27:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.679644 |
# |  1 | precision@10 | 0.629879 |
# |  2 | recall@10    | 0.232697 |
# |  3 | map@10       | 0.185874 |
# +----+--------------+----------
# 2021-12-03 14:27:12 [INFO]-
# 2021-12-03 14:27:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:27:12 [INFO]-Execute [train_eval_worker] method costing 124209.93 ms
# 2021-12-03 14:28:50 [INFO]-[Training Epoch 18], log_like_loss 31.013734817504883 kl_loss: -4.286284446716309 alpha: 0.001 lr: 0.001
# 2021-12-03 14:28:51 [INFO]-Execute [train_an_epoch] method costing 221107.21 ms
#  24%|##3       | 19/80 [1:15:04<4:04:32, 240.54s/it]Epoch 19 starts !
# 2021-12-03 14:29:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:31:12 [INFO]-Current testEngine.best_valid_performance 0.6789456308306431
# 2021-12-03 14:31:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:31:12 [INFO]-performance on validation at epoch 18
# 2021-12-03 14:31:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.684053 |
# |  1 | precision@10 | 0.634091 |
# |  2 | recall@10    | 0.236048 |
# |  3 | map@10       | 0.189284 |
# +----+--------------+----------
# 2021-12-03 14:31:12 [INFO]-
# 2021-12-03 14:31:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:31:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:31:12 [INFO]-performance on testing at epoch 18
# 2021-12-03 14:31:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.685732 |
# |  1 | precision@10 | 0.635411 |
# |  2 | recall@10    | 0.23522  |
# |  3 | map@10       | 0.188647 |
# +----+--------------+----------
# 2021-12-03 14:31:12 [INFO]-
# 2021-12-03 14:31:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:31:12 [INFO]-Execute [train_eval_worker] method costing 122567.35 ms
# 2021-12-03 14:32:50 [INFO]-[Training Epoch 19], log_like_loss 30.938045501708984 kl_loss: -4.475286960601807 alpha: 0.001 lr: 0.001
# 2021-12-03 14:32:50 [INFO]-Execute [train_an_epoch] method costing 218663.80 ms
#  25%|##5       | 20/80 [1:19:03<4:00:14, 240.24s/it]Epoch 20 starts !
# 2021-12-03 14:33:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:35:14 [INFO]-Current testEngine.best_valid_performance 0.6840534857455721
# 2021-12-03 14:35:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:35:14 [INFO]-performance on validation at epoch 19
# 2021-12-03 14:35:14 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.689416 |
# |  1 | precision@10 | 0.639368 |
# |  2 | recall@10    | 0.238343 |
# |  3 | map@10       | 0.191735 |
# +----+--------------+----------
# 2021-12-03 14:35:14 [INFO]-
# 2021-12-03 14:35:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:35:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:35:14 [INFO]-performance on testing at epoch 19
# 2021-12-03 14:35:14 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.691285 |
# |  1 | precision@10 | 0.641076 |
# |  2 | recall@10    | 0.237584 |
# |  3 | map@10       | 0.191376 |
# +----+--------------+----------
# 2021-12-03 14:35:14 [INFO]-
# 2021-12-03 14:35:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:35:14 [INFO]-Execute [train_eval_worker] method costing 124595.63 ms
# 2021-12-03 14:36:53 [INFO]-[Training Epoch 20], log_like_loss 30.86619758605957 kl_loss: -4.618403911590576 alpha: 0.001 lr: 0.001
# 2021-12-03 14:36:53 [INFO]-Execute [train_an_epoch] method costing 222188.92 ms
#  26%|##6       | 21/80 [1:23:06<3:57:04, 241.09s/it]Epoch 21 starts !
# 2021-12-03 14:37:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:39:18 [INFO]-Current testEngine.best_valid_performance 0.6894155640088475
# 2021-12-03 14:39:18 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:39:18 [INFO]-performance on validation at epoch 20
# 2021-12-03 14:39:18 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.695365 |
# |  1 | precision@10 | 0.644676 |
# |  2 | recall@10    | 0.240348 |
# |  3 | map@10       | 0.194758 |
# +----+--------------+----------
# 2021-12-03 14:39:18 [INFO]-
# 2021-12-03 14:39:18 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:39:18 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:39:18 [INFO]-performance on testing at epoch 20
# 2021-12-03 14:39:18 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.696114 |
# |  1 | precision@10 | 0.646274 |
# |  2 | recall@10    | 0.239744 |
# |  3 | map@10       | 0.193902 |
# +----+--------------+----------
# 2021-12-03 14:39:18 [INFO]-
# 2021-12-03 14:39:18 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:39:18 [INFO]-Execute [train_eval_worker] method costing 125607.31 ms
# 2021-12-03 14:40:57 [INFO]-[Training Epoch 21], log_like_loss 30.809368133544922 kl_loss: -4.748280048370361 alpha: 0.001 lr: 0.001
# 2021-12-03 14:40:57 [INFO]-Execute [train_an_epoch] method costing 222750.87 ms
#  28%|##7       | 22/80 [1:27:10<3:53:51, 241.92s/it]Epoch 22 starts !
# 2021-12-03 14:41:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:43:23 [INFO]-Current testEngine.best_valid_performance 0.6953653430688157
# 2021-12-03 14:43:23 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:43:23 [INFO]-performance on validation at epoch 21
# 2021-12-03 14:43:23 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.700076 |
# |  1 | precision@10 | 0.649357 |
# |  2 | recall@10    | 0.242557 |
# |  3 | map@10       | 0.197108 |
# +----+--------------+----------
# 2021-12-03 14:43:23 [INFO]-
# 2021-12-03 14:43:23 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:43:23 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 14:43:23 [INFO]-performance on testing at epoch 21
# 2021-12-03 14:43:23 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.701365 |
# |  1 | precision@10 | 0.651039 |
# |  2 | recall@10    | 0.241708 |
# |  3 | map@10       | 0.196204 |
# +----+--------------+----------
# 2021-12-03 14:43:23 [INFO]-
# 2021-12-03 14:43:23 [INFO]---------------------------------------------------------------------------------
# ...
#  52%|#####2    | 42/80 [2:47:59<2:32:55, 241.45s/it]Epoch 42 starts !
# 2021-12-03 16:02:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:04:10 [INFO]-Current testEngine.best_valid_performance 0.7525277979799468
# 2021-12-03 16:04:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:04:10 [INFO]-performance on validation at epoch 41
# 2021-12-03 16:04:10 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.753964 |
# |  1 | precision@10 | 0.702202 |
# |  2 | recall@10    | 0.265667 |
# |  3 | map@10       | 0.225271 |
# +----+--------------+----------
# 2021-12-03 16:04:10 [INFO]-
# 2021-12-03 16:04:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:04:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:04:10 [INFO]-performance on testing at epoch 41
# 2021-12-03 16:04:10 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.755735 |
# |  1 | precision@10 | 0.704293 |
# |  2 | recall@10    | 0.265012 |
# |  3 | map@10       | 0.224695 |
# +----+--------------+----------
# 2021-12-03 16:04:10 [INFO]-
# 2021-12-03 16:04:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:04:10 [INFO]-Execute [train_eval_worker] method costing 125353.12 ms
# 2021-12-03 16:05:52 [INFO]-[Training Epoch 42], log_like_loss 30.143516540527344 kl_loss: -5.9425048828125 alpha: 0.001 lr: 0.001
# 2021-12-03 16:05:52 [INFO]-Execute [train_an_epoch] method costing 225752.13 ms
#  54%|#####3    | 43/80 [2:52:05<2:29:44, 242.84s/it]Epoch 43 starts !
# 2021-12-03 16:06:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:08:17 [INFO]-Current testEngine.best_valid_performance 0.7539641519230337
# 2021-12-03 16:08:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:08:17 [INFO]-performance on validation at epoch 42
# 2021-12-03 16:08:17 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.754922 |
# |  1 | precision@10 | 0.703208 |
# |  2 | recall@10    | 0.266125 |
# |  3 | map@10       | 0.225931 |
# +----+--------------+----------
# 2021-12-03 16:08:17 [INFO]-
# 2021-12-03 16:08:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:08:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:08:17 [INFO]-performance on testing at epoch 42
# 2021-12-03 16:08:17 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.756652 |
# |  1 | precision@10 | 0.705202 |
# |  2 | recall@10    | 0.26544  |
# |  3 | map@10       | 0.225255 |
# +----+--------------+----------
# 2021-12-03 16:08:17 [INFO]-
# 2021-12-03 16:08:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:08:17 [INFO]-Execute [train_eval_worker] method costing 125755.62 ms
# 2021-12-03 16:09:57 [INFO]-[Training Epoch 43], log_like_loss 30.1285343170166 kl_loss: -5.9543232917785645 alpha: 0.001 lr: 0.001
# 2021-12-03 16:09:58 [INFO]-Execute [train_an_epoch] method costing 225088.23 ms
#  55%|#####5    | 44/80 [2:56:11<2:26:16, 243.80s/it]Epoch 44 starts !
# 2021-12-03 16:10:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:12:22 [INFO]-Current testEngine.best_valid_performance 0.7549216044283976
# 2021-12-03 16:12:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:12:22 [INFO]-performance on validation at epoch 43
# 2021-12-03 16:12:22 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.757074 |
# |  1 | precision@10 | 0.705281 |
# |  2 | recall@10    | 0.26688  |
# |  3 | map@10       | 0.22707  |
# +----+--------------+----------
# 2021-12-03 16:12:22 [INFO]-
# 2021-12-03 16:12:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:12:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:12:22 [INFO]-performance on testing at epoch 43
# 2021-12-03 16:12:22 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.758458 |
# |  1 | precision@10 | 0.707252 |
# |  2 | recall@10    | 0.266199 |
# |  3 | map@10       | 0.22623  |
# +----+--------------+----------
# 2021-12-03 16:12:22 [INFO]-
# 2021-12-03 16:12:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:12:22 [INFO]-Execute [train_eval_worker] method costing 125510.62 ms
# 2021-12-03 16:14:04 [INFO]-[Training Epoch 44], log_like_loss 30.114961624145508 kl_loss: -6.019159317016602 alpha: 0.001 lr: 0.001
# 2021-12-03 16:14:04 [INFO]-Execute [train_an_epoch] method costing 225875.30 ms
#  56%|#####6    | 45/80 [3:00:17<2:22:44, 244.69s/it]Epoch 45 starts !
# 2021-12-03 16:14:24 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:16:28 [INFO]-Current testEngine.best_valid_performance 0.757074130440635
# 2021-12-03 16:16:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:16:28 [INFO]-performance on validation at epoch 44
# 2021-12-03 16:16:28 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.757953 |
# |  1 | precision@10 | 0.706305 |
# |  2 | recall@10    | 0.267246 |
# |  3 | map@10       | 0.227494 |
# +----+--------------+----------
# 2021-12-03 16:16:28 [INFO]-
# 2021-12-03 16:16:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:16:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:16:28 [INFO]-performance on testing at epoch 44
# 2021-12-03 16:16:28 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.759265 |
# |  1 | precision@10 | 0.707703 |
# |  2 | recall@10    | 0.266555 |
# |  3 | map@10       | 0.226766 |
# +----+--------------+----------
# 2021-12-03 16:16:28 [INFO]-
# 2021-12-03 16:16:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:16:28 [INFO]-Execute [train_eval_worker] method costing 124708.39 ms
# 2021-12-03 16:18:10 [INFO]-[Training Epoch 45], log_like_loss 30.094589233398438 kl_loss: -6.063826560974121 alpha: 0.001 lr: 0.001
# 2021-12-03 16:18:10 [INFO]-Execute [train_an_epoch] method costing 224692.62 ms
#  57%|#####7    | 46/80 [3:04:24<2:19:00, 245.31s/it]Epoch 46 starts !
# 2021-12-03 16:18:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:20:33 [INFO]-Current testEngine.best_valid_performance 0.7579526520707447
# 2021-12-03 16:20:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:20:33 [INFO]-performance on validation at epoch 45
# 2021-12-03 16:20:33 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.759617 |
# |  1 | precision@10 | 0.707875 |
# |  2 | recall@10    | 0.267949 |
# |  3 | map@10       | 0.228513 |
# +----+--------------+----------
# 2021-12-03 16:20:33 [INFO]-
# 2021-12-03 16:20:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:20:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:20:33 [INFO]-performance on testing at epoch 45
# 2021-12-03 16:20:33 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.760919 |
# |  1 | precision@10 | 0.709566 |
# |  2 | recall@10    | 0.267301 |
# |  3 | map@10       | 0.227577 |
# +----+--------------+----------
# 2021-12-03 16:20:33 [INFO]-
# 2021-12-03 16:20:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:20:33 [INFO]-Execute [train_eval_worker] method costing 122940.06 ms
# 2021-12-03 16:22:17 [INFO]-[Training Epoch 46], log_like_loss 30.08589744567871 kl_loss: -6.064965724945068 alpha: 0.001 lr: 0.001
# 2021-12-03 16:22:17 [INFO]-Execute [train_an_epoch] method costing 224676.61 ms
#  59%|#####8    | 47/80 [3:08:31<2:15:10, 245.77s/it]Epoch 47 starts !
# 2021-12-03 16:22:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:24:42 [INFO]-Current testEngine.best_valid_performance 0.7596171922740566
# 2021-12-03 16:24:42 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:24:42 [INFO]-performance on validation at epoch 46
# 2021-12-03 16:24:42 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.76078  |
# |  1 | precision@10 | 0.708792 |
# |  2 | recall@10    | 0.26845  |
# |  3 | map@10       | 0.229164 |
# +----+--------------+----------
# 2021-12-03 16:24:42 [INFO]-
# 2021-12-03 16:24:42 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:24:42 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:24:42 [INFO]-performance on testing at epoch 46
# 2021-12-03 16:24:42 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.762324 |
# |  1 | precision@10 | 0.71105  |
# |  2 | recall@10    | 0.268228 |
# |  3 | map@10       | 0.22845  |
# +----+--------------+----------
# 2021-12-03 16:24:42 [INFO]-
# 2021-12-03 16:24:42 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:24:42 [INFO]-Execute [train_eval_worker] method costing 124760.31 ms
# 2021-12-03 16:26:23 [INFO]-[Training Epoch 47], log_like_loss 30.078819274902344 kl_loss: -6.101595401763916 alpha: 0.001 lr: 0.001
# 2021-12-03 16:26:23 [INFO]-Execute [train_an_epoch] method costing 224325.62 ms
#  60%|######    | 48/80 [3:12:36<2:11:00, 245.65s/it]Epoch 48 starts !
# 2021-12-03 16:26:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:28:49 [INFO]-Current testEngine.best_valid_performance 0.760780279726545
# 2021-12-03 16:28:49 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:28:49 [INFO]-performance on validation at epoch 47
# 2021-12-03 16:28:49 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.761559 |
# |  1 | precision@10 | 0.709628 |
# |  2 | recall@10    | 0.268801 |
# |  3 | map@10       | 0.229583 |
# +----+--------------+----------
# 2021-12-03 16:28:49 [INFO]-
# 2021-12-03 16:28:49 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:28:49 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:28:49 [INFO]-performance on testing at epoch 47
# 2021-12-03 16:28:49 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.762944 |
# |  1 | precision@10 | 0.711104 |
# |  2 | recall@10    | 0.268165 |
# |  3 | map@10       | 0.228878 |
# +----+--------------+----------
# 2021-12-03 16:28:49 [INFO]-
# 2021-12-03 16:28:49 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:28:49 [INFO]-Execute [train_eval_worker] method costing 125917.29 ms
# 2021-12-03 16:30:30 [INFO]-[Training Epoch 48], log_like_loss 30.045438766479492 kl_loss: -6.164002418518066 alpha: 0.001 lr: 0.001
# 2021-12-03 16:30:30 [INFO]-Execute [train_an_epoch] method costing 225859.12 ms
#  61%|######1   | 49/80 [3:16:43<2:07:07, 246.06s/it]Epoch 49 starts !
# 2021-12-03 16:30:50 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:32:58 [INFO]-Current testEngine.best_valid_performance 0.7615591948255651
# 2021-12-03 16:32:58 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:32:58 [INFO]-performance on validation at epoch 48
# 2021-12-03 16:32:58 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.763348 |
# |  1 | precision@10 | 0.711368 |
# |  2 | recall@10    | 0.269498 |
# |  3 | map@10       | 0.230497 |
# +----+--------------+----------
# 2021-12-03 16:32:58 [INFO]-
# 2021-12-03 16:32:58 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:32:58 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:32:58 [INFO]-performance on testing at epoch 48
# 2021-12-03 16:32:58 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.764007 |
# |  1 | precision@10 | 0.712677 |
# |  2 | recall@10    | 0.268918 |
# |  3 | map@10       | 0.229524 |
# +----+--------------+----------
# 2021-12-03 16:32:58 [INFO]-
# 2021-12-03 16:32:58 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:32:58 [INFO]-Execute [train_eval_worker] method costing 128424.14 ms
# 2021-12-03 16:34:37 [INFO]-[Training Epoch 49], log_like_loss 30.032978057861328 kl_loss: -6.201941967010498 alpha: 0.001 lr: 0.001
# 2021-12-03 16:34:38 [INFO]-Execute [train_an_epoch] method costing 226273.13 ms
#  62%|######2   | 50/80 [3:20:51<2:03:11, 246.38s/it]Epoch 50 starts !
# 2021-12-03 16:34:57 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:37:00 [INFO]-Current testEngine.best_valid_performance 0.76334762532034
# 2021-12-03 16:37:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:37:00 [INFO]-performance on validation at epoch 49
# 2021-12-03 16:37:00 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.763756 |
# |  1 | precision@10 | 0.711947 |
# |  2 | recall@10    | 0.26971  |
# |  3 | map@10       | 0.230723 |
# +----+--------------+----------
# 2021-12-03 16:37:00 [INFO]-
# 2021-12-03 16:37:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:37:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:37:00 [INFO]-performance on testing at epoch 49
# 2021-12-03 16:37:00 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.764378 |
# |  1 | precision@10 | 0.712962 |
# |  2 | recall@10    | 0.269047 |
# |  3 | map@10       | 0.229742 |
# +----+--------------+----------
# 2021-12-03 16:37:00 [INFO]-
# 2021-12-03 16:37:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-03 16:37:00 [INFO]-Execute [train_eval_worker] method costing 122743.83 ms
# 2021-12-03 16:38:39 [INFO]-[Training Epoch 50], log_like_loss 30.018774032592773 kl_loss: -6.232687473297119 alpha: 0.001 lr: 0.001
# 2021-12-03 16:38:39 [INFO]-Execute [train_an_epoch] method costing 221041.84 ms
#  64%|######3   | 51/80 [3:24:52<1:58:25, 245.01s/it]Epoch 51 starts !
# 2021-12-03 16:38:59 [INFO]---------------------------------------------------------------------------------
