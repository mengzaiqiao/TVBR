# %% [markdown]
# ### Install Beta-recsys

# %% [markdown]
# ## Loading dataset

# %%
import sys

sys.path.append("../")

import random

import numpy as np

from beta_rec.data.grocery_data import GroceryData
from beta_rec.datasets.instacart import Instacart_25

seed = 2021
random.seed(seed)  # Fix random seeds for reproducibility
np.random.seed(seed)

# make sure that you have already download the Instacart data from this link: https://www.kaggle.com/c/instacart-market-basket-analysis#
# uncompressed them and put them in this folder: ../datasets/instacart_25/raw/*.csv


dataset = Instacart_25(
    min_u_c=20, min_i_c=30, min_o_c=10
)  # Specifying the filtering conditions.

# Split the data
split_dataset = dataset.load_temporal_basket_split(test_rate=0.2, n_test=10)
data = GroceryData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 3857794    | 3857794    | 3857794      | 3857794         | 3857794     |
# | nunique | 23093      | 14565      | 1            | 3857794         | 373719      |
# +---------+------------+------------+--------------+-----------------+-------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table
# Execute [__init__] method costing 98826.21 ms
# Execute [__init__] method costing 0.00 ms

# %% [markdown]
# ### Model config

# %%
config = {"config_file": "../configs/tvbr_default.json"}
config["n_sample"] = 5000000  # To reduce the test running time
config["max_epoch"] = 80
config["emb_dim"] = 64
config["time_step"] = 50
config["batch_size"] = 10000
# config["tunable"] = [
#     {"name": "lr", "type": "choice", "values": [0.5, 0.05, 0.025, 0.001, 0.005]},
# ]
# config["tune"] = True
# the 'config_file' key is required, that is used load a default config.
# Other keys can be specified to replace the default settings.

# %% [markdown]
# ### Model intialization and training

# %%
from beta_rec.recommenders import TVBR

for item_fea_type in [
#     "random",
#     "cate",
#     "cate_word2vec",
#     "cate_bert",
#     "cate_one_hot",
#     "random_word2vec",
#     "random_bert",
    "random_one_hot",
    "random_bert_word2vec_one_hot",
    "random_cate_word2vec",
    "random_cate_bert",
    "random_cate_one_hot",
    "random_cate_bert_word2vec_one_hot",
]:
    config["item_fea_type"] = item_fea_type
    lr = 0.001
    time_step = 20
    config["lr"] = lr
    config["time_step"] = time_step
    config["root_dir"] = "/home/zm324/workspace/beta-recsys/"
    config["dataset"] = "instacart_25"
    model = TVBR(config)
    model.train(data)
    model.test(data.test)
    # @To be discussed
# model.train(train_df)
# Case 1, without validation, stop training by loss or max_epoch

# model.train(train_df,valid_df[0])
# Case 2, with validation, stop training by performance on validation set

# model.train(train_df,valid_df[0],test_df[0])
# Case 3, same as Case 2, but also evaluate performance for each epoch on test set.

# Note that the best model will be save automatically, and record the model-save-dir.
# Out:
# Search default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# Found default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# loading config file /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +----+-----------------------+------------------------------------+
# |    | keys                  | values                             |
# |----+-----------------------+------------------------------------|
# |  0 | system:root_dir       | /home/zm324/workspace/beta-recsys/ |
# |  1 | model:n_sample        | 5000000                            |
# |  2 | model:max_epoch       | 80                                 |
# |  3 | model:emb_dim         | 64                                 |
# |  4 | model:time_step       | 20                                 |
# |  5 | model:batch_size      | 10000                              |
# |  6 | model:lr              | 0.001                              |
# |  7 | dataset:item_fea_type | random_one_hot                     |
# |  8 | dataset:dataset       | instacart_25                       |
# +----+-----------------------+------------------------------------+
# --------------------------------------------------------------------------------
# logs will save in file: /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211210_202428_murihu .stdout.log .stderr.log
# 2021-12-10 20:24:28 [INFO]-
# Python version: 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0
# 2021-12-10 20:24:28 [INFO]-
# 2021-12-10 20:24:28 [INFO]-Pytorch version: 1.7.1
# 2021-12-10 20:24:28 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211210_202428_murihu
# 2021-12-10 20:24:28 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211210_202428_murihu
# 2021-12-10 20:24:28 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/tvbr_result.csv
# 2021-12-10 20:24:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:24:28 [INFO]-System configs
# 2021-12-10 20:24:28 [INFO]-
# +----+----------------+-----------------------------------------------------------------------------------+
# |    | keys           | values                                                                            |
# |----+----------------+-----------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                 |
# |  1 | log_dir        | logs/                                                                             |
# |  2 | result_dir     | results/                                                                          |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                      |
# |  4 | checkpoint_dir | checkpoints/                                                                      |
# |  5 | dataset_dir    | datasets/                                                                         |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211210_202428_murihu        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                   |
# |  8 | device         | gpu                                                                               |
# |  9 | seed           | 2020                                                                              |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                            |
# | 11 | k              | [5, 10, 20]                                                                       |
# | 12 | valid_metric   | ndcg                                                                              |
# | 13 | valid_k        | 10                                                                                |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/tvbr_result.csv                         |
# | 15 | save_mode      | average                                                                           |
# | 16 | model_run_id   | TVBR_default_20211210_202428_murihu                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211210_202428_murihu        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211210_202428_murihu |
# +----+----------------+-----------------------------------------------------------------------------------
# 2021-12-10 20:24:28 [INFO]-
# 2021-12-10 20:24:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:24:28 [ERROR]-Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# 2021-12-10 20:24:28 [ERROR]-wandb: Currently logged in as: mengzaiqiao (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/mengzaiqiao/TVBR/runs/ibt3t1cj" target="_blank">eternal-shape-52</a></strong> to <a href="https://wandb.ai/mengzaiqiao/TVBR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 2021-12-10 20:24:29 [INFO]-Get a gpu with the most available memory : 2
# 2021-12-10 20:24:29 [INFO]-Initializing test engine ...
# 2021-12-10 20:24:29 [INFO]-Get a gpu with the most available memory : 2
# 2021-12-10 20:24:29 [INFO]-load basic item featrue for dataset: instacart_25  type: one_hot
# 2021-12-10 20:24:37 [INFO]-Setting device for torch_engine cuda:2
# 2021-12-10 20:24:37 [INFO]-
# TVBR(
#   (user_emb): Embedding(23093, 64)
#   (item_emb): Embedding(14565, 64)
#   (time_embdding): Embedding(21, 21)
#   (user_mean): Embedding(23093, 64)
#   (user_std): Embedding(23093, 64)
#   (item_mean): Embedding(14565, 64)
#   (item_std): Embedding(14565, 64)
#   (time2mean_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2mean_i): Sequential(
#     (0): Linear(in_features=761, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_i): Sequential(
#     (0): Linear(in_features=761, out_features=64, bias=True)
#     (1): Tanh()
#   )
#
# 2021-12-10 20:24:37 [INFO]-
# 2021-12-10 20:24:39 [INFO]-Initialize Sampler!
# 2021-12-10 20:24:39 [INFO]-preparing training triples ...
# 2021-12-10 20:24:40 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:40 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:41 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:41 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:41 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 100%|##########| 20/20 [09:51<00:00, 29.59s/it]
#   0%|          | 0/80 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-12-10 20:35:39 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:46:24 [INFO]-[Training Epoch 0], log_like_loss 1.9465770721435547 kl_loss: -0.13789667189121246 alpha: 0.001 lr: 0.001
# 2021-12-10 20:46:24 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:46:24 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:46:24 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:46:24 [INFO]-Execute [train_an_epoch] method costing 644939.78 ms
#   1%|1         | 1/80 [10:44<14:09:10, 644.95s/it]Epoch 1 starts !
# 2021-12-10 20:46:24 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:57:15 [INFO]-[Training Epoch 1], log_like_loss 1.8373390436172485 kl_loss: -0.3782039284706116 alpha: 0.001 lr: 0.001
# 2021-12-10 20:57:15 [INFO]-Execute [train_an_epoch] method costing 650682.89 ms
#   2%|2         | 2/80 [21:35<14:00:41, 646.68s/it]Epoch 2 starts !
# 2021-12-10 20:57:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21
01 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:09:36 [INFO]-[Training Epoch 37], log_like_loss 1.6472398042678833 kl_loss: -1.1774418354034424 alpha: 0.001 lr: 0.001
# 2021-12-11 03:09:36 [INFO]-Execute [train_an_epoch] method costing 574824.51 ms
#  48%|####7     | 38/80 [6:33:56<6:47:52, 582.68s/it]Epoch 38 starts !
# 2021-12-11 03:09:36 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:19:15 [INFO]-[Training Epoch 38], log_like_loss 1.6466089487075806 kl_loss: -1.1793524026870728 alpha: 0.001 lr: 0.001
# 2021-12-11 03:19:15 [INFO]-Execute [train_an_epoch] method costing 579422.06 ms
#  49%|####8     | 39/80 [6:43:36<6:37:30, 581.73s/it]Epoch 39 starts !
# 2021-12-11 03:19:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:28:53 [INFO]-[Training Epoch 39], log_like_loss 1.645998239517212 kl_loss: -1.1819005012512207 alpha: 0.001 lr: 0.001
# 2021-12-11 03:28:53 [INFO]-Execute [train_an_epoch] method costing 578078.38 ms
#  50%|#####     | 40/80 [6:53:14<6:27:06, 580.65s/it]Epoch 40 starts !
# 2021-12-11 03:28:53 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:38:31 [INFO]-[Training Epoch 40], log_like_loss 1.6452906131744385 kl_loss: -1.1829248666763306 alpha: 0.001 lr: 0.001
# 2021-12-11 03:38:31 [INFO]-Execute [train_an_epoch] method costing 577640.58 ms
#  51%|#####1    | 41/80 [7:02:53<6:17:14, 580.38s/it]Epoch 41 starts !
# 2021-12-11 03:38:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:39:56 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:39:56 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:39:56 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:39:56 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:39:56 [INFO]-Current testEngine.best_valid_performance 0
# 2021-12-11 03:39:56 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:39:57 [INFO]-performance on validation at epoch 40
# 2021-12-11 03:39:57 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.810502 |
# |  1 | precision@10 | 0.761419 |
# |  2 | recall@10    | 0.294562 |
# |  3 | map@10       | 0.258716 |
# +----+--------------+----------
# 2021-12-11 03:39:57 [INFO]-
# 2021-12-11 03:39:57 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:39:57 [INFO]-Execute [train_eval_worker] method costing 83307.63 ms
# 2021-12-11 03:49:22 [INFO]-[Training Epoch 41], log_like_loss 1.6445417404174805 kl_loss: -1.186746597290039 alpha: 0.001 lr: 0.001
# 2021-12-11 03:49:22 [INFO]-Execute [train_an_epoch] method costing 648342.82 ms
#  52%|#####2    | 42/80 [7:13:44<6:20:49, 601.31s/it]Epoch 42 starts !
# 2021-12-11 03:49:23 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:50:46 [INFO]-Current testEngine.best_valid_performance 0.8105018034211194
# 2021-12-11 03:50:46 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:50:46 [INFO]-performance on validation at epoch 41
# 2021-12-11 03:50:46 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.811149 |
# |  1 | precision@10 | 0.76218  |
# |  2 | recall@10    | 0.295062 |
# |  3 | map@10       | 0.259193 |
# +----+--------------+----------
# 2021-12-11 03:50:46 [INFO]-
# 2021-12-11 03:50:46 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:50:46 [INFO]-Execute [train_eval_worker] method costing 82920.56 ms
# 2021-12-11 04:00:42 [INFO]-[Training Epoch 42], log_like_loss 1.6439554691314697 kl_loss: -1.1887781620025635 alpha: 0.001 lr: 0.001
# 2021-12-11 04:00:43 [INFO]-Execute [train_an_epoch] method costing 678416.80 ms
#  54%|#####3    | 43/80 [7:25:05<6:25:32, 625.20s/it]Epoch 43 starts !
# 2021-12-11 04:00:44 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:02:41 [INFO]-Current testEngine.best_valid_performance 0.8111485482749121
# 2021-12-11 04:02:41 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:02:41 [INFO]-performance on validation at epoch 42
# 2021-12-11 04:02:41 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.812038 |
# |  1 | precision@10 | 0.762874 |
# |  2 | recall@10    | 0.295393 |
# |  3 | map@10       | 0.259743 |
# +----+--------------+----------
# 2021-12-11 04:02:41 [INFO]-
# 2021-12-11 04:02:41 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:02:41 [INFO]-Execute [train_eval_worker] method costing 116260.06 ms
# 2021-12-11 04:14:10 [INFO]-[Training Epoch 43], log_like_loss 1.6437435150146484 kl_loss: -1.1905194520950317 alpha: 0.001 lr: 0.001
# 2021-12-11 04:14:11 [INFO]-Execute [train_an_epoch] method costing 804170.31 ms
#  55%|#####5    | 44/80 [7:38:33<6:48:04, 680.12s/it]Epoch 44 starts !
# 2021-12-11 04:14:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:16:10 [INFO]-Current testEngine.best_valid_performance 0.812037914057828
# 2021-12-11 04:16:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:16:10 [INFO]-performance on validation at epoch 43
# 2021-12-11 04:16:10 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.813044 |
# |  1 | precision@10 | 0.763786 |
# |  2 | recall@10    | 0.295749 |
# |  3 | map@10       | 0.260377 |
# +----+--------------+----------
# 2021-12-11 04:16:10 [INFO]-
# 2021-12-11 04:16:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:16:10 [INFO]-Execute [train_eval_worker] method costing 117566.43 ms
# 2021-12-11 04:27:43 [INFO]-[Training Epoch 44], log_like_loss 1.6431188583374023 kl_loss: -1.1933094263076782 alpha: 0.001 lr: 0.001
# 2021-12-11 04:27:44 [INFO]-Execute [train_an_epoch] method costing 808849.45 ms
#  56%|#####6    | 45/80 [7:52:06<6:59:58, 719.96s/it]Epoch 45 starts !
# 2021-12-11 04:27:46 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:30:00 [INFO]-Current testEngine.best_valid_performance 0.8130441908377258
# 2021-12-11 04:30:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:30:00 [INFO]-performance on validation at epoch 44
# 2021-12-11 04:30:00 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.813609 |
# |  1 | precision@10 | 0.764458 |
# |  2 | recall@10    | 0.295985 |
# |  3 | map@10       | 0.260694 |
# +----+--------------+----------
# 2021-12-11 04:30:00 [INFO]-
# 2021-12-11 04:30:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:30:00 [INFO]-Execute [train_eval_worker] method costing 134420.62 ms
# 2021-12-11 04:41:20 [INFO]-[Training Epoch 45], log_like_loss 1.6431307792663574 kl_loss: -1.1940094232559204 alpha: 0.001 lr: 0.001
# 2021-12-11 04:41:20 [INFO]-Execute [train_an_epoch] method costing 811915.06 ms
#  57%|#####7    | 46/80 [8:05:42<7:04:18, 748.78s/it]Epoch 46 starts !
# 2021-12-11 04:41:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:43:14 [INFO]-Current testEngine.best_valid_performance 0.8136093608082636
# 2021-12-11 04:43:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:43:14 [INFO]-performance on validation at epoch 45
# 2021-12-11 04:43:14 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.814526 |
# |  1 | precision@10 | 0.765442 |
# |  2 | recall@10    | 0.2965   |
# |  3 | map@10       | 0.261286 |
# +----+--------------+----------
# 2021-12-11 04:43:14 [INFO]-
# 2021-12-11 04:43:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:43:14 [INFO]-Execute [train_eval_worker] method costing 112914.53 ms
# 2021-12-11 04:54:48 [INFO]-[Training Epoch 46], log_like_loss 1.6417921781539917 kl_loss: -1.1967874765396118 alpha: 0.001 lr: 0.001
# 2021-12-11 04:54:48 [INFO]-Execute [train_an_epoch] method costing 806191.32 ms
#  59%|#####8    | 47/80 [8:19:10<7:01:37, 766.59s/it]Epoch 47 starts !
# 2021-12-11 04:54:50 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:57:01 [INFO]-Current testEngine.best_valid_performance 0.8145258921945681
# 2021-12-11 04:57:01 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:57:01 [INFO]-performance on validation at epoch 46
# 2021-12-11 04:57:01 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.814973 |
# |  1 | precision@10 | 0.765931 |
# |  2 | recall@10    | 0.296674 |
# |  3 | map@10       | 0.261553 |
# +----+--------------+----------
# 2021-12-11 04:57:01 [INFO]-
# 2021-12-11 04:57:01 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:57:01 [INFO]-Execute [train_eval_worker] method costing 130917.98 ms
# 2021-12-11 05:08:28 [INFO]-[Training Epoch 47], log_like_loss 1.641513466835022 kl_loss: -1.1975891590118408 alpha: 0.001 lr: 0.001
# 2021-12-11 05:08:28 [INFO]-Execute [train_an_epoch] method costing 816485.58 ms
#  60%|######    | 48/80 [8:32:50<6:57:28, 782.76s/it]Epoch 48 starts !
# 2021-12-11 05:08:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:10:16 [INFO]-Current testEngine.best_valid_performance 0.8149726372449033
# 2021-12-11 05:10:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:10:16 [INFO]-performance on validation at epoch 47
# 2021-12-11 05:10:16 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.815669 |
# |  1 | precision@10 | 0.76667  |
# |  2 | recall@10    | 0.296971 |
# |  3 | map@10       | 0.26191  |
# +----+--------------+----------
# 2021-12-11 05:10:16 [INFO]-
# 2021-12-11 05:10:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:10:16 [INFO]-Execute [train_eval_worker] method costing 105647.43 ms
# 2021-12-11 05:21:35 [INFO]-[Training Epoch 48], log_like_loss 1.641194462776184 kl_loss: -1.2014240026474 alpha: 0.001 lr: 0.001
# 2021-12-11 05:21:35 [INFO]-Execute [train_an_epoch] method costing 785137.20 ms
#  61%|######1   | 49/80 [8:45:57<6:45:05, 784.05s/it]Epoch 49 starts !
# 2021-12-11 05:21:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:23:31 [INFO]-Current testEngine.best_valid_performance 0.8156685356854316
# 2021-12-11 05:23:31 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:23:32 [INFO]-performance on validation at epoch 48
# 2021-12-11 05:23:32 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.816381 |
# |  1 | precision@10 | 0.767528 |
# |  2 | recall@10    | 0.297386 |
# |  3 | map@10       | 0.262398 |
# +----+--------------+----------
# 2021-12-11 05:23:32 [INFO]-
# 2021-12-11 05:23:32 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:23:32 [INFO]-Execute [train_eval_worker] method costing 114279.44 ms
# 2021-12-11 05:34:50 [INFO]-[Training Epoch 49], log_like_loss 1.6409093141555786 kl_loss: -1.201992392539978 alpha: 0.001 lr: 0.001
# 2021-12-11 05:34:51 [INFO]-Execute [train_an_epoch] method costing 791301.19 ms
#  62%|######2   | 50/80 [8:59:13<6:33:41, 787.39s/it]Epoch 50 starts !
# 2021-12-11 05:34:52 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:36:57 [INFO]-Current testEngine.best_valid_performance 0.8163805436250674
# 2021-12-11 05:36:57 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:36:57 [INFO]-performance on validation at epoch 49
# 2021-12-11 05:36:57 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.816761 |
# |  1 | precision@10 | 0.767893 |
# |  2 | recall@10    | 0.297656 |
# |  3 | map@10       | 0.262765 |
# +----+--------------+----------
# 2021-12-11 05:36:57 [INFO]-
# 2021-12-11 05:36:57 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:36:57 [INFO]-Execute [train_eval_worker] method costing 124446.75 ms
# 2021-12-11 05:48:03 [INFO]-[Training Epoch 50], log_like_loss 1.640956163406372 kl_loss: -1.204870581626892 alpha: 0.001 lr: 0.001
# 2021-12-11 05:48:03 [INFO]-Execute [train_an_epoch] method costing 788863.48 ms
#  64%|######3   | 51/80 [9:12:26<6:21:22, 789.04s/it]Epoch 51 starts !
# 2021-12-11 05:48:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:50:34 [INFO]-Current testEngine.best_valid_performance 0.8167611799349912
# 2021-12-11 05:50:34 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:50:34 [INFO]-performance on validation at epoch 50
# 2021-12-11 05:50:34 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.81732  |
# |  1 | precision@10 | 0.768489 |
# |  2 | recall@10    | 0.2978   |
# |  3 | map@10       | 0.262968 |
# +----+--------------+----------
# 2021-12-11 05:50:34 [INFO]-
# 2021-12-11 05:50:34 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:50:34 [INFO]-Execute [train_eval_worker] method costing 148440.76 ms
# 2021-12-11 06:03:54 [INFO]-[Training Epoch 51], log_like_loss 1.6406292915344238 kl_loss: -1.3685450553894043 alpha: 0.001 lr: 0.001
# 2021-12-11 06:03:54 [INFO]-Execute [train_an_epoch] method costing 946632.54 ms
#  65%|######5   | 52/80 [9:28:18<6:31:04, 838.01s/it]Epoch 52 starts !
# 2021-12-11 06:03:58 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:06:39 [INFO]-Current testEngine.best_valid_performance 0.8173199803235848
# 2021-12-11 06:06:39 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:06:39 [INFO]-performance on validation at epoch 51
# 2021-12-11 06:06:39 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.817962 |
# |  1 | precision@10 | 0.768974 |
# |  2 | recall@10    | 0.298099 |
# |  3 | map@10       | 0.263508 |
# +----+--------------+----------
# 2021-12-11 06:06:39 [INFO]-
# 2021-12-11 06:06:39 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:06:39 [INFO]-Execute [train_eval_worker] method costing 161094.99 ms
# 2021-12-11 06:17:18 [INFO]-[Training Epoch 52], log_like_loss 1.6400195360183716 kl_loss: -1.904604434967041 alpha: 0.001 lr: 0.001
# 2021-12-11 06:17:19 [INFO]-Execute [train_an_epoch] method costing 800859.57 ms
#  66%|######6   | 53/80 [9:41:41<6:12:21, 827.48s/it]Epoch 53 starts !
# 2021-12-11 06:17:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:19:13 [INFO]-Current testEngine.best_valid_performance 0.8179624406666016
# 2021-12-11 06:19:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:19:13 [INFO]-performance on validation at epoch 52
# 2021-12-11 06:19:13 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.818415 |
# |  1 | precision@10 | 0.769575 |
# |  2 | recall@10    | 0.298375 |
# |  3 | map@10       | 0.263861 |
# +----+--------------+----------
# 2021-12-11 06:19:13 [INFO]-
# 2021-12-11 06:19:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:19:13 [INFO]-Execute [train_eval_worker] method costing 112844.63 ms
# 2021-12-11 06:30:18 [INFO]-[Training Epoch 53], log_like_loss 1.6399829387664795 kl_loss: -1.9069525003433228 alpha: 0.001 lr: 0.001
# 2021-12-11 06:30:18 [INFO]-Execute [train_an_epoch] method costing 777437.92 ms
#  68%|######7   | 54/80 [9:54:40<5:52:18, 813.02s/it]Epoch 54 starts !
# 2021-12-11 06:30:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:32:10 [INFO]-Current testEngine.best_valid_performance 0.8184151589506024
# 2021-12-11 06:32:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:32:10 [INFO]-performance on validation at epoch 53
# 2021-12-11 06:32:10 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.818869 |
# |  1 | precision@10 | 0.770127 |
# |  2 | recall@10    | 0.298735 |
# |  3 | map@10       | 0.264201 |
# +----+--------------+----------
# 2021-12-11 06:32:10 [INFO]-
# 2021-12-11 06:32:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:32:10 [INFO]-Execute [train_eval_worker] method costing 109804.36 ms
# 2021-12-11 06:43:15 [INFO]-[Training Epoch 54], log_like_loss 1.6396770477294922 kl_loss: -1.9064817428588867 alpha: 0.001 lr: 0.001
# 2021-12-11 06:43:15 [INFO]-Execute [train_an_epoch] method costing 774822.11 ms
#  69%|######8   | 55/80 [10:07:37<5:34:14, 802.19s/it]Epoch 55 starts !
# 2021-12-11 06:43:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:45:06 [INFO]-Current testEngine.best_valid_performance 0.818868844279948
# 2021-12-11 06:45:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:45:06 [INFO]-performance on validation at epoch 54
# 2021-12-11 06:45:06 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.819058 |
# |  1 | precision@10 | 0.770327 |
# |  2 | recall@10    | 0.298757 |
# |  3 | map@10       | 0.264334 |
# +----+--------------+----------
# 2021-12-11 06:45:06 [INFO]-
# 2021-12-11 06:45:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:45:06 [INFO]-Execute [train_eval_worker] method costing 109608.65 ms
# 2021-12-11 06:56:09 [INFO]-[Training Epoch 55], log_like_loss 1.6396173238754272 kl_loss: -1.9072827100753784 alpha: 0.001 lr: 0.001
# 2021-12-11 06:56:09 [INFO]-Execute [train_an_epoch] method costing 772657.86 ms
#  70%|#######   | 56/80 [10:20:31<5:17:33, 793.91s/it]Epoch 56 starts !
# 2021-12-11 06:56:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:58:01 [INFO]-Current testEngine.best_valid_performance 0.8190576971511185
# 2021-12-11 06:58:01 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:58:01 [INFO]-performance on validation at epoch 55
# 2021-12-11 06:58:01 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.819932 |
# |  1 | precision@10 | 0.771253 |
# |  2 | recall@10    | 0.299196 |
# |  3 | map@10       | 0.264822 |
# +----+--------------+----------
# 2021-12-11 06:58:01 [INFO]-
# 2021-12-11 06:58:01 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:58:01 [INFO]-Execute [train_eval_worker] method costing 109494.65 ms
# 2021-12-11 07:09:06 [INFO]-[Training Epoch 56], log_like_loss 1.6388415098190308 kl_loss: -1.908202886581421 alpha: 0.001 lr: 0.001
# 2021-12-11 07:09:06 [INFO]-Execute [train_an_epoch] method costing 773354.70 ms
#  71%|#######1  | 57/80 [10:33:28<5:02:20, 788.71s/it]Epoch 57 starts !
# 2021-12-11 07:09:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:11:01 [INFO]-Current testEngine.best_valid_performance 0.8199320074354325
# 2021-12-11 07:11:01 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:11:01 [INFO]-performance on validation at epoch 56
# 2021-12-11 07:11:01 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.82036  |
# |  1 | precision@10 | 0.771711 |
# |  2 | recall@10    | 0.299462 |
# |  3 | map@10       | 0.265107 |
# +----+--------------+----------
# 2021-12-11 07:11:01 [INFO]-
# 2021-12-11 07:11:02 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:11:02 [INFO]-Execute [train_eval_worker] method costing 113668.76 ms
# 2021-12-11 07:21:59 [INFO]-[Training Epoch 57], log_like_loss 1.6390925645828247 kl_loss: -1.9093308448791504 alpha: 0.001 lr: 0.001
# 2021-12-11 07:21:59 [INFO]-Execute [train_an_epoch] method costing 771107.32 ms
#  72%|#######2  | 58/80 [10:46:21<4:47:27, 783.97s/it]Epoch 58 starts !
# 2021-12-11 07:22:01 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:23:52 [INFO]-number of epochs that have no update 1
# 2021-12-11 07:23:52 [INFO]-Execute [train_eval_worker] method costing 111509.96 ms
# 2021-12-11 07:34:39 [INFO]-[Training Epoch 58], log_like_loss 1.6385492086410522 kl_loss: -1.9104130268096924 alpha: 0.001 lr: 0.001
# 2021-12-11 07:34:39 [INFO]-Execute [train_an_epoch] method costing 758555.72 ms
#  74%|#######3  | 59/80 [10:59:01<4:31:54, 776.89s/it]Epoch 59 starts !
# 2021-12-11 07:34:41 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:36:32 [INFO]-Current testEngine.best_valid_performance 0.8203598700503927
# 2021-12-11 07:36:32 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:36:32 [INFO]-performance on validation at epoch 58
# 2021-12-11 07:36:32 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.820718 |
# |  1 | precision@10 | 0.772107 |
# |  2 | recall@10    | 0.299827 |
# |  3 | map@10       | 0.265438 |
# +----+--------------+----------
# 2021-12-11 07:36:32 [INFO]-
# 2021-12-11 07:36:32 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:36:32 [INFO]-Execute [train_eval_worker] method costing 111197.09 ms
# 2021-12-11 07:47:22 [INFO]-[Training Epoch 59], log_like_loss 1.638389229774475 kl_loss: -1.9107611179351807 alpha: 0.001 lr: 0.001
# 2021-12-11 07:47:22 [INFO]-Execute [train_an_epoch] method costing 760890.01 ms
#  75%|#######5  | 60/80 [11:11:44<4:17:34, 772.73s/it]Epoch 60 starts !
# 2021-12-11 07:47:24 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:49:11 [INFO]-Current testEngine.best_valid_performance 0.8207177864046877
# 2021-12-11 07:49:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:49:11 [INFO]-performance on validation at epoch 59
# 2021-12-11 07:49:11 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.82109  |
# |  1 | precision@10 | 0.77261  |
# |  2 | recall@10    | 0.300001 |
# |  3 | map@10       | 0.265685 |
# +----+--------------+----------
# 2021-12-11 07:49:11 [INFO]-
# 2021-12-11 07:49:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:49:11 [INFO]-Execute [train_eval_worker] method costing 107239.99 ms
# 2021-12-11 08:00:07 [INFO]-[Training Epoch 60], log_like_loss 1.638454794883728 kl_loss: -1.9103261232376099 alpha: 0.001 lr: 0.001
# 2021-12-11 08:00:08 [INFO]-Execute [train_an_epoch] method costing 762283.37 ms
#  76%|#######6  | 61/80 [11:24:30<4:03:59, 770.51s/it]Epoch 61 starts !
# 2021-12-11 08:00:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 08:01:30 [INFO]-Current testEngine.best_valid_performance 0.8210898277806137
# 2021-12-11 08:01:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 08:01:30 [INFO]-performance on validation at epoch 60
# 2021-12-11 08:01:30 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.821387 |
# |  1 | precision@10 | 0.772885 |
# |  2 | recall@10    | 0.300133 |
# |  3 | map@10       | 0.265949 |
# +----+--------------+----------
# 2021-12-11 08:01:30 [INFO]-
# ...
# 2021-12-11 12:17:55 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 12:17:55 [INFO]-Execute [test_eval_worker] method costing 189765.72 ms
# 2021-12-11 12:21:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:21:06 [INFO]-performance on test
# 2021-12-11 12:21:06 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.872879 |
# |  1 | precision@5  | 0.851547 |
# |  2 | recall@5     | 0.17678  |
# |  3 | map@5        | 0.164958 |
# |  4 | ndcg@10      | 0.826599 |
# |  5 | precision@10 | 0.778528 |
# |  6 | recall@10    | 0.30162  |
# |  7 | map@10       | 0.268176 |
# |  8 | ndcg@20      | 0.781843 |
# |  9 | precision@20 | 0.672236 |
# | 10 | recall@20    | 0.477476 |
# | 11 | map@20       | 0.399235 |
# +----+--------------+----------
# 2021-12-11 12:21:06 [INFO]-
# 2021-12-11 12:21:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:21:06 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 12:21:06 [INFO]-Execute [test_eval_worker] method costing 189511.39 ms
# 2021-12-11 12:24:18 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:24:18 [INFO]-performance on test
# 2021-12-11 12:24:18 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.872631 |
# |  1 | precision@5  | 0.851342 |
# |  2 | recall@5     | 0.17669  |
# |  3 | map@5        | 0.164847 |
# |  4 | ndcg@10      | 0.826903 |
# |  5 | precision@10 | 0.779295 |
# |  6 | recall@10    | 0.301656 |
# |  7 | map@10       | 0.268258 |
# |  8 | ndcg@20      | 0.781344 |
# |  9 | precision@20 | 0.67167  |
# | 10 | recall@20    | 0.476854 |
# | 11 | map@20       | 0.398899 |
# +----+--------------+----------
# 2021-12-11 12:24:18 [INFO]-
# 2021-12-11 12:24:18 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:24:18 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 12:24:18 [INFO]-Execute [test_eval_worker] method costing 189702.51 ms
# 2021-12-11 12:27:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:27:33 [INFO]-performance on test
# 2021-12-11 12:27:33 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.871808 |
# |  1 | precision@5  | 0.85062  |
# |  2 | recall@5     | 0.176276 |
# |  3 | map@5        | 0.164166 |
# |  4 | ndcg@10      | 0.826305 |
# |  5 | precision@10 | 0.778813 |
# |  6 | recall@10    | 0.301524 |
# |  7 | map@10       | 0.267585 |
# |  8 | ndcg@20      | 0.78122  |
# |  9 | precision@20 | 0.671904 |
# | 10 | recall@20    | 0.477018 |
# | 11 | map@20       | 0.3984   |
# +----+--------------+----------
# 2021-12-11 12:27:33 [INFO]-
# 2021-12-11 12:27:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:27:33 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 12:27:33 [INFO]-Execute [test_eval_worker] method costing 192798.29 ms
# 2021-12-11 12:30:46 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:30:46 [INFO]-performance on test
# 2021-12-11 12:30:46 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.871883 |
# |  1 | precision@5  | 0.850477 |
# |  2 | recall@5     | 0.176496 |
# |  3 | map@5        | 0.164555 |
# |  4 | ndcg@10      | 0.826482 |
# |  5 | precision@10 | 0.778943 |
# |  6 | recall@10    | 0.301828 |
# |  7 | map@10       | 0.268052 |
# |  8 | ndcg@20      | 0.781241 |
# |  9 | precision@20 | 0.671588 |
# | 10 | recall@20    | 0.477208 |
# | 11 | map@20       | 0.39869  |
# +----+--------------+----------
# 2021-12-11 12:30:46 [INFO]-
# 2021-12-11 12:30:46 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:30:46 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 12:30:46 [INFO]-Execute [test_eval_worker] method costing 191310.13 ms
# 2021-12-11 12:30:46 [INFO]-Execute [test_eval] method costing 2011721.87 ms
# 2021-12-11 12:30:46 [INFO]-Search default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# 2021-12-11 12:30:46 [INFO]-Found default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# 2021-12-11 12:30:46 [INFO]-loading config file /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# 2021-12-11 12:30:46 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:30:46 [INFO]-Received parameters from command line (or default):
# 2021-12-11 12:30:46 [INFO]-
# +----+-----------------------+------------------------------------+
# |    | keys                  | values                             |
# |----+-----------------------+------------------------------------|
# |  0 | system:root_dir       | /home/zm324/workspace/beta-recsys/ |
# |  1 | model:n_sample        | 5000000                            |
# |  2 | model:max_epoch       | 80                                 |
# |  3 | model:emb_dim         | 64                                 |
# |  4 | model:time_step       | 20                                 |
# |  5 | model:batch_size      | 10000                              |
# |  6 | model:lr              | 0.001                              |
# |  7 | dataset:item_fea_type | random_bert_word2vec_one_hot       |
# |  8 | dataset:dataset       | instacart_25                       |
# +----+-----------------------+------------------------------------
# 2021-12-11 12:30:46 [INFO]-
# 2021-12-11 12:30:46 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:30:46 [INFO]-logs will save in file: /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211211_123046_ttfvyo .stdout.log .stderr.log
# 2021-12-11 12:30:46 [INFO]-
# 2021-12-11 12:30:46 [INFO]-
# Python version: 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0
# 2021-12-11 12:30:46 [INFO]-2021-12-11 12:30:46 [INFO]-
# 2021-12-11 12:30:46 [INFO]-2021-12-11 12:30:46 [INFO]-Pytorch version: 1.7.1
# 2021-12-11 12:30:46 [INFO]-2021-12-11 12:30:46 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211211_123046_ttfvyo
# 2021-12-11 12:30:46 [INFO]-2021-12-11 12:30:46 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211211_123046_ttfvyo
# 2021-12-11 12:30:46 [INFO]-2021-12-11 12:30:46 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/tvbr_result.csv
# 2021-12-11 12:30:46 [INFO]-2021-12-11 12:30:46 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:30:46 [INFO]-2021-12-11 12:30:46 [INFO]-System configs
# 2021-12-11 12:30:46 [INFO]-
# 2021-12-11 12:30:46 [INFO]-
# +----+----------------+-----------------------------------------------------------------------------------+
# |    | keys           | values                                                                            |
# |----+----------------+-----------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                 |
# |  1 | log_dir        | logs/                                                                             |
# |  2 | result_dir     | results/                                                                          |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                      |
# |  4 | checkpoint_dir | checkpoints/                                                                      |
# |  5 | dataset_dir    | datasets/                                                                         |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211211_123046_ttfvyo        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                   |
# |  8 | device         | gpu                                                                               |
# |  9 | seed           | 2020                                                                              |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                            |
# | 11 | k              | [5, 10, 20]                                                                       |
# | 12 | valid_metric   | ndcg                                                                              |
# | 13 | valid_k        | 10                                                                                |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/tvbr_result.csv                         |
# | 15 | save_mode      | average                                                                           |
# | 16 | model_run_id   | TVBR_default_20211211_123046_ttfvyo                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211211_123046_ttfvyo        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211211_123046_ttfvyo |
# +----+----------------+-----------------------------------------------------------------------------------
# 2021-12-11 12:30:46 [INFO]-2021-12-11 12:30:46 [INFO]-
# 2021-12-11 12:30:46 [INFO]-2021-12-11 12:30:46 [INFO]---------------------------------------------------------------------------------
# Finishing last run (ID:ibt3t1cj) before initializing another...
# <br/>Waiting for W&B process to finish, PID 13971... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 2.82MB of 2.82MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# </div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>TVBR_default_20211210_202428_murihu/device/GPU/GPU_load (%)</td><td>0.0</td></tr><tr><td>TVBR_default_20211210_202428_murihu/device/GPU/GPU_load (%)/global_step</td><td>30274</td></tr><tr><td>TVBR_default_20211210_202428_murihu/device/GPU/GPU_memory_free (%)</td><td>37051.34766</td></tr><tr><td>TVBR_default_20211210_202428_murihu/device/GPU/GPU_memory_free (%)/global_step</td><td>30274</td></tr><tr><td>TVBR_default_20211210_202428_murihu/device/GPU/GPU_memory_used (%)</td><td>65348.65234</td></tr><tr><td>TVBR_default_20211210_202428_murihu/device/GPU/GPU_memory_used (%)/global_step</td><td>30274</td></tr><tr><td>TVBR_default_20211210_202428_murihu/device/cpu/CPU_load (%)</td><td>159.3</td></tr><tr><td>TVBR_default_20211210_202428_murihu/device/cpu/CPU_load (%)/global_step</td><td>30274</td></tr><tr><td>TVBR_default_20211210_202428_murihu/device/mem/memory_used (GB)</td><td>3.24416</td></tr><tr><td>TVBR_default_20211210_202428_murihu/device/mem/memory_used (GB)/global_step</td><td>30274</td></tr><tr><td>TVBR_default_20211210_202428_murihu/model/loss/kl_loss</td><td>-1.92712</td></tr><tr><td>TVBR_default_20211210_202428_murihu/model/loss/kl_loss/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202428_murihu/model/loss/rec_loss</td><td>3.55925</td></tr><tr><td>TVBR_default_20211210_202428_murihu/model/loss/rec_loss/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202428_murihu/performance/map/valid</td><td>0.26898</td></tr><tr><td>TVBR_default_20211210_202428_murihu/performance/map/valid/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202428_murihu/performance/ndcg/valid</td><td>0.82582</td></tr><tr><td>TVBR_default_20211210_202428_murihu/performance/ndcg/valid/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202428_murihu/performance/precision/valid</td><td>0.7772</td></tr><tr><td>TVBR_default_20211210_202428_murihu/performance/precision/valid/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202428_murihu/performance/recall/valid</td><td>0.30239</td></tr><tr><td>TVBR_default_20211210_202428_murihu/performance/recall/valid/global_step</td><td>79</td></tr><tr><td>epoch</td><td>79</td></tr><tr><td>global_step</td><td>30274</td></tr><tr><td>valid_map@10</td><td>0.26898</td></tr><tr><td>valid_ndcg@10</td><td>0.82582</td></tr><tr><td>valid_precision@10</td><td>0.7772</td></tr><tr><td>valid_recall@10</td><td>0.30239</td></tr></table>
# </div></div>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 7 other file(s)
# <br/>Synced <strong style="color:#cdcd00">eternal-shape-52</strong>: <a href="https://wandb.ai/mengzaiqiao/TVBR/runs/ibt3t1cj" target="_blank">https://wandb.ai/mengzaiqiao/TVBR/runs/ibt3t1cj</a><br/>
# Find logs at: <code>./wandb/run-20211210_202428-ibt3t1cj/logs</code><br/>
# Successfully finished last run (ID:ibt3t1cj). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/mengzaiqiao/TVBR/runs/3fw423us" target="_blank">cosmic-terrain-58</a></strong> to <a href="https://wandb.ai/mengzaiqiao/TVBR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 2021-12-11 12:30:59 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 12:30:59 [INFO]-Initializing test engine ...
# 2021-12-11 12:30:59 [INFO]-[ERROR]: CANNOT support feature type random_bert_word2vec_one_hot! intialize with random feature
# 2021-12-11 12:31:00 [INFO]-Setting device for torch_engine cpu
# 2021-12-11 12:31:00 [INFO]-
# TVBR(
#   (user_emb): Embedding(23093, 64)
#   (item_emb): Embedding(14565, 64)
#   (time_embdding): Embedding(21, 21)
#   (user_mean): Embedding(23093, 64)
#   (user_std): Embedding(23093, 64)
#   (item_mean): Embedding(14565, 64)
#   (item_std): Embedding(14565, 64)
#   (time2mean_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2mean_i): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_i): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#
# 2021-12-11 12:31:00 [INFO]-
# 2021-12-11 12:31:00 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 12:31:00 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 12:31:01 [INFO]-Initialize Sampler!
# 2021-12-11 12:31:01 [INFO]-preparing training triples ...
# 2021-12-11 12:31:02 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 12:31:02 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 100%|##########| 20/20 [10:17<00:00, 30.85s/it]
#   0%|          | 0/80 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-12-11 12:42:36 [INFO]---------------------------------------------------------------------------------
