# %% [markdown]
# ### Install Beta-recsys

# %% [markdown]
# ## Loading dataset

# %%
import sys

sys.path.append("../")

import random

import numpy as np

from beta_rec.data.grocery_data import GroceryData
from beta_rec.datasets.instacart import Instacart_25

seed = 2021
random.seed(seed)  # Fix random seeds for reproducibility
np.random.seed(seed)

# make sure that you have already download the Instacart data from this link: https://www.kaggle.com/c/instacart-market-basket-analysis#
# uncompressed them and put them in this folder: ../datasets/instacart_25/raw/*.csv


dataset = Instacart_25(
    min_u_c=20, min_i_c=30, min_o_c=10
)  # Specifying the filtering conditions.

# Split the data
split_dataset = dataset.load_temporal_basket_split(test_rate=0.2, n_test=10)
data = GroceryData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 3857794    | 3857794    | 3857794      | 3857794         | 3857794     |
# | nunique | 23093      | 14565      | 1            | 3857794         | 373719      |
# +---------+------------+------------+--------------+-----------------+-------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table
# Execute [__init__] method costing 96204.24 ms
# Execute [__init__] method costing 0.00 ms

# %% [markdown]
# ### Model config

# %%
config = {"config_file": "../configs/tvbr_default.json"}
config["n_sample"] = 5000000  # To reduce the test running time
config["max_epoch"] = 80
config["emb_dim"] = 64
config["time_step"] = 50
config["batch_size"] = 10000
# config["tunable"] = [
#     {"name": "lr", "type": "choice", "values": [0.5, 0.05, 0.025, 0.001, 0.005]},
# ]
# config["tune"] = True
# the 'config_file' key is required, that is used load a default config.
# Other keys can be specified to replace the default settings.

# %% [markdown]
# ### Model intialization and training

# %%
from beta_rec.recommenders import TVBR

for item_fea_type in [
    "random",
    "cate",
    "cate_word2vec",
    "cate_bert",
    "cate_one_hot",
    "random_word2vec",
    "random_bert",
#     "random_one_hot",
#     "random_bert_word2vec_one_hot",
#     "random_cate_word2vec",
#     "random_cate_bert",
#     "random_cate_one_hot",
#     "random_cate_bert_word2vec_one_hot",
]:
    config["item_fea_type"] = item_fea_type
    lr = 0.001
    time_step = 20
    config["lr"] = lr
    config["time_step"] = time_step
    config["root_dir"] = "/home/zm324/workspace/beta-recsys/"
    config["dataset"] = "instacart_25"
    model = TVBR(config)
    model.train(data)
    model.test(data.test)
    # @To be discussed
# model.train(train_df)
# Case 1, without validation, stop training by loss or max_epoch

# model.train(train_df,valid_df[0])
# Case 2, with validation, stop training by performance on validation set

# model.train(train_df,valid_df[0],test_df[0])
# Case 3, same as Case 2, but also evaluate performance for each epoch on test set.

# Note that the best model will be save automatically, and record the model-save-dir.
# Out:
# Search default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# Found default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# loading config file /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +----+-----------------------+------------------------------------+
# |    | keys                  | values                             |
# |----+-----------------------+------------------------------------|
# |  0 | system:root_dir       | /home/zm324/workspace/beta-recsys/ |
# |  1 | model:n_sample        | 5000000                            |
# |  2 | model:max_epoch       | 80                                 |
# |  3 | model:emb_dim         | 64                                 |
# |  4 | model:time_step       | 20                                 |
# |  5 | model:batch_size      | 10000                              |
# |  6 | model:lr              | 0.001                              |
# |  7 | dataset:item_fea_type | random                             |
# |  8 | dataset:dataset       | instacart_25                       |
# +----+-----------------------+------------------------------------+
# --------------------------------------------------------------------------------
# logs will save in file: /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211210_202422_murihu .stdout.log .stderr.log
# 2021-12-10 20:24:22 [INFO]-
# Python version: 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0
# 2021-12-10 20:24:22 [INFO]-
# 2021-12-10 20:24:22 [INFO]-Pytorch version: 1.7.1
# 2021-12-10 20:24:22 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211210_202422_murihu
# 2021-12-10 20:24:22 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211210_202422_murihu
# 2021-12-10 20:24:22 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/tvbr_result.csv
# 2021-12-10 20:24:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:24:22 [INFO]-System configs
# 2021-12-10 20:24:22 [INFO]-
# +----+----------------+-----------------------------------------------------------------------------------+
# |    | keys           | values                                                                            |
# |----+----------------+-----------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                 |
# |  1 | log_dir        | logs/                                                                             |
# |  2 | result_dir     | results/                                                                          |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                      |
# |  4 | checkpoint_dir | checkpoints/                                                                      |
# |  5 | dataset_dir    | datasets/                                                                         |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211210_202422_murihu        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                   |
# |  8 | device         | gpu                                                                               |
# |  9 | seed           | 2020                                                                              |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                            |
# | 11 | k              | [5, 10, 20]                                                                       |
# | 12 | valid_metric   | ndcg                                                                              |
# | 13 | valid_k        | 10                                                                                |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/tvbr_result.csv                         |
# | 15 | save_mode      | average                                                                           |
# | 16 | model_run_id   | TVBR_default_20211210_202422_murihu                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211210_202422_murihu        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211210_202422_murihu |
# +----+----------------+-----------------------------------------------------------------------------------
# 2021-12-10 20:24:22 [INFO]-
# 2021-12-10 20:24:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:24:22 [ERROR]-Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# 2021-12-10 20:24:22 [ERROR]-wandb: Currently logged in as: mengzaiqiao (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/mengzaiqiao/TVBR/runs/26dn6yft" target="_blank">azure-cherry-51</a></strong> to <a href="https://wandb.ai/mengzaiqiao/TVBR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 2021-12-10 20:24:23 [INFO]-Get a gpu with the most available memory : 1
# 2021-12-10 20:24:23 [INFO]-Initializing test engine ...
# 2021-12-10 20:24:23 [INFO]-Get a gpu with the most available memory : 1
# 2021-12-10 20:24:25 [INFO]-Setting device for torch_engine cuda:1
# 2021-12-10 20:24:25 [INFO]-
# TVBR(
#   (user_emb): Embedding(23093, 64)
#   (item_emb): Embedding(14565, 64)
#   (time_embdding): Embedding(21, 21)
#   (user_mean): Embedding(23093, 64)
#   (user_std): Embedding(23093, 64)
#   (item_mean): Embedding(14565, 64)
#   (item_std): Embedding(14565, 64)
#   (time2mean_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2mean_i): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_i): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#
# 2021-12-10 20:24:25 [INFO]-
# 2021-12-10 20:24:27 [INFO]-Initialize Sampler!
# 2021-12-10 20:24:27 [INFO]-preparing training triples ...
# 2021-12-10 20:24:28 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:28 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:29 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:29 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:24:29 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 100%|##########| 20/20 [09:49<00:00, 29.48s/it]
#   0%|          | 0/80 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-12-10 20:35:26 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:46:11 [INFO]-[Training Epoch 0], log_like_loss 1.951809287071228 kl_loss: -0.12353431433439255 alpha: 0.001 lr: 0.001
# 2021-12-10 20:46:11 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:46:11 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:46:11 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:46:11 [INFO]-Execute [train_an_epoch] method costing 645016.16 ms
#   1%|1         | 1/80 [10:45<14:09:16, 645.02s/it]Epoch 1 starts !
# 2021-12-10 20:46:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:56:55 [INFO]-[Training Epoch 1], log_like_loss 1.8380327224731445 kl_loss: -0.21912169456481934 alpha: 0.001 lr: 0.001
# 2021-12-10 20:56:55 [INFO]-Execute [train_an_epoch] method costing 644053.53 ms
#   2%|2         | 2/80 [21:29<13:58:10, 644.74s/it]Epoch 2 starts !
# 2021-12-10 20:56:55 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:07:43 [INFO]-[Training Epoch 2], log_like_loss 1.7985635995864868 kl_loss: -0.3129269778728485 alpha: 0.001 lr: 0.001
# 2021-12-10 21:07:43 [INFO]-Execute [train_an_epoch] method costing 648390.06 ms
#   4%|3         | 3/80 [32:17<13:48:51, 645.86s/it]Epoch 3 starts !
# 2021-12-10 21:07:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:18:43 [INFO]-[Training Epoch 3], log_like_loss 1.7771433591842651 kl_loss: -0.4268594980239868 alpha: 0.001 lr: 0.001
# 2021-12-10 21:18:43 [INFO]-Execute [train_an_epoch] method costing 659523.93 ms
#   5%|5         | 4/80 [43:17<13:43:18, 649.98s/it]Epoch 4 starts !
# 2021-12-10 21:18:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:29:34 [INFO]-[Training Epoch 4], log_like_loss 1.7623282670974731 kl_loss: -0.5424435138702393 alpha: 0.001 lr: 0.001
# 2021-12-10 21:29:34 [INFO]-Execute [train_an_epoch] method costing 650889.46 ms
#   6%|6         | 5/80 [54:08<13:32:50, 650.27s/it]Epoch 5 starts !
# 2021-12-10 21:29:34 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:40:27 [INFO]-[Training Epoch 5], log_like_loss 1.748975396156311 kl_loss: -0.6420496702194214 alpha: 0.001 lr: 0.001
# 2021-12-10 21:40:27 [INFO]-Execute [train_an_epoch] method costing 652648.74 ms
#   8%|7         | 6/80 [1:05:00<13:22:54, 651.00s/it]Epoch 6 starts !
# 2021-12-10 21:40:27 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 21:51:25 [INFO]-[Training Epoch 6], log_like_loss 1.737810492515564 kl_loss: -0.7359446287155151 alpha: 0.001 lr: 0.001
# 2021-12-10 21:51:25 [INFO]-Execute [train_an_epoch] method costing 658538.99 ms
#   9%|8         | 7/80 [1:15:59<13:14:49, 653.28s/it]Epoch 7 starts !
# 2021-12-10 21:51:25 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:02:17 [INFO]-[Training Epoch 7], log_like_loss 1.7281485795974731 kl_loss: -0.8230956792831421 alpha: 0.001 lr: 0.001
# 2021-12-10 22:02:17 [INFO]-Execute [train_an_epoch] method costing 652060.57 ms
#  10%|#         | 8/80 [1:26:51<13:03:31, 652.94s/it]Epoch 8 starts !
# 2021-12-10 22:02:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:13:00 [INFO]-[Training Epoch 8], log_like_loss 1.719730019569397 kl_loss: -0.8899447321891785 alpha: 0.001 lr: 0.001
# 2021-12-10 22:13:00 [INFO]-Execute [train_an_epoch] method costing 643001.74 ms
#  11%|#1        | 9/80 [1:37:34<12:49:08, 649.98s/it]Epoch 9 starts !
# 2021-12-10 22:13:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:23:29 [INFO]-[Training Epoch 9], log_like_loss 1.7125071287155151 kl_loss: -0.9367928504943848 alpha: 0.001 lr: 0.001
# 2021-12-10 22:23:30 [INFO]-Execute [train_an_epoch] method costing 629085.61 ms
#  12%|#2        | 10/80 [1:48:03<12:31:01, 643.73s/it]Epoch 10 starts !
# 2021-12-10 22:23:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:34:04 [INFO]-[Training Epoch 10], log_like_loss 1.706605076789856 kl_loss: -0.9713089466094971 alpha: 0.001 lr: 0.001
# 2021-12-10 22:34:04 [INFO]-Execute [train_an_epoch] method costing 634790.52 ms
#  14%|#3        | 11/80 [1:58:38<12:17:13, 641.07s/it]Epoch 11 starts !
# 2021-12-10 22:34:04 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:44:43 [INFO]-[Training Epoch 11], log_like_loss 1.7007960081100464 kl_loss: -0.998611330986023 alpha: 0.001 lr: 0.001
# 2021-12-10 22:44:43 [INFO]-Execute [train_an_epoch] method costing 638599.42 ms
#  15%|#5        | 12/80 [2:09:17<12:05:43, 640.35s/it]Epoch 12 starts !
# 2021-12-10 22:44:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 22:55:27 [INFO]-[Training Epoch 12], log_like_loss 1.6957213878631592 kl_loss: -1.016769528388977 alpha: 0.001 lr: 0.001
# 2021-12-10 22:55:28 [INFO]-Execute [train_an_epoch] method costing 644340.59 ms
#  16%|#6        | 13/80 [2:20:01<11:56:24, 641.56s/it]Epoch 13 starts !
# 2021-12-10 22:55:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:06:02 [INFO]-[Training Epoch 13], log_like_loss 1.690755009651184 kl_loss: -1.0308440923690796 alpha: 0.001 lr: 0.001
# 2021-12-10 23:06:02 [INFO]-Execute [train_an_epoch] method costing 634536.20 ms
#  18%|#7        | 14/80 [2:30:36<11:43:25, 639.47s/it]Epoch 14 starts !
# 2021-12-10 23:06:02 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:16:44 [INFO]-[Training Epoch 14], log_like_loss 1.686871886253357 kl_loss: -1.0430936813354492 alpha: 0.001 lr: 0.001
# 2021-12-10 23:16:44 [INFO]-Execute [train_an_epoch] method costing 641938.62 ms
#  19%|#8        | 15/80 [2:41:18<11:33:35, 640.24s/it]Epoch 15 starts !
# 2021-12-10 23:16:44 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:27:20 [INFO]-[Training Epoch 15], log_like_loss 1.684073805809021 kl_loss: -1.0555713176727295 alpha: 0.001 lr: 0.001
# 2021-12-10 23:27:20 [INFO]-Execute [train_an_epoch] method costing 635876.01 ms
#  20%|##        | 16/80 [2:51:54<11:21:32, 638.95s/it]Epoch 16 starts !
# 2021-12-10 23:27:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:37:54 [INFO]-[Training Epoch 16], log_like_loss 1.6798956394195557 kl_loss: -1.067650318145752 alpha: 0.001 lr: 0.001
# 2021-12-10 23:37:54 [INFO]-Execute [train_an_epoch] method costing 633907.07 ms
#  21%|##1       | 17/80 [3:02:28<11:09:19, 637.46s/it]Epoch 17 starts !
# 2021-12-10 23:37:54 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:48:37 [INFO]-[Training Epoch 17], log_like_loss 1.6775912046432495 kl_loss: -1.0785599946975708 alpha: 0.001 lr: 0.001
# 2021-12-10 23:48:37 [INFO]-Execute [train_an_epoch] method costing 642526.14 ms
#  22%|##2       | 18/80 [3:13:10<11:00:17, 638.99s/it]Epoch 18 starts !
# 2021-12-10 23:48:37 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 23:59:20 [INFO]-[Training Epoch 18], log_like_loss 1.6741360425949097 kl_loss: -1.0887141227722168 alpha: 0.001 lr: 0.001
# 2021-12-10 23:59:20 [INFO]-Execute [train_an_epoch] method costing 643658.75 ms
#  24%|##3       | 19/80 [3:23:54<10:51:04, 640.41s/it]Epoch 19 starts !
# 2021-12-10 23:59:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 00:10:00 [INFO]-[Training Epoch 19], log_like_loss 1.6723450422286987 kl_loss: -1.098035216331482 alpha: 0.001 lr: 0.001
# 2021-12-11 00:10:00 [INFO]-Execute [train_an_epoch] method costing 639272.29 ms
#  25%|##5       | 20/80 [3:34:33<10:40:05, 640.08s/it]Epoch 20 starts !
# 2021-12-11 00:10:00 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 00:20:30 [INFO]-[Training Epoch 20], log_like_loss 1.6694905757904053 kl_loss: -1.1075780391693115 alpha: 0.001 lr: 0.001
# 2021-12-11 00:20:31 [INFO]-Execute [train_an_epoch] method costing 630883.83 ms
#  26%|##6       | 21/80 [3:45:04<10:26:43, 637.34s/it]Epoch 21 starts !
# 2021-12-11 00:20:31 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 00:31:11 [INFO]-[Training Epoch 21], log_like_loss 1.6675190925598145 kl_loss: -1.1140953302383423 alpha: 0.001 lr: 0.001
# 2021-12-11 00:31:11 [INFO]-Execute [train_an_epoch] method costing 640097.36 ms
#  28%|##7       | 22/80 [3:55:44<10:16:55, 638.19s/it]Epoch 22 starts !
# 2021-12-11 00:31:11 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 00:41:31 [INFO]-[Training Epoch 22], log_like_loss 1.6654095649719238 kl_loss: -1.1201339960098267 alpha: 0.001 lr: 0.001
# 2021-12-11 00:41:31 [INFO]-Execute [train_an_epoch] method costing 620175.86 ms
#  29%|##8       | 23/80 [4:06:05<10:01:09, 632.80s/it]Epoch 23 starts !
# 2021-12-11 00:41:31 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 00:51:22 [INFO]-[Training Epoch 23], log_like_loss 1.6637271642684937 kl_loss: -1.1255981922149658 alpha: 0.001 lr: 0.001
# 2021-12-11 00:51:22 [INFO]-Execute [train_an_epoch] method costing 590647.40 ms
#  30%|###       | 24/80 [4:15:55<9:38:49, 620.17s/it] Epoch 24 starts !
# 2021-12-11 00:51:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:01:09 [INFO]-[Training Epoch 24], log_like_loss 1.661913275718689 kl_loss: -1.1309083700180054 alpha: 0.001 lr: 0.001
# 2021-12-11 01:01:09 [INFO]-Execute [train_an_epoch] method costing 587042.93 ms
#  31%|###1      | 25/80 [4:25:43<9:19:23, 610.25s/it]Epoch 25 starts !
# 2021-12-11 01:01:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:11:13 [INFO]-[Training Epoch 25], log_like_loss 1.6600185632705688 kl_loss: -1.1360063552856445 alpha: 0.001 lr: 0.001
# 2021-12-11 01:11:14 [INFO]-Execute [train_an_epoch] method costing 604678.41 ms
#  32%|###2      | 26/80 [4:35:47<9:07:44, 608.60s/it]Epoch 26 starts !
# 2021-12-11 01:11:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:23:15 [INFO]-[Training Epoch 26], log_like_loss 1.6589653491973877 kl_loss: -1.1410377025604248 alpha: 0.001 lr: 0.001
# 2021-12-11 01:23:15 [INFO]-Execute [train_an_epoch] method costing 721222.15 ms
#  34%|###3      | 27/80 [4:47:49<9:27:27, 642.41s/it]Epoch 27 starts !
# 2021-12-11 01:23:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:33:43 [INFO]-[Training Epoch 27], log_like_loss 1.6576546430587769 kl_loss: -1.1466000080108643 alpha: 0.001 lr: 0.001
# 2021-12-11 01:33:43 [INFO]-Execute [train_an_epoch] method costing 628245.14 ms
#  35%|###5      | 28/80 [4:58:17<9:13:05, 638.18s/it]Epoch 28 starts !
# 2021-12-11 01:33:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:43:37 [INFO]-[Training Epoch 28], log_like_loss 1.655531406402588 kl_loss: -1.1493358612060547 alpha: 0.001 lr: 0.001
# 2021-12-11 01:43:38 [INFO]-Execute [train_an_epoch] method costing 594319.48 ms
#  36%|###6      | 29/80 [5:08:11<8:51:16, 625.04s/it]Epoch 29 starts !
# 2021-12-11 01:43:38 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 01:53:30 [INFO]-[Training Epoch 29], log_like_loss 1.654921054840088 kl_loss: -1.154312252998352 alpha: 0.001 lr: 0.001
# 2021-12-11 01:53:30 [INFO]-Execute [train_an_epoch] method costing 592198.81 ms
#  38%|###7      | 30/80 [5:18:04<8:32:40, 615.21s/it]Epoch 30 starts !
# 2021-12-11 01:53:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 02:03:22 [INFO]-[Training Epoch 30], log_like_loss 1.6542601585388184 kl_loss: -1.156446099281311 alpha: 0.001 lr: 0.001
# 2021-12-11 02:03:22 [INFO]-Execute [train_an_epoch] method costing 592445.41 ms
#  39%|###8      | 31/80 [5:27:56<8:16:51, 608.40s/it]Epoch 31 starts !
# 2021-12-11 02:03:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 02:13:13 [INFO]-[Training Epoch 31], log_like_loss 1.6528925895690918 kl_loss: -1.1598962545394897 alpha: 0.001 lr: 0.001
# 2021-12-11 02:13:13 [INFO]-Execute [train_an_epoch] method costing 590765.98 ms
#  40%|####      | 32/80 [5:37:47<8:02:30, 603.13s/it]Epoch 32 starts !
# 2021-12-11 02:13:13 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 02:23:05 [INFO]-[Training Epoch 32], log_like_loss 1.6515077352523804 kl_loss: -1.1635024547576904 alpha: 0.001 lr: 0.001
# 2021-12-11 02:23:05 [INFO]-Execute [train_an_epoch] method costing 591854.90 ms
#  41%|####1     | 33/80 [5:47:39<7:49:48, 599.76s/it]Epoch 33 starts !
# 2021-12-11 02:23:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 02:32:48 [INFO]-[Training Epoch 33], log_like_loss 1.6507755517959595 kl_loss: -1.1656051874160767 alpha: 0.001 lr: 0.001
# 2021-12-11 02:32:48 [INFO]-Execute [train_an_epoch] method costing 583005.79 ms
#  42%|####2     | 34/80 [5:57:22<7:35:58, 594.76s/it]Epoch 34 starts !
# 2021-12-11 02:32:48 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 02:42:34 [INFO]-[Training Epoch 34], log_like_loss 1.649886131286621 kl_loss: -1.1681125164031982 alpha: 0.001 lr: 0.001
# 2021-12-11 02:42:34 [INFO]-Execute [train_an_epoch] method costing 586012.96 ms
#  44%|####3     | 35/80 [6:07:08<7:24:06, 592.15s/it]Epoch 35 starts !
# 2021-12-11 02:42:34 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 02:52:17 [INFO]-[Training Epoch 35], log_like_loss 1.6484402418136597 kl_loss: -1.170538306236267 alpha: 0.001 lr: 0.001
# 2021-12-11 02:52:17 [INFO]-Execute [train_an_epoch] method costing 582483.37 ms
#  45%|####5     | 36/80 [6:16:50<7:12:08, 589.28s/it]Epoch 36 starts !
# 2021-12-11 02:52:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:01:55 [INFO]-[Training Epoch 36], log_like_loss 1.648164987564087 kl_loss: -1.172668218612671 alpha: 0.001 lr: 0.001
# 2021-12-11 03:01:55 [INFO]-Execute [train_an_epoch] method costing 578111.15 ms
#  46%|####6     | 37/80 [6:26:29<6:59:55, 585.95s/it]Epoch 37 starts !
# 2021-12-11 03:01:55 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:11:38 [INFO]-[Training Epoch 37], log_like_loss 1.6474069356918335 kl_loss: -1.1921355724334717 alpha: 0.001 lr: 0.001
# 2021-12-11 03:11:38 [INFO]-Execute [train_an_epoch] method costing 583038.89 ms
#  48%|####7     | 38/80 [6:36:12<6:49:34, 585.10s/it]Epoch 38 starts !
# 2021-12-11 03:11:38 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:21:15 [INFO]-[Training Epoch 38], log_like_loss 1.6467323303222656 kl_loss: -1.8248753547668457 alpha: 0.001 lr: 0.001
# 2021-12-11 03:21:15 [INFO]-Execute [train_an_epoch] method costing 577037.53 ms
#  49%|####8     | 39/80 [6:45:49<6:38:10, 582.70s/it]Epoch 39 starts !
# 2021-12-11 03:21:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:30:59 [INFO]-[Training Epoch 39], log_like_loss 1.6460402011871338 kl_loss: -1.881186842918396 alpha: 0.001 lr: 0.001
# 2021-12-11 03:30:59 [INFO]-Execute [train_an_epoch] method costing 583716.06 ms
#  50%|#####     | 40/80 [6:55:33<6:28:41, 583.03s/it]Epoch 40 starts !
# 2021-12-11 03:30:59 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:40:37 [INFO]-[Training Epoch 40], log_like_loss 1.6455278396606445 kl_loss: -1.8836838006973267 alpha: 0.001 lr: 0.001
# 2021-12-11 03:40:37 [INFO]-Execute [train_an_epoch] method costing 578046.26 ms
#  51%|#####1    | 41/80 [7:05:13<6:18:21, 582.10s/it]Epoch 41 starts !
# 2021-12-11 03:40:39 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:42:14 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:42:14 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:42:14 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:42:14 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:42:14 [INFO]-Current testEngine.best_valid_performance 0
# 2021-12-11 03:42:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:42:14 [INFO]-performance on validation at epoch 40
# 2021-12-11 03:42:14 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.809501 |
# |  1 | precision@10 | 0.760556 |
# |  2 | recall@10    | 0.294537 |
# |  3 | map@10       | 0.25818  |
# +----+--------------+----------
# 2021-12-11 03:42:14 [INFO]-
# 2021-12-11 03:42:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:42:14 [INFO]-Execute [train_eval_worker] method costing 94941.74 ms
# 2021-12-11 03:51:39 [INFO]-[Training Epoch 41], log_like_loss 1.6449511051177979 kl_loss: -1.8867074251174927 alpha: 0.001 lr: 0.001
# 2021-12-11 03:51:39 [INFO]-Execute [train_an_epoch] method costing 660286.08 ms
#  52%|#####2    | 42/80 [7:16:15<6:23:50, 606.07s/it]Epoch 42 starts !
# 2021-12-11 03:51:41 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:53:09 [INFO]-Current testEngine.best_valid_performance 0.8095010357040092
# 2021-12-11 03:53:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:53:09 [INFO]-performance on validation at epoch 41
# 2021-12-11 03:53:09 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.810162 |
# |  1 | precision@10 | 0.761388 |
# |  2 | recall@10    | 0.294817 |
# |  3 | map@10       | 0.25862  |
# +----+--------------+----------
# 2021-12-11 03:53:09 [INFO]-
# 2021-12-11 03:53:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:53:09 [INFO]-Execute [train_eval_worker] method costing 88455.85 ms
# 2021-12-11 04:03:37 [INFO]-[Training Epoch 42], log_like_loss 1.6440365314483643 kl_loss: -1.8883975744247437 alpha: 0.001 lr: 0.001
# 2021-12-11 04:03:38 [INFO]-Execute [train_an_epoch] method costing 716590.91 ms
#  54%|#####3    | 43/80 [7:28:13<6:34:33, 639.82s/it]Epoch 43 starts !
# 2021-12-11 04:03:39 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:05:35 [INFO]-Current testEngine.best_valid_performance 0.8101615632824531
# 2021-12-11 04:05:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:05:35 [INFO]-performance on validation at epoch 42
# 2021-12-11 04:05:35 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.810954 |
# |  1 | precision@10 | 0.762336 |
# |  2 | recall@10    | 0.29536  |
# |  3 | map@10       | 0.259184 |
# +----+--------------+----------
# 2021-12-11 04:05:35 [INFO]-
# 2021-12-11 04:05:35 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:05:35 [INFO]-Execute [train_eval_worker] method costing 115910.54 ms
# 2021-12-11 04:17:06 [INFO]-[Training Epoch 43], log_like_loss 1.643841028213501 kl_loss: -1.8956550359725952 alpha: 0.001 lr: 0.001
# 2021-12-11 04:17:06 [INFO]-Execute [train_an_epoch] method costing 805064.02 ms
#  55%|#####5    | 44/80 [7:41:41<6:54:10, 690.28s/it]Epoch 44 starts !
# 2021-12-11 04:17:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:19:15 [INFO]-Current testEngine.best_valid_performance 0.8109541355456639
# 2021-12-11 04:19:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:19:15 [INFO]-performance on validation at epoch 43
# 2021-12-11 04:19:15 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.811952 |
# |  1 | precision@10 | 0.763368 |
# |  2 | recall@10    | 0.295666 |
# |  3 | map@10       | 0.259744 |
# +----+--------------+----------
# 2021-12-11 04:19:15 [INFO]-
# 2021-12-11 04:19:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:19:15 [INFO]-Execute [train_eval_worker] method costing 127204.55 ms
# 2021-12-11 04:30:44 [INFO]-[Training Epoch 44], log_like_loss 1.6435072422027588 kl_loss: -2.18550443649292 alpha: 0.001 lr: 0.001
# 2021-12-11 04:30:44 [INFO]-Execute [train_an_epoch] method costing 814320.41 ms
#  56%|#####6    | 45/80 [7:55:20<7:05:04, 728.69s/it]Epoch 45 starts !
# 2021-12-11 04:30:46 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:32:52 [INFO]-Current testEngine.best_valid_performance 0.8119520883174729
# 2021-12-11 04:32:52 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:32:52 [INFO]-performance on validation at epoch 44
# 2021-12-11 04:32:52 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.812751 |
# |  1 | precision@10 | 0.764147 |
# |  2 | recall@10    | 0.296084 |
# |  3 | map@10       | 0.260172 |
# +----+--------------+----------
# 2021-12-11 04:32:52 [INFO]-
# 2021-12-11 04:32:52 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:32:52 [INFO]-Execute [train_eval_worker] method costing 125821.00 ms
# 2021-12-11 04:44:20 [INFO]-[Training Epoch 45], log_like_loss 1.6436456441879272 kl_loss: -2.2448787689208984 alpha: 0.001 lr: 0.001
# 2021-12-11 04:44:20 [INFO]-Execute [train_an_epoch] method costing 814088.07 ms
#  57%|#####7    | 46/80 [8:08:55<7:07:44, 754.84s/it]Epoch 46 starts !
# 2021-12-11 04:44:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:46:38 [INFO]-Current testEngine.best_valid_performance 0.8127506828373092
# 2021-12-11 04:46:38 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:46:38 [INFO]-performance on validation at epoch 45
# 2021-12-11 04:46:38 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.813237 |
# |  1 | precision@10 | 0.764743 |
# |  2 | recall@10    | 0.296472 |
# |  3 | map@10       | 0.260597 |
# +----+--------------+----------
# 2021-12-11 04:46:38 [INFO]-
# 2021-12-11 04:46:38 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:46:38 [INFO]-Execute [train_eval_worker] method costing 135974.06 ms
# 2021-12-11 04:57:57 [INFO]-[Training Epoch 46], log_like_loss 1.6422202587127686 kl_loss: -2.2473649978637695 alpha: 0.001 lr: 0.001
# 2021-12-11 04:57:57 [INFO]-Execute [train_an_epoch] method costing 813085.51 ms
#  59%|#####8    | 47/80 [8:22:32<7:05:25, 773.49s/it]Epoch 47 starts !
# 2021-12-11 04:57:59 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:00:08 [INFO]-Current testEngine.best_valid_performance 0.8132374896845485
# 2021-12-11 05:00:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:00:08 [INFO]-performance on validation at epoch 46
# 2021-12-11 05:00:08 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.814257 |
# |  1 | precision@10 | 0.765646 |
# |  2 | recall@10    | 0.296978 |
# |  3 | map@10       | 0.261294 |
# +----+--------------+----------
# 2021-12-11 05:00:08 [INFO]-
# 2021-12-11 05:00:08 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:00:08 [INFO]-Execute [train_eval_worker] method costing 129803.48 ms
# 2021-12-11 05:11:31 [INFO]-[Training Epoch 47], log_like_loss 1.6421183347702026 kl_loss: -2.2487399578094482 alpha: 0.001 lr: 0.001
# 2021-12-11 05:11:31 [INFO]-Execute [train_an_epoch] method costing 810468.19 ms
#  60%|######    | 48/80 [8:36:07<6:59:06, 785.84s/it]Epoch 48 starts !
# 2021-12-11 05:11:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:13:38 [INFO]-Current testEngine.best_valid_performance 0.81425710100122
# 2021-12-11 05:13:38 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:13:38 [INFO]-performance on validation at epoch 47
# 2021-12-11 05:13:38 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.814859 |
# |  1 | precision@10 | 0.766283 |
# |  2 | recall@10    | 0.297216 |
# |  3 | map@10       | 0.261702 |
# +----+--------------+----------
# 2021-12-11 05:13:38 [INFO]-
# 2021-12-11 05:13:38 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:13:38 [INFO]-Execute [train_eval_worker] method costing 125096.06 ms
# 2021-12-11 05:24:57 [INFO]-[Training Epoch 48], log_like_loss 1.6412667036056519 kl_loss: -2.250657558441162 alpha: 0.001 lr: 0.001
# 2021-12-11 05:24:57 [INFO]-Execute [train_an_epoch] method costing 802601.79 ms
#  61%|######1   | 49/80 [8:49:33<6:49:06, 791.83s/it]Epoch 49 starts !
# 2021-12-11 05:24:59 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:26:48 [INFO]-Current testEngine.best_valid_performance 0.8148586190269005
# 2021-12-11 05:26:48 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:26:48 [INFO]-performance on validation at epoch 48
# 2021-12-11 05:26:48 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.815355 |
# |  1 | precision@10 | 0.766861 |
# |  2 | recall@10    | 0.297428 |
# |  3 | map@10       | 0.262086 |
# +----+--------------+----------
# 2021-12-11 05:26:48 [INFO]-
# 2021-12-11 05:26:48 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:26:48 [INFO]-Execute [train_eval_worker] method costing 108724.13 ms
# 2021-12-11 05:38:17 [INFO]-[Training Epoch 49], log_like_loss 1.641042709350586 kl_loss: -2.251323699951172 alpha: 0.001 lr: 0.001
# 2021-12-11 05:38:17 [INFO]-Execute [train_an_epoch] method costing 795659.81 ms
#  62%|######2   | 50/80 [9:02:52<6:37:04, 794.14s/it]Epoch 50 starts !
# 2021-12-11 05:38:19 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:40:16 [INFO]-Current testEngine.best_valid_performance 0.8153548786743838
# 2021-12-11 05:40:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:40:16 [INFO]-performance on validation at epoch 49
# 2021-12-11 05:40:16 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.815967 |
# |  1 | precision@10 | 0.767293 |
# |  2 | recall@10    | 0.297695 |
# |  3 | map@10       | 0.26251  |
# +----+--------------+----------
# 2021-12-11 05:40:16 [INFO]-
# 2021-12-11 05:40:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:40:16 [INFO]-Execute [train_eval_worker] method costing 117402.12 ms
# 2021-12-11 05:52:24 [INFO]-[Training Epoch 50], log_like_loss 1.6413089036941528 kl_loss: -2.2532529830932617 alpha: 0.001 lr: 0.001
# 2021-12-11 05:52:24 [INFO]-Execute [train_an_epoch] method costing 844004.28 ms
#  64%|######3   | 51/80 [9:17:00<6:31:32, 810.10s/it]Epoch 51 starts !
# 2021-12-11 05:52:26 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:55:09 [INFO]-Current testEngine.best_valid_performance 0.8159673690284204
# 2021-12-11 05:55:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:55:09 [INFO]-performance on validation at epoch 50
# 2021-12-11 05:55:09 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.816434 |
# |  1 | precision@10 | 0.767737 |
# |  2 | recall@10    | 0.297908 |
# |  3 | map@10       | 0.262808 |
# +----+--------------+----------
# 2021-12-11 05:55:09 [INFO]-
# 2021-12-11 05:55:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:55:09 [INFO]-Execute [train_eval_worker] method costing 163284.92 ms
# 2021-12-11 06:08:12 [INFO]-[Training Epoch 51], log_like_loss 1.6407746076583862 kl_loss: -2.2548863887786865 alpha: 0.001 lr: 0.001
# 2021-12-11 06:08:12 [INFO]-Execute [train_an_epoch] method costing 943916.30 ms
#  65%|######5   | 52/80 [9:32:48<6:37:23, 851.55s/it]Epoch 52 starts !
# 2021-12-11 06:08:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:10:07 [INFO]-Current testEngine.best_valid_performance 0.8164336037695592
# 2021-12-11 06:10:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:10:07 [INFO]-performance on validation at epoch 51
# 2021-12-11 06:10:07 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.817005 |
# |  1 | precision@10 | 0.76816  |
# |  2 | recall@10    | 0.298222 |
# |  3 | map@10       | 0.263203 |
# +----+--------------+----------
# 2021-12-11 06:10:07 [INFO]-
# 2021-12-11 06:10:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:10:07 [INFO]-Execute [train_eval_worker] method costing 112282.84 ms
# 2021-12-11 06:21:25 [INFO]-[Training Epoch 52], log_like_loss 1.6403732299804688 kl_loss: -2.256479501724243 alpha: 0.001 lr: 0.001
# 2021-12-11 06:21:25 [INFO]-Execute [train_an_epoch] method costing 790472.71 ms
#  66%|######6   | 53/80 [9:46:00<6:15:12, 833.80s/it]Epoch 53 starts !
# 2021-12-11 06:21:27 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:23:05 [INFO]-Current testEngine.best_valid_performance 0.8170054327212021
# 2021-12-11 06:23:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:23:05 [INFO]-performance on validation at epoch 52
# 2021-12-11 06:23:05 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.817425 |
# |  1 | precision@10 | 0.768694 |
# |  2 | recall@10    | 0.298396 |
# |  3 | map@10       | 0.263462 |
# +----+--------------+----------
# 2021-12-11 06:23:05 [INFO]-
# 2021-12-11 06:23:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:23:05 [INFO]-Execute [train_eval_worker] method costing 98293.27 ms
# 2021-12-11 06:34:15 [INFO]-[Training Epoch 53], log_like_loss 1.6399072408676147 kl_loss: -2.2577686309814453 alpha: 0.001 lr: 0.001
# 2021-12-11 06:34:16 [INFO]-Execute [train_an_epoch] method costing 768135.75 ms
#  68%|######7   | 54/80 [9:58:51<5:53:07, 814.89s/it]Epoch 54 starts !
# 2021-12-11 06:34:17 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:36:04 [INFO]-Current testEngine.best_valid_performance 0.8174247490857063
# 2021-12-11 06:36:04 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:36:04 [INFO]-performance on validation at epoch 53
# 2021-12-11 06:36:04 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.818148 |
# |  1 | precision@10 | 0.769459 |
# |  2 | recall@10    | 0.298806 |
# |  3 | map@10       | 0.263891 |
# +----+--------------+----------
# 2021-12-11 06:36:04 [INFO]-
# 2021-12-11 06:36:04 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:36:04 [INFO]-Execute [train_eval_worker] method costing 107008.31 ms
# 2021-12-11 06:47:08 [INFO]-[Training Epoch 54], log_like_loss 1.6398675441741943 kl_loss: -2.25870943069458 alpha: 0.001 lr: 0.001
# 2021-12-11 06:47:09 [INFO]-Execute [train_an_epoch] method costing 771163.55 ms
#  69%|######8   | 55/80 [10:11:44<5:34:18, 802.34s/it]Epoch 55 starts !
# 2021-12-11 06:47:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:49:03 [INFO]-Current testEngine.best_valid_performance 0.8181478335980421
# 2021-12-11 06:49:03 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:49:03 [INFO]-performance on validation at epoch 54
# 2021-12-11 06:49:03 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.818478 |
# |  1 | precision@10 | 0.769846 |
# |  2 | recall@10    | 0.299002 |
# |  3 | map@10       | 0.264087 |
# +----+--------------+----------
# 2021-12-11 06:49:03 [INFO]-
# 2021-12-11 06:49:03 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:49:03 [INFO]-Execute [train_eval_worker] method costing 112996.42 ms
# 2021-12-11 07:00:19 [INFO]-[Training Epoch 55], log_like_loss 1.6395552158355713 kl_loss: -2.260460138320923 alpha: 0.001 lr: 0.001
# 2021-12-11 07:00:19 [INFO]-Execute [train_an_epoch] method costing 788304.60 ms
#  70%|#######   | 56/80 [10:24:54<5:19:28, 798.69s/it]Epoch 56 starts !
# 2021-12-11 07:00:21 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:02:16 [INFO]-Current testEngine.best_valid_performance 0.8184781365540841
# 2021-12-11 07:02:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:02:16 [INFO]-performance on validation at epoch 55
# 2021-12-11 07:02:16 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.818869 |
# |  1 | precision@10 | 0.770269 |
# |  2 | recall@10    | 0.299229 |
# |  3 | map@10       | 0.264342 |
# +----+--------------+----------
# 2021-12-11 07:02:16 [INFO]-
# 2021-12-11 07:02:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:02:16 [INFO]-Execute [train_eval_worker] method costing 115777.59 ms
# 2021-12-11 07:13:29 [INFO]-[Training Epoch 56], log_like_loss 1.6389052867889404 kl_loss: -2.261234998703003 alpha: 0.001 lr: 0.001
# 2021-12-11 07:13:29 [INFO]-Execute [train_an_epoch] method costing 788037.72 ms
#  71%|#######1  | 57/80 [10:38:04<5:05:08, 796.03s/it]Epoch 57 starts !
# 2021-12-11 07:13:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:15:22 [INFO]-Current testEngine.best_valid_performance 0.8188689794232897
# 2021-12-11 07:15:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:15:22 [INFO]-performance on validation at epoch 56
# 2021-12-11 07:15:22 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.819661 |
# |  1 | precision@10 | 0.771088 |
# |  2 | recall@10    | 0.299565 |
# |  3 | map@10       | 0.264693 |
# +----+--------------+----------
# 2021-12-11 07:15:22 [INFO]-
# 2021-12-11 07:15:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:15:22 [INFO]-Execute [train_eval_worker] method costing 111745.22 ms
# 2021-12-11 07:26:27 [INFO]-[Training Epoch 57], log_like_loss 1.6390208005905151 kl_loss: -2.2632577419281006 alpha: 0.001 lr: 0.001
# 2021-12-11 07:26:27 [INFO]-Execute [train_an_epoch] method costing 774737.63 ms
#  72%|#######2  | 58/80 [10:51:02<4:49:53, 790.63s/it]Epoch 58 starts !
# 2021-12-11 07:26:29 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:28:27 [INFO]-Current testEngine.best_valid_performance 0.8196609868878086
# 2021-12-11 07:28:27 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:28:27 [INFO]-performance on validation at epoch 57
# 2021-12-11 07:28:27 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.81984  |
# |  1 | precision@10 | 0.771364 |
# |  2 | recall@10    | 0.299647 |
# |  3 | map@10       | 0.264892 |
# +----+--------------+----------
# 2021-12-11 07:28:27 [INFO]-
# 2021-12-11 07:28:27 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:28:27 [INFO]-Execute [train_eval_worker] method costing 118947.99 ms
# 2021-12-11 07:39:27 [INFO]-[Training Epoch 58], log_like_loss 1.6386933326721191 kl_loss: -2.2627429962158203 alpha: 0.001 lr: 0.001
# 2021-12-11 07:39:27 [INFO]-Execute [train_an_epoch] method costing 778624.31 ms
#  74%|#######3  | 59/80 [11:04:03<4:35:39, 787.57s/it]Epoch 59 starts !
# 2021-12-11 07:39:29 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:41:32 [INFO]-Current testEngine.best_valid_performance 0.8198399555595444
# 2021-12-11 07:41:32 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:41:32 [INFO]-performance on validation at epoch 58
# 2021-12-11 07:41:32 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.820568 |
# |  1 | precision@10 | 0.772254 |
# |  2 | recall@10    | 0.300094 |
# |  3 | map@10       | 0.265311 |
# +----+--------------+----------
# 2021-12-11 07:41:32 [INFO]-
# 2021-12-11 07:41:32 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:41:32 [INFO]-Execute [train_eval_worker] method costing 123111.07 ms
# 2021-12-11 07:52:26 [INFO]-[Training Epoch 59], log_like_loss 1.6383421421051025 kl_loss: -2.2632641792297363 alpha: 0.001 lr: 0.001
# 2021-12-11 07:52:26 [INFO]-Execute [train_an_epoch] method costing 777282.16 ms
#  75%|#######5  | 60/80 [11:17:02<4:21:41, 785.06s/it]Epoch 60 starts !
# 2021-12-11 07:52:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:54:25 [INFO]-Current testEngine.best_valid_performance 0.820567921447365
# 2021-12-11 07:54:25 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:54:25 [INFO]-performance on validation at epoch 59
# 2021-12-11 07:54:25 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.820832 |
# |  1 | precision@10 | 0.772392 |
# |  2 | recall@10    | 0.300165 |
# |  3 | map@10       | 0.265543 |
# +----+--------------+----------
# 2021-12-11 07:54:25 [INFO]-
# 2021-12-11 07:54:25 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:54:25 [INFO]-Execute [train_eval_worker] method costing 116521.19 ms
# 2021-12-11 08:05:20 [INFO]-[Training Epoch 60], log_like_loss 1.6384644508361816 kl_loss: -2.262486457824707 alpha: 0.001 lr: 0.001
# 2021-12-11 08:05:20 [INFO]-Execute [train_an_epoch] method costing 772142.56 ms
#  76%|#######6  | 61/80 [11:29:56<4:07:34, 781.81s/it]Epoch 61 starts !
# 2021-12-11 08:05:22 [INFO]---------------------------------------------------------------------------------
# ...
# 2021-12-11 12:24:41 [INFO]-Execute [test_eval_worker] method costing 187173.25 ms
# 2021-12-11 12:27:55 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:27:55 [INFO]-performance on test
# 2021-12-11 12:27:55 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.872339 |
# |  1 | precision@5  | 0.850994 |
# |  2 | recall@5     | 0.176668 |
# |  3 | map@5        | 0.164761 |
# |  4 | ndcg@10      | 0.826831 |
# |  5 | precision@10 | 0.779045 |
# |  6 | recall@10    | 0.30212  |
# |  7 | map@10       | 0.268498 |
# |  8 | ndcg@20      | 0.781609 |
# |  9 | precision@20 | 0.67202  |
# | 10 | recall@20    | 0.477282 |
# | 11 | map@20       | 0.399315 |
# +----+--------------+----------
# 2021-12-11 12:27:55 [INFO]-
# 2021-12-11 12:27:55 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:27:55 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 12:27:55 [INFO]-Execute [test_eval_worker] method costing 191581.07 ms
# 2021-12-11 12:31:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:31:07 [INFO]-performance on test
# 2021-12-11 12:31:07 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.873768 |
# |  1 | precision@5  | 0.852536 |
# |  2 | recall@5     | 0.177109 |
# |  3 | map@5        | 0.165456 |
# |  4 | ndcg@10      | 0.8276   |
# |  5 | precision@10 | 0.779558 |
# |  6 | recall@10    | 0.302144 |
# |  7 | map@10       | 0.268964 |
# |  8 | ndcg@20      | 0.78214  |
# |  9 | precision@20 | 0.672118 |
# | 10 | recall@20    | 0.477405 |
# | 11 | map@20       | 0.399741 |
# +----+--------------+----------
# 2021-12-11 12:31:07 [INFO]-
# 2021-12-11 12:31:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:31:07 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 12:31:08 [INFO]-Execute [test_eval_worker] method costing 190764.18 ms
# 2021-12-11 12:34:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:34:15 [INFO]-performance on test
# 2021-12-11 12:34:15 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.872303 |
# |  1 | precision@5  | 0.851244 |
# |  2 | recall@5     | 0.176656 |
# |  3 | map@5        | 0.164464 |
# |  4 | ndcg@10      | 0.82637  |
# |  5 | precision@10 | 0.778675 |
# |  6 | recall@10    | 0.301628 |
# |  7 | map@10       | 0.267781 |
# |  8 | ndcg@20      | 0.781383 |
# |  9 | precision@20 | 0.67202  |
# | 10 | recall@20    | 0.476949 |
# | 11 | map@20       | 0.398674 |
# +----+--------------+----------
# 2021-12-11 12:34:15 [INFO]-
# 2021-12-11 12:34:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:34:15 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 12:34:15 [INFO]-Execute [test_eval_worker] method costing 186035.31 ms
# 2021-12-11 12:37:26 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:37:26 [INFO]-performance on test
# 2021-12-11 12:37:26 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.872806 |
# |  1 | precision@5  | 0.8516   |
# |  2 | recall@5     | 0.176814 |
# |  3 | map@5        | 0.164825 |
# |  4 | ndcg@10      | 0.826434 |
# |  5 | precision@10 | 0.778533 |
# |  6 | recall@10    | 0.301495 |
# |  7 | map@10       | 0.268092 |
# |  8 | ndcg@20      | 0.781411 |
# |  9 | precision@20 | 0.67173  |
# | 10 | recall@20    | 0.476989 |
# | 11 | map@20       | 0.398875 |
# +----+--------------+----------
# 2021-12-11 12:37:26 [INFO]-
# 2021-12-11 12:37:26 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:37:26 [INFO]-/home/zm324/workspace/beta-recsys/results/tvbr_result.csv  already exists, appending result to it
# 2021-12-11 12:37:26 [INFO]-Execute [test_eval_worker] method costing 189140.70 ms
# 2021-12-11 12:37:26 [INFO]-Execute [test_eval] method costing 1985021.46 ms
# 2021-12-11 12:37:26 [INFO]-Search default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# 2021-12-11 12:37:26 [INFO]-Found default config file in /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# 2021-12-11 12:37:26 [INFO]-loading config file /home/zm324/anaconda3/envs/beta_rec/configs/tvbr_default.json
# 2021-12-11 12:37:26 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:37:26 [INFO]-Received parameters from command line (or default):
# 2021-12-11 12:37:26 [INFO]-
# +----+-----------------------+------------------------------------+
# |    | keys                  | values                             |
# |----+-----------------------+------------------------------------|
# |  0 | system:root_dir       | /home/zm324/workspace/beta-recsys/ |
# |  1 | model:n_sample        | 5000000                            |
# |  2 | model:max_epoch       | 80                                 |
# |  3 | model:emb_dim         | 64                                 |
# |  4 | model:time_step       | 20                                 |
# |  5 | model:batch_size      | 10000                              |
# |  6 | model:lr              | 0.001                              |
# |  7 | dataset:item_fea_type | cate                               |
# |  8 | dataset:dataset       | instacart_25                       |
# +----+-----------------------+------------------------------------
# 2021-12-11 12:37:26 [INFO]-
# 2021-12-11 12:37:26 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:37:26 [INFO]-logs will save in file: /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211211_123726_ttfvyo .stdout.log .stderr.log
# 2021-12-11 12:37:26 [INFO]-
# 2021-12-11 12:37:26 [INFO]-
# Python version: 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0
# 2021-12-11 12:37:26 [INFO]-2021-12-11 12:37:26 [INFO]-
# 2021-12-11 12:37:26 [INFO]-2021-12-11 12:37:26 [INFO]-Pytorch version: 1.7.1
# 2021-12-11 12:37:26 [INFO]-2021-12-11 12:37:26 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211211_123726_ttfvyo
# 2021-12-11 12:37:26 [INFO]-2021-12-11 12:37:26 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211211_123726_ttfvyo
# 2021-12-11 12:37:26 [INFO]-2021-12-11 12:37:26 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/tvbr_result.csv
# 2021-12-11 12:37:26 [INFO]-2021-12-11 12:37:26 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 12:37:26 [INFO]-2021-12-11 12:37:26 [INFO]-System configs
# 2021-12-11 12:37:26 [INFO]-
# 2021-12-11 12:37:26 [INFO]-
# +----+----------------+-----------------------------------------------------------------------------------+
# |    | keys           | values                                                                            |
# |----+----------------+-----------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                 |
# |  1 | log_dir        | logs/                                                                             |
# |  2 | result_dir     | results/                                                                          |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                      |
# |  4 | checkpoint_dir | checkpoints/                                                                      |
# |  5 | dataset_dir    | datasets/                                                                         |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/TVBR_default_20211211_123726_ttfvyo        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                   |
# |  8 | device         | gpu                                                                               |
# |  9 | seed           | 2020                                                                              |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                            |
# | 11 | k              | [5, 10, 20]                                                                       |
# | 12 | valid_metric   | ndcg                                                                              |
# | 13 | valid_k        | 10                                                                                |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/tvbr_result.csv                         |
# | 15 | save_mode      | average                                                                           |
# | 16 | model_run_id   | TVBR_default_20211211_123726_ttfvyo                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/TVBR_default_20211211_123726_ttfvyo        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/TVBR_default_20211211_123726_ttfvyo |
# +----+----------------+-----------------------------------------------------------------------------------
# 2021-12-11 12:37:26 [INFO]-2021-12-11 12:37:26 [INFO]-
# 2021-12-11 12:37:26 [INFO]-2021-12-11 12:37:26 [INFO]---------------------------------------------------------------------------------
# Finishing last run (ID:26dn6yft) before initializing another...
# <br/>Waiting for W&B process to finish, PID 13765... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 2.95MB of 2.95MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# </div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>TVBR_default_20211210_202422_murihu/device/GPU/GPU_load (%)</td><td>0.0</td></tr><tr><td>TVBR_default_20211210_202422_murihu/device/GPU/GPU_load (%)/global_step</td><td>31401</td></tr><tr><td>TVBR_default_20211210_202422_murihu/device/GPU/GPU_memory_free (%)</td><td>42199.69141</td></tr><tr><td>TVBR_default_20211210_202422_murihu/device/GPU/GPU_memory_free (%)/global_step</td><td>31401</td></tr><tr><td>TVBR_default_20211210_202422_murihu/device/GPU/GPU_memory_used (%)</td><td>60200.30859</td></tr><tr><td>TVBR_default_20211210_202422_murihu/device/GPU/GPU_memory_used (%)/global_step</td><td>31401</td></tr><tr><td>TVBR_default_20211210_202422_murihu/device/cpu/CPU_load (%)</td><td>254.3</td></tr><tr><td>TVBR_default_20211210_202422_murihu/device/cpu/CPU_load (%)/global_step</td><td>31401</td></tr><tr><td>TVBR_default_20211210_202422_murihu/device/mem/memory_used (GB)</td><td>3.27792</td></tr><tr><td>TVBR_default_20211210_202422_murihu/device/mem/memory_used (GB)/global_step</td><td>31401</td></tr><tr><td>TVBR_default_20211210_202422_murihu/model/loss/kl_loss</td><td>-2.28161</td></tr><tr><td>TVBR_default_20211210_202422_murihu/model/loss/kl_loss/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202422_murihu/model/loss/rec_loss</td><td>3.91335</td></tr><tr><td>TVBR_default_20211210_202422_murihu/model/loss/rec_loss/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202422_murihu/model/loss/total_loss</td><td>1.63174</td></tr><tr><td>TVBR_default_20211210_202422_murihu/model/loss/total_loss/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202422_murihu/performance/map/valid</td><td>0.26854</td></tr><tr><td>TVBR_default_20211210_202422_murihu/performance/map/valid/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202422_murihu/performance/ndcg/valid</td><td>0.8251</td></tr><tr><td>TVBR_default_20211210_202422_murihu/performance/ndcg/valid/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202422_murihu/performance/precision/valid</td><td>0.77693</td></tr><tr><td>TVBR_default_20211210_202422_murihu/performance/precision/valid/global_step</td><td>79</td></tr><tr><td>TVBR_default_20211210_202422_murihu/performance/recall/valid</td><td>0.30231</td></tr><tr><td>TVBR_default_20211210_202422_murihu/performance/recall/valid/global_step</td><td>79</td></tr><tr><td>epoch</td><td>79</td></tr><tr><td>global_step</td><td>31401</td></tr><tr><td>valid_map@10</td><td>0.26854</td></tr><tr><td>valid_ndcg@10</td><td>0.8251</td></tr><tr><td>valid_precision@10</td><td>0.77693</td></tr><tr><td>valid_recall@10</td><td>0.30231</td></tr></table>
# </div></div>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 7 other file(s)
# <br/>Synced <strong style="color:#cdcd00">azure-cherry-51</strong>: <a href="https://wandb.ai/mengzaiqiao/TVBR/runs/26dn6yft" target="_blank">https://wandb.ai/mengzaiqiao/TVBR/runs/26dn6yft</a><br/>
# Find logs at: <code>./wandb/run-20211210_202422-26dn6yft/logs</code><br/>
# Successfully finished last run (ID:26dn6yft). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/mengzaiqiao/TVBR/runs/2u5ji4od" target="_blank">upbeat-shadow-59</a></strong> to <a href="https://wandb.ai/mengzaiqiao/TVBR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 2021-12-11 12:37:39 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 12:37:39 [INFO]-Initializing test engine ...
# 2021-12-11 12:37:40 [INFO]-load basic item featrue for dataset: instacart_25  type: cate
# 2021-12-11 12:37:47 [INFO]-Setting device for torch_engine cpu
# 2021-12-11 12:37:47 [INFO]-
# TVBR(
#   (user_emb): Embedding(23093, 64)
#   (item_emb): Embedding(14565, 64)
#   (time_embdding): Embedding(21, 21)
#   (user_mean): Embedding(23093, 64)
#   (user_std): Embedding(23093, 64)
#   (item_mean): Embedding(14565, 64)
#   (item_std): Embedding(14565, 64)
#   (time2mean_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_u): Sequential(
#     (0): Linear(in_features=597, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2mean_i): Sequential(
#     (0): Linear(in_features=240, out_features=64, bias=True)
#     (1): Tanh()
#   )
#   (time2std_i): Sequential(
#     (0): Linear(in_features=240, out_features=64, bias=True)
#     (1): Tanh()
#   )
#
# 2021-12-11 12:37:47 [INFO]-
# 2021-12-11 12:37:47 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 12:37:47 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 12:37:47 [INFO]-Initialize Sampler!
# 2021-12-11 12:37:47 [INFO]-preparing training triples ...
# 2021-12-11 12:37:48 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 12:37:49 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 100%|##########| 20/20 [12:01<00:00, 36.06s/it]
#   0%|          | 0/80 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-12-11 12:51:14 [INFO]---------------------------------------------------------------------------------
