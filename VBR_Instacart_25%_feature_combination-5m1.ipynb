# %% [markdown]
# ### Install Beta-recsys

# %% [markdown]
# ## Loading dataset

# %%
import sys

sys.path.append("../")

import random

import numpy as np

from beta_rec.data.grocery_data import GroceryData
from beta_rec.datasets.instacart import Instacart_25

seed = 2021
random.seed(seed)  # Fix random seeds for reproducibility
np.random.seed(seed)

# make sure that you have already download the Instacart data from this link: https://www.kaggle.com/c/instacart-market-basket-analysis#
# uncompressed them and put them in this folder: ../datasets/instacart_25/raw/*.csv


dataset = Instacart_25(
    min_u_c=20, min_i_c=30, min_o_c=10
)  # Specifying the filtering conditions.

# Split the data
split_dataset = dataset.load_temporal_basket_split(test_rate=0.2, n_test=10)
data = GroceryData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 3857794    | 3857794    | 3857794      | 3857794         | 3857794     |
# | nunique | 23093      | 14565      | 1            | 3857794         | 373719      |
# +---------+------------+------------+--------------+-----------------+-------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table
# Execute [__init__] method costing 90799.70 ms
# Execute [__init__] method costing 0.00 ms

# %% [markdown]
# ### Model config

# %%
config = {"config_file": "../configs/vbcar_default.json"}
config["n_sample"] = 5000000  # To reduce the test running time
config["max_epoch"] = 80
config["emb_dim"] = 64
config["root_dir"] = "/home/zm324/workspace/beta-recsys/"
config["dataset"] = "instacart_25"
config["batch_size"] = 10000
config["lr"] = 0.001

# config["item_fea_type"] = "random_word2vec"
# config["tunable"] = [
#     {"name": "lr", "type": "choice", "values": [0.5, 0.05, 0.025, 0.001, 0.005]},
# ]
# config["tune"] = True
# the 'config_file' key is required, that is used load a default config.
# Other keys can be specified to replace the default settings.

# %% [markdown]
# ### Model intialization and training

# %%
from beta_rec.recommenders import VBCAR

for item_fea_type in [
#     "random",
#     "cate",
#     "cate_word2vec",
#     "cate_bert",
#     "cate_one_hot",
#     "random_word2vec",
#     "random_bert",
    "random_one_hot",
    "random_bert_word2vec_one_hot",
    "random_cate_word2vec",
    "random_cate_bert",
    "random_cate_one_hot",
    "random_cate_bert_word2vec_one_hot",
]:
    config["item_fea_type"] = item_fea_type
    model = VBCAR(config)
    model.train(data)
    model.test(data.test)
# @To be discussed
# model.train(train_df)
# Case 1, without validation, stop training by loss or max_epoch

# model.train(train_df,valid_df[0])
# Case 2, with validation, stop training by performance on validation set

# model.train(train_df,valid_df[0],test_df[0])
# Case 3, same as Case 2, but also evaluate performance for each epoch on test set.

# Note that the best model will be save automatically, and record the model-save-dir.
# Out:
# Search default config file in /home/zm324/anaconda3/envs/beta_rec/configs/vbcar_default.json
# Found default config file in /home/zm324/anaconda3/envs/beta_rec/configs/vbcar_default.json
# loading config file /home/zm324/anaconda3/envs/beta_rec/configs/vbcar_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +----+-----------------------+------------------------------------+
# |    | keys                  | values                             |
# |----+-----------------------+------------------------------------|
# |  0 | system:root_dir       | /home/zm324/workspace/beta-recsys/ |
# |  1 | model:n_sample        | 5000000                            |
# |  2 | model:max_epoch       | 80                                 |
# |  3 | model:emb_dim         | 64                                 |
# |  4 | model:batch_size      | 10000                              |
# |  5 | model:lr              | 0.001                              |
# |  6 | dataset:dataset       | instacart_25                       |
# |  7 | dataset:item_fea_type | random_one_hot                     |
# +----+-----------------------+------------------------------------+
# --------------------------------------------------------------------------------
# logs will save in file: /home/zm324/workspace/beta-recsys/logs/VBCAR_default_20211210_202509_murihu .stdout.log .stderr.log
# 2021-12-10 20:25:09 [INFO]-
# Python version: 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0
# 2021-12-10 20:25:09 [INFO]-
# 2021-12-10 20:25:09 [INFO]-Pytorch version: 1.7.1
# 2021-12-10 20:25:09 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/beta-recsys/runs/VBCAR_default_20211210_202509_murihu
# 2021-12-10 20:25:09 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/beta-recsys/checkpoints/VBCAR_default_20211210_202509_murihu
# 2021-12-10 20:25:09 [INFO]-Performance result will save in file: /home/zm324/workspace/beta-recsys/results/vbcar_result.csv
# 2021-12-10 20:25:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:25:09 [INFO]-System configs
# 2021-12-10 20:25:09 [INFO]-
# +----+----------------+------------------------------------------------------------------------------------+
# |    | keys           | values                                                                             |
# |----+----------------+------------------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace/beta-recsys                                                  |
# |  1 | log_dir        | logs/                                                                              |
# |  2 | result_dir     | results/                                                                           |
# |  3 | process_dir    | /home/zm324/workspace/beta-recsys/processes/                                       |
# |  4 | checkpoint_dir | checkpoints/                                                                       |
# |  5 | dataset_dir    | datasets/                                                                          |
# |  6 | run_dir        | /home/zm324/workspace/beta-recsys/runs/VBCAR_default_20211210_202509_murihu        |
# |  7 | tune_dir       | /home/zm324/workspace/beta-recsys/tune_results/                                    |
# |  8 | device         | gpu                                                                                |
# |  9 | seed           | 2020                                                                               |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                             |
# | 11 | k              | [5, 10, 20]                                                                        |
# | 12 | valid_metric   | ndcg                                                                               |
# | 13 | valid_k        | 10                                                                                 |
# | 14 | result_file    | /home/zm324/workspace/beta-recsys/results/vbcar_result.csv                         |
# | 15 | save_mode      | average                                                                            |
# | 16 | model_run_id   | VBCAR_default_20211210_202509_murihu                                               |
# | 17 | log_file       | /home/zm324/workspace/beta-recsys/logs/VBCAR_default_20211210_202509_murihu        |
# | 18 | model_save_dir | /home/zm324/workspace/beta-recsys/checkpoints/VBCAR_default_20211210_202509_murihu |
# +----+----------------+------------------------------------------------------------------------------------
# 2021-12-10 20:25:09 [INFO]-
# 2021-12-10 20:25:09 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20:25:09 [ERROR]-Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# 2021-12-10 20:25:10 [ERROR]-wandb: Currently logged in as: mengzaiqiao (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/mengzaiqiao/VBCAR/runs/1umyqoq7" target="_blank">misunderstood-voice-62</a></strong> to <a href="https://wandb.ai/mengzaiqiao/VBCAR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 2021-12-10 20:25:11 [INFO]-Get a gpu with the most available memory : 1
# 2021-12-10 20:25:11 [INFO]-Initializing test engine ...
# 2021-12-10 20:25:11 [INFO]-Get a gpu with the most available memory : 1
# 2021-12-10 20:25:11 [INFO]-load basic item featrue for dataset: instacart_25  type: one_hot
# 2021-12-10 20:25:18 [INFO]-Setting device for torch_engine cuda:1
# 2021-12-10 20:25:18 [INFO]-
# VBCAR(
#   (user_emb): Embedding(23093, 64)
#   (item_emb): Embedding(14565, 64)
#   (fc_u_1_mu): Linear(in_features=512, out_features=256, bias=True)
#   (fc_u_2_mu): Linear(in_features=256, out_features=128, bias=True)
#   (fc_i_1_mu): Linear(in_features=676, out_features=256, bias=True)
#   (fc_i_2_mu): Linear(in_features=256, out_features=128, bias=True)
#
# 2021-12-10 20:25:18 [INFO]-
# 2021-12-10 20:25:19 [INFO]-Initialize Sampler!
# 2021-12-10 20:25:19 [INFO]-Preparing training triples ...
# 2021-12-10 20:25:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:25:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:25:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:25:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-10 20:25:20 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 100%|##########| 5000000/5000000 [10:36<00:00, 7861.37it/s]
# 2021-12-10 20:36:15 [INFO]-done!
#   0%|          | 0/80 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-12-10 20:36:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-10 20
42 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 02:47:07 [INFO]-[Training Epoch 36], log_like_loss 0.18939809210300446 kl_loss: 0.03163037047386169 alpha: 0.001 lr: 0.001
# 2021-12-11 02:47:07 [INFO]-Execute [train_an_epoch] method costing 564785.29 ms
#  46%|####6     | 37/80 [6:10:38<6:50:12, 572.38s/it]Epoch 37 starts !
# 2021-12-11 02:47:07 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 02:56:28 [INFO]-[Training Epoch 37], log_like_loss 0.18933578934669495 kl_loss: 0.03188624381422996 alpha: 0.001 lr: 0.001
# 2021-12-11 02:56:28 [INFO]-Execute [train_an_epoch] method costing 561615.33 ms
#  48%|####7     | 38/80 [6:20:00<6:38:24, 569.16s/it]Epoch 38 starts !
# 2021-12-11 02:56:28 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:05:51 [INFO]-[Training Epoch 38], log_like_loss 0.18929233775138854 kl_loss: 0.03183271592259407 alpha: 0.001 lr: 0.001
# 2021-12-11 03:05:51 [INFO]-Execute [train_an_epoch] method costing 563183.78 ms
#  49%|####8     | 39/80 [6:29:23<6:27:42, 567.38s/it]Epoch 39 starts !
# 2021-12-11 03:05:51 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:15:16 [INFO]-[Training Epoch 39], log_like_loss 0.18923600871562957 kl_loss: 0.03187998550534248 alpha: 0.001 lr: 0.001
# 2021-12-11 03:15:16 [INFO]-Execute [train_an_epoch] method costing 564899.27 ms
#  50%|#####     | 40/80 [6:38:48<6:17:45, 566.64s/it]Epoch 40 starts !
# 2021-12-11 03:15:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:24:36 [INFO]-[Training Epoch 40], log_like_loss 0.18917203660011292 kl_loss: 0.03179132212996483 alpha: 0.001 lr: 0.001
# 2021-12-11 03:24:36 [INFO]-Execute [train_an_epoch] method costing 560014.83 ms
#  51%|#####1    | 41/80 [6:48:09<6:07:16, 565.03s/it]Epoch 41 starts !
# 2021-12-11 03:24:38 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:26:16 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:26:16 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:26:16 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:26:16 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 03:26:16 [INFO]-Current testEngine.best_valid_performance 0
# 2021-12-11 03:26:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:26:16 [INFO]-performance on validation at epoch 40
# 2021-12-11 03:26:16 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.81568  |
# |  1 | precision@10 | 0.767444 |
# |  2 | recall@10    | 0.295832 |
# |  3 | map@10       | 0.262096 |
# +----+--------------+----------
# 2021-12-11 03:26:16 [INFO]-
# 2021-12-11 03:26:16 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:26:16 [INFO]-Execute [train_eval_worker] method costing 98604.68 ms
# 2021-12-11 03:35:23 [INFO]-[Training Epoch 41], log_like_loss 0.189126189994812 kl_loss: 0.0318423326253891 alpha: 0.001 lr: 0.001
# 2021-12-11 03:35:23 [INFO]-Execute [train_an_epoch] method costing 645508.98 ms
#  52%|#####2    | 42/80 [6:58:56<6:13:19, 589.45s/it]Epoch 42 starts !
# 2021-12-11 03:35:24 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:37:05 [INFO]-Current testEngine.best_valid_performance 0.8156804304546404
# 2021-12-11 03:37:05 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:37:05 [INFO]-performance on validation at epoch 41
# 2021-12-11 03:37:05 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.815945 |
# |  1 | precision@10 | 0.767715 |
# |  2 | recall@10    | 0.29565  |
# |  3 | map@10       | 0.262163 |
# +----+--------------+----------
# 2021-12-11 03:37:06 [INFO]-
# 2021-12-11 03:37:06 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:37:06 [INFO]-Execute [train_eval_worker] method costing 101510.82 ms
# 2021-12-11 03:46:03 [INFO]-[Training Epoch 42], log_like_loss 0.1890885806322098 kl_loss: 0.03184425631761551 alpha: 0.001 lr: 0.001
# 2021-12-11 03:46:03 [INFO]-Execute [train_an_epoch] method costing 638764.43 ms
#  54%|#####3    | 43/80 [7:09:35<6:12:47, 604.52s/it]Epoch 43 starts !
# 2021-12-11 03:46:04 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:47:36 [INFO]-Current testEngine.best_valid_performance 0.8159449423644227
# 2021-12-11 03:47:36 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:47:36 [INFO]-performance on validation at epoch 42
# 2021-12-11 03:47:36 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.818057 |
# |  1 | precision@10 | 0.769771 |
# |  2 | recall@10    | 0.296893 |
# |  3 | map@10       | 0.263653 |
# +----+--------------+----------
# 2021-12-11 03:47:36 [INFO]-
# 2021-12-11 03:47:36 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:47:36 [INFO]-Execute [train_eval_worker] method costing 92649.88 ms
# 2021-12-11 03:56:09 [INFO]-[Training Epoch 43], log_like_loss 0.1890406132698059 kl_loss: 0.0326269069314003 alpha: 0.001 lr: 0.001
# 2021-12-11 03:56:09 [INFO]-Execute [train_an_epoch] method costing 604919.91 ms
#  55%|#####5    | 44/80 [7:19:41<6:02:58, 604.96s/it]Epoch 44 starts !
# 2021-12-11 03:56:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:57:43 [INFO]-Current testEngine.best_valid_performance 0.818056959730013
# 2021-12-11 03:57:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:57:43 [INFO]-performance on validation at epoch 43
# 2021-12-11 03:57:43 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.819132 |
# |  1 | precision@10 | 0.771066 |
# |  2 | recall@10    | 0.297671 |
# |  3 | map@10       | 0.264316 |
# +----+--------------+----------
# 2021-12-11 03:57:43 [INFO]-
# 2021-12-11 03:57:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 03:57:43 [INFO]-Execute [train_eval_worker] method costing 93653.85 ms
# 2021-12-11 04:08:14 [INFO]-[Training Epoch 44], log_like_loss 0.18900379383563995 kl_loss: 0.031963047397136686 alpha: 0.001 lr: 0.001
# 2021-12-11 04:08:14 [INFO]-Execute [train_an_epoch] method costing 724125.05 ms
#  56%|#####6    | 45/80 [7:31:47<6:13:56, 641.05s/it]Epoch 45 starts !
# 2021-12-11 04:08:15 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:10:30 [INFO]-Current testEngine.best_valid_performance 0.8191323660132579
# 2021-12-11 04:10:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:10:30 [INFO]-performance on validation at epoch 44
# 2021-12-11 04:10:30 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.820522 |
# |  1 | precision@10 | 0.77244  |
# |  2 | recall@10    | 0.298545 |
# |  3 | map@10       | 0.265312 |
# +----+--------------+----------
# 2021-12-11 04:10:30 [INFO]-
# 2021-12-11 04:10:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:10:30 [INFO]-Execute [train_eval_worker] method costing 135090.29 ms
# 2021-12-11 04:21:32 [INFO]-[Training Epoch 45], log_like_loss 0.18897778315544128 kl_loss: 0.031905175256729125 alpha: 0.001 lr: 0.001
# 2021-12-11 04:21:32 [INFO]-Execute [train_an_epoch] method costing 796633.94 ms
#  57%|#####7    | 46/80 [7:45:04<6:29:52, 688.01s/it]Epoch 46 starts !
# 2021-12-11 04:21:33 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:23:43 [INFO]-Current testEngine.best_valid_performance 0.820522332263737
# 2021-12-11 04:23:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:23:43 [INFO]-performance on validation at epoch 45
# 2021-12-11 04:23:43 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.821733 |
# |  1 | precision@10 | 0.773766 |
# |  2 | recall@10    | 0.299255 |
# |  3 | map@10       | 0.266003 |
# +----+--------------+----------
# 2021-12-11 04:23:43 [INFO]-
# 2021-12-11 04:23:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:23:43 [INFO]-Execute [train_eval_worker] method costing 130338.89 ms
# 2021-12-11 04:34:01 [INFO]-[Training Epoch 46], log_like_loss 0.1889396040916443 kl_loss: 0.0319074339389801 alpha: 0.001 lr: 0.001
# 2021-12-11 04:34:01 [INFO]-Execute [train_an_epoch] method costing 748184.62 ms
#  59%|#####8    | 47/80 [7:57:34<6:28:33, 706.48s/it]Epoch 47 starts !
# 2021-12-11 04:34:02 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:36:10 [INFO]-Current testEngine.best_valid_performance 0.8217333844069119
# 2021-12-11 04:36:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:36:10 [INFO]-performance on validation at epoch 46
# 2021-12-11 04:36:10 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.82216  |
# |  1 | precision@10 | 0.773766 |
# |  2 | recall@10    | 0.299408 |
# |  3 | map@10       | 0.26626  |
# +----+--------------+----------
# 2021-12-11 04:36:10 [INFO]-
# 2021-12-11 04:36:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:36:10 [INFO]-Execute [train_eval_worker] method costing 127747.96 ms
# 2021-12-11 04:46:24 [INFO]-[Training Epoch 47], log_like_loss 0.18890766808986664 kl_loss: 0.03205749630331993 alpha: 0.001 lr: 0.001
# 2021-12-11 04:46:24 [INFO]-Execute [train_an_epoch] method costing 741398.03 ms
#  60%|######    | 48/80 [8:09:56<6:22:33, 717.29s/it]Epoch 48 starts !
# 2021-12-11 04:46:25 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:48:42 [INFO]-Current testEngine.best_valid_performance 0.8221602528786028
# 2021-12-11 04:48:42 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:48:42 [INFO]-performance on validation at epoch 47
# 2021-12-11 04:48:42 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.823482 |
# |  1 | precision@10 | 0.775462 |
# |  2 | recall@10    | 0.300141 |
# |  3 | map@10       | 0.267298 |
# +----+--------------+----------
# 2021-12-11 04:48:42 [INFO]-
# 2021-12-11 04:48:42 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 04:48:42 [INFO]-Execute [train_eval_worker] method costing 137746.03 ms
# 2021-12-11 04:59:38 [INFO]-[Training Epoch 48], log_like_loss 0.1888764628648758 kl_loss: 0.03198767822980881 alpha: 0.001 lr: 0.001
# 2021-12-11 04:59:38 [INFO]-Execute [train_an_epoch] method costing 793468.28 ms
#  61%|######1   | 49/80 [8:23:11<6:22:33, 740.45s/it]Epoch 49 starts !
# 2021-12-11 04:59:39 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:01:50 [INFO]-Current testEngine.best_valid_performance 0.8234822568411012
# 2021-12-11 05:01:50 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:01:50 [INFO]-performance on validation at epoch 48
# 2021-12-11 05:01:50 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.824501 |
# |  1 | precision@10 | 0.776645 |
# |  2 | recall@10    | 0.300806 |
# |  3 | map@10       | 0.267859 |
# +----+--------------+----------
# 2021-12-11 05:01:50 [INFO]-
# 2021-12-11 05:01:50 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:01:50 [INFO]-Execute [train_eval_worker] method costing 131274.44 ms
# 2021-12-11 05:12:46 [INFO]-[Training Epoch 49], log_like_loss 0.18884781503677367 kl_loss: 0.03201055701375008 alpha: 0.001 lr: 0.001
# 2021-12-11 05:12:46 [INFO]-Execute [train_an_epoch] method costing 787240.92 ms
#  62%|######2   | 50/80 [8:36:19<6:17:26, 754.89s/it]Epoch 50 starts !
# 2021-12-11 05:12:48 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:14:42 [INFO]-Current testEngine.best_valid_performance 0.8245013021801584
# 2021-12-11 05:14:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:14:43 [INFO]-performance on validation at epoch 49
# 2021-12-11 05:14:43 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.825463 |
# |  1 | precision@10 | 0.777535 |
# |  2 | recall@10    | 0.301562 |
# |  3 | map@10       | 0.268584 |
# +----+--------------+----------
# 2021-12-11 05:14:43 [INFO]-
# 2021-12-11 05:14:43 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:14:43 [INFO]-Execute [train_eval_worker] method costing 114864.91 ms
# 2021-12-11 05:24:52 [INFO]-[Training Epoch 50], log_like_loss 0.18882923274040223 kl_loss: 0.03198156258463859 alpha: 0.001 lr: 0.001
# 2021-12-11 05:24:52 [INFO]-Execute [train_an_epoch] method costing 724166.99 ms
#  64%|######3   | 51/80 [8:48:25<6:00:34, 746.01s/it]Epoch 51 starts !
# 2021-12-11 05:24:53 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:26:44 [INFO]-Current testEngine.best_valid_performance 0.8254628659775017
# 2021-12-11 05:26:44 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:26:44 [INFO]-performance on validation at epoch 50
# 2021-12-11 05:26:44 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.825513 |
# |  1 | precision@10 | 0.777575 |
# |  2 | recall@10    | 0.301564 |
# |  3 | map@10       | 0.268528 |
# +----+--------------+----------
# 2021-12-11 05:26:44 [INFO]-
# 2021-12-11 05:26:44 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:26:44 [INFO]-Execute [train_eval_worker] method costing 110811.23 ms
# 2021-12-11 05:36:53 [INFO]-[Training Epoch 51], log_like_loss 0.18880387258529663 kl_loss: 0.03207742137908936 alpha: 0.001 lr: 0.001
# 2021-12-11 05:36:53 [INFO]-Execute [train_an_epoch] method costing 719875.26 ms
#  65%|######5   | 52/80 [9:00:26<5:44:39, 738.56s/it]Epoch 52 starts !
# 2021-12-11 05:36:54 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:38:52 [INFO]-Current testEngine.best_valid_performance 0.8255133505062062
# 2021-12-11 05:38:52 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:38:52 [INFO]-performance on validation at epoch 51
# 2021-12-11 05:38:52 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.826608 |
# |  1 | precision@10 | 0.778941 |
# |  2 | recall@10    | 0.302303 |
# |  3 | map@10       | 0.269269 |
# +----+--------------+----------
# 2021-12-11 05:38:52 [INFO]-
# 2021-12-11 05:38:52 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:38:52 [INFO]-Execute [train_eval_worker] method costing 117758.41 ms
# 2021-12-11 05:49:02 [INFO]-[Training Epoch 52], log_like_loss 0.18878365123271942 kl_loss: 0.03207791991233826 alpha: 0.001 lr: 0.001
# 2021-12-11 05:49:02 [INFO]-Execute [train_an_epoch] method costing 727908.71 ms
#  66%|######6   | 53/80 [9:12:35<5:31:05, 735.75s/it]Epoch 53 starts !
# 2021-12-11 05:49:03 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:51:31 [INFO]-Current testEngine.best_valid_performance 0.8266077418851154
# 2021-12-11 05:51:31 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:51:31 [INFO]-performance on validation at epoch 52
# 2021-12-11 05:51:31 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.826646 |
# |  1 | precision@10 | 0.778945 |
# |  2 | recall@10    | 0.302426 |
# |  3 | map@10       | 0.269399 |
# +----+--------------+----------
# 2021-12-11 05:51:31 [INFO]-
# 2021-12-11 05:51:31 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 05:51:31 [INFO]-Execute [train_eval_worker] method costing 147581.58 ms
# 2021-12-11 06:03:28 [INFO]-[Training Epoch 53], log_like_loss 0.18876399962902068 kl_loss: 0.032128934985399246 alpha: 0.001 lr: 0.001
# 2021-12-11 06:03:28 [INFO]-Execute [train_an_epoch] method costing 864994.10 ms
#  68%|######7   | 54/80 [9:27:02<5:35:52, 775.10s/it]Epoch 54 starts !
# 2021-12-11 06:03:30 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:06:19 [INFO]-Current testEngine.best_valid_performance 0.8266462667220434
# 2021-12-11 06:06:19 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:06:19 [INFO]-performance on validation at epoch 53
# 2021-12-11 06:06:19 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.827411 |
# |  1 | precision@10 | 0.779626 |
# |  2 | recall@10    | 0.302515 |
# |  3 | map@10       | 0.269946 |
# +----+--------------+----------
# 2021-12-11 06:06:19 [INFO]-
# 2021-12-11 06:06:19 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:06:19 [INFO]-Execute [train_eval_worker] method costing 169259.91 ms
# 2021-12-11 06:16:37 [INFO]-[Training Epoch 54], log_like_loss 0.1887386376142502 kl_loss: 0.031976077908277514 alpha: 0.001 lr: 0.001
# 2021-12-11 06:16:37 [INFO]-Execute [train_an_epoch] method costing 786721.19 ms
#  69%|######8   | 55/80 [9:40:10<5:24:33, 778.93s/it]Epoch 55 starts !
# 2021-12-11 06:16:38 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:18:39 [INFO]-number of epochs that have no update 1
# 2021-12-11 06:18:39 [INFO]-Execute [train_eval_worker] method costing 121118.20 ms
# 2021-12-11 06:29:09 [INFO]-[Training Epoch 55], log_like_loss 0.1887143435239792 kl_loss: 0.03200628209710121 alpha: 0.001 lr: 0.001
# 2021-12-11 06:29:09 [INFO]-Execute [train_an_epoch] method costing 751121.82 ms
#  70%|#######   | 56/80 [9:52:42<5:08:23, 770.96s/it]Epoch 56 starts !
# 2021-12-11 06:29:10 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:31:12 [INFO]-Current testEngine.best_valid_performance 0.8274107691773188
# 2021-12-11 06:31:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:31:12 [INFO]-performance on validation at epoch 55
# 2021-12-11 06:31:12 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.828092 |
# |  1 | precision@10 | 0.780605 |
# |  2 | recall@10    | 0.303315 |
# |  3 | map@10       | 0.270353 |
# +----+--------------+----------
# 2021-12-11 06:31:12 [INFO]-
# 2021-12-11 06:31:12 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:31:12 [INFO]-Execute [train_eval_worker] method costing 121555.21 ms
# 2021-12-11 06:41:46 [INFO]-[Training Epoch 56], log_like_loss 0.188700675034523 kl_loss: 0.03212527154684067 alpha: 0.001 lr: 0.001
# 2021-12-11 06:41:46 [INFO]-Execute [train_an_epoch] method costing 755380.65 ms
#  71%|#######1  | 57/80 [10:05:19<4:53:53, 766.65s/it]Epoch 57 starts !
# 2021-12-11 06:41:47 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:43:52 [INFO]-Current testEngine.best_valid_performance 0.8280918040013792
# 2021-12-11 06:43:52 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:43:52 [INFO]-performance on validation at epoch 56
# 2021-12-11 06:43:52 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.828118 |
# |  1 | precision@10 | 0.780694 |
# |  2 | recall@10    | 0.303347 |
# |  3 | map@10       | 0.270295 |
# +----+--------------+----------
# 2021-12-11 06:43:52 [INFO]-
# 2021-12-11 06:43:52 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:43:52 [INFO]-Execute [train_eval_worker] method costing 125044.07 ms
# 2021-12-11 06:54:26 [INFO]-[Training Epoch 57], log_like_loss 0.18867858946323396 kl_loss: 0.032090413200855254 alpha: 0.001 lr: 0.001
# 2021-12-11 06:54:26 [INFO]-Execute [train_an_epoch] method costing 759020.63 ms
#  72%|#######2  | 58/80 [10:17:59<4:40:23, 764.72s/it]Epoch 58 starts !
# 2021-12-11 06:54:27 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:56:22 [INFO]-Current testEngine.best_valid_performance 0.8281181355895689
# 2021-12-11 06:56:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:56:22 [INFO]-performance on validation at epoch 57
# 2021-12-11 06:56:22 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.829586 |
# |  1 | precision@10 | 0.782385 |
# |  2 | recall@10    | 0.304139 |
# |  3 | map@10       | 0.271154 |
# +----+--------------+----------
# 2021-12-11 06:56:22 [INFO]-
# 2021-12-11 06:56:22 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 06:56:22 [INFO]-Execute [train_eval_worker] method costing 114665.24 ms
# 2021-12-11 07:06:12 [INFO]-[Training Epoch 58], log_like_loss 0.18866482400894166 kl_loss: 0.03210770693421364 alpha: 0.001 lr: 0.001
# 2021-12-11 07:06:12 [INFO]-Execute [train_an_epoch] method costing 705120.79 ms
#  74%|#######3  | 59/80 [10:29:45<4:21:31, 747.21s/it]Epoch 59 starts !
# 2021-12-11 07:06:14 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:08:18 [INFO]-number of epochs that have no update 1
# 2021-12-11 07:08:18 [INFO]-Execute [train_eval_worker] method costing 124450.84 ms
# 2021-12-11 07:18:53 [INFO]-[Training Epoch 59], log_like_loss 0.18865111854076386 kl_loss: 0.031969244688749315 alpha: 0.001 lr: 0.001
# 2021-12-11 07:18:53 [INFO]-Execute [train_an_epoch] method costing 759561.02 ms
#  75%|#######5  | 60/80 [10:42:26<4:10:25, 751.28s/it]Epoch 60 starts !
# 2021-12-11 07:18:54 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:21:01 [INFO]-Current testEngine.best_valid_performance 0.8295863446398056
# 2021-12-11 07:21:01 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:21:01 [INFO]-performance on validation at epoch 59
# 2021-12-11 07:21:01 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.830168 |
# |  1 | precision@10 | 0.782776 |
# |  2 | recall@10    | 0.304521 |
# |  3 | map@10       | 0.271735 |
# +----+--------------+----------
# 2021-12-11 07:21:01 [INFO]-
# 2021-12-11 07:21:01 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:21:01 [INFO]-Execute [train_eval_worker] method costing 126417.44 ms
# 2021-12-11 07:31:19 [INFO]-[Training Epoch 60], log_like_loss 0.18861973295211792 kl_loss: 0.03205239652395248 alpha: 0.001 lr: 0.001
# 2021-12-11 07:31:19 [INFO]-Execute [train_an_epoch] method costing 744687.26 ms
#  76%|#######6  | 61/80 [10:54:52<3:57:23, 749.65s/it]Epoch 61 starts !
# 2021-12-11 07:31:20 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:33:24 [INFO]-number of epochs that have no update 1
# 2021-12-11 07:33:24 [INFO]-Execute [train_eval_worker] method costing 123744.04 ms
# 2021-12-11 07:43:52 [INFO]-[Training Epoch 61], log_like_loss 0.18861148421764373 kl_loss: 0.03206543526649475 alpha: 0.001 lr: 0.001
# 2021-12-11 07:43:52 [INFO]-Execute [train_an_epoch] method costing 751823.61 ms
#  78%|#######7  | 62/80 [11:07:25<3:45:13, 750.76s/it]Epoch 62 starts !
# 2021-12-11 07:43:54 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:46:02 [INFO]-Current testEngine.best_valid_performance 0.8301681960498357
# 2021-12-11 07:46:02 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:46:02 [INFO]-performance on validation at epoch 61
# 2021-12-11 07:46:02 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.830624 |
# |  1 | precision@10 | 0.783195 |
# |  2 | recall@10    | 0.304744 |
# |  3 | map@10       | 0.271987 |
# +----+--------------+----------
# 2021-12-11 07:46:02 [INFO]-
# 2021-12-11 07:46:02 [INFO]---------------------------------------------------------------------------------
# 2021-12-11 07:46:02 [INFO]-Execute [train_eval_worker] method costing 128785.19 ms
# 2021-12-11 07:56:24 [INFO]-[Training Epoch 62], log_like_loss 0.18859780809879303 kl_loss: 0.03213158492445946 alpha: 0.001 lr: 0.001
# ...
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# </div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>VBCAR_default_20211210_202509_murihu/device/GPU/GPU_load (%)</td><td>6.0</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/device/GPU/GPU_load (%)/global_step</td><td>26534</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/device/GPU/GPU_memory_free (%)</td><td>42199.69141</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/device/GPU/GPU_memory_free (%)/global_step</td><td>26534</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/device/GPU/GPU_memory_used (%)</td><td>60200.30859</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/device/GPU/GPU_memory_used (%)/global_step</td><td>26534</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/device/cpu/CPU_load (%)</td><td>97.4</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/device/cpu/CPU_load (%)/global_step</td><td>26534</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/device/mem/memory_used (GB)</td><td>3.39391</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/device/mem/memory_used (GB)/global_step</td><td>26534</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/model/loss/kl_loss</td><td>0.03163</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/model/loss/kl_loss/global_step</td><td>79</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/model/loss/rec_loss</td><td>0.15665</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/model/loss/rec_loss/global_step</td><td>79</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/model/loss/total_loss</td><td>0.18828</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/model/loss/total_loss/global_step</td><td>79</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/performance/map/valid</td><td>0.2739</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/performance/map/valid/global_step</td><td>79</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/performance/ndcg/valid</td><td>0.8338</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/performance/ndcg/valid/global_step</td><td>79</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/performance/precision/valid</td><td>0.78749</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/performance/precision/valid/global_step</td><td>79</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/performance/recall/valid</td><td>0.3069</td></tr><tr><td>VBCAR_default_20211210_202509_murihu/performance/recall/valid/global_step</td><td>79</td></tr><tr><td>epoch</td><td>79</td></tr><tr><td>global_step</td><td>26534</td></tr><tr><td>valid_map@10</td><td>0.2739</td></tr><tr><td>valid_ndcg@10</td><td>0.8338</td></tr><tr><td>valid_precision@10</td><td>0.78749</td></tr><tr><td>valid_recall@10</td><td>0.3069</td></tr></table>
# </div></div>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 7 other file(s)
# <br/>Synced <strong style="color:#cdcd00">misunderstood-voice-62</strong>: <a href="https://wandb.ai/mengzaiqiao/VBCAR/runs/1umyqoq7" target="_blank">https://wandb.ai/mengzaiqiao/VBCAR/runs/1umyqoq7</a><br/>
# Find logs at: <code>./wandb/run-20211210_202510-1umyqoq7/logs</code><br/>
# Successfully finished last run (ID:1umyqoq7). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/mengzaiqiao/VBCAR/runs/rtsiwcp5" target="_blank">lilac-mountain-70</a></strong> to <a href="https://wandb.ai/mengzaiqiao/VBCAR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 2021-12-11 11:53:34 [INFO]-Get a gpu with the most available memory : 3
# 2021-12-11 11:53:34 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11 11:53:34 [INFO]-Initializing test engine ...
# 2021-12-11 11:53:35 [INFO]-Get a gpu with the most available memory : 3
# 2021-12-11 11:53:35 [INFO]-[ERROR]: CANNOT support feature type random_bert_word2vec_one_hot! intialize with random feature
# 2021-12-11 11:53:45 [INFO]-Setting device for torch_engine cuda:3
# 2021-12-11 11:53:45 [INFO]-
# VBCAR(
#   (user_emb): Embedding(23093, 64)
#   (item_emb): Embedding(14565, 64)
#   (fc_u_1_mu): Linear(in_features=512, out_features=256, bias=True)
#   (fc_u_2_mu): Linear(in_features=256, out_features=128, bias=True)
#   (fc_i_1_mu): Linear(in_features=512, out_features=256, bias=True)
#   (fc_i_2_mu): Linear(in_features=256, out_features=128, bias=True)
#
# 2021-12-11 11:53:45 [INFO]-
# 2021-12-11 11:53:45 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-12-11