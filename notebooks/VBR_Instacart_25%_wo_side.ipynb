# %% [markdown]
# ### Install Beta-recsys

# %% [markdown]
# ## Loading dataset

# %%
import sys

sys.path.append("../")

import random

import numpy as np

from beta_rec.data.grocery_data import GroceryData
from beta_rec.datasets.instacart import Instacart_25

seed = 2021
random.seed(seed)  # Fix random seeds for reproducibility
np.random.seed(seed)

# make sure that you have already download the Instacart data from this link: https://www.kaggle.com/c/instacart-market-basket-analysis#
# uncompressed them and put them in this folder: ../datasets/instacart_25/raw/*.csv


dataset = Instacart_25(
    min_u_c=20, min_i_c=30, min_o_c=10
)  # Specifying the filtering conditions.

# Split the data
split_dataset = dataset.load_temporal_basket_split(test_rate=0.2, n_test=10)
data = GroceryData(split_dataset)
# Out:
# --------------------------------------------------------------------------------
# Loaded training set statistics
# +---------+------------+------------+--------------+-----------------+-------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   | col_order   |
# |---------+------------+------------+--------------+-----------------+-------------|
# | count   | 3857794    | 3857794    | 3857794      | 3857794         | 3857794     |
# | nunique | 23093      | 14565      | 1            | 3857794         | 373719      |
# +---------+------------+------------+--------------+-----------------+-------------+
# valid_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# test_data_0 statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# --------------------------------------------------------------------------------
# After intersection, testing set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3072601    | 3072601    | 3072601      | 3072601         |
# | nunique | 22434      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# After intersection, validation set [0] statistics
# +---------+------------+------------+--------------+-----------------+
# |         | col_user   | col_item   | col_rating   | col_timestamp   |
# |---------+------------+------------+--------------+-----------------|
# | count   | 3076168    | 3076168    | 3076168      | 3076168         |
# | nunique | 22475      | 14565      | 2            | 1               |
# +---------+------------+------------+--------------+-----------------+
# Filling alias table
# Filling alias table

# %% [markdown]
# ### Model config

# %%
config = {"config_file": "../configs/vbcar_default.json"}
config["n_sample"] = 1000000  # To reduce the test running time
config["max_epoch"] = 80
config["emb_dim"] = 64
config["batch_size"] = 1024
# config["tunable"] = [
#     {"name": "lr", "type": "choice", "values": [0.5, 0.05, 0.025, 0.001, 0.005]},
# ]
# config["tune"] = True
# the 'config_file' key is required, that is used load a default config.
# Other keys can be specified to replace the default settings.

# %% [markdown]
# ### Model intialization and training

# %%
from beta_rec.recommenders import VBCAR

for lr in [0.001]:
    config["lr"] = lr
    model = VBCAR(config)
    model.train(data)
    model.test(data.test[0])
# @To be discussed
# model.train(train_df)
# Case 1, without validation, stop training by loss or max_epoch

# model.train(train_df,valid_df[0])
# Case 2, with validation, stop training by performance on validation set

# model.train(train_df,valid_df[0],test_df[0])
# Case 3, same as Case 2, but also evaluate performance for each epoch on test set.

# Note that the best model will be save automatically, and record the model-save-dir.
# Out:
# Search default config file in /home/zm324/anaconda3/envs/beta_rec/configs/vbcar_default.json
# Found default config file in /home/zm324/anaconda3/envs/beta_rec/configs/vbcar_default.json
# loading config file /home/zm324/anaconda3/envs/beta_rec/configs/vbcar_default.json
# --------------------------------------------------------------------------------
# Received parameters from command line (or default):
# +----+------------------+----------+
# |    | keys             |   values |
# |----+------------------+----------|
# |  0 | model:n_sample   |    1e+06 |
# |  1 | model:max_epoch  |   80     |
# |  2 | model:emb_dim    |   64     |
# |  3 | model:batch_size | 1024     |
# |  4 | model:lr         |    0.001 |
# +----+------------------+----------+
# --------------------------------------------------------------------------------
# logs will save in file: /home/zm324/workspace/logs/VBCAR_default_20211129_154303_murihu .stdout.log .stderr.log
# 2021-11-29 15:43:03 [INFO]-
# Python version: 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0
# 2021-11-29 15:43:03 [INFO]-
# 2021-11-29 15:43:03 [INFO]-Pytorch version: 1.7.1
# 2021-11-29 15:43:03 [INFO]-The intermediate running statuses will be reported in folder: /home/zm324/workspace/runs/VBCAR_default_20211129_154303_murihu
# 2021-11-29 15:43:03 [INFO]-Model checkpoint will save in file: /home/zm324/workspace/checkpoints/VBCAR_default_20211129_154303_murihu
# 2021-11-29 15:43:03 [INFO]-Performance result will save in file: /home/zm324/workspace/results/vbcar_result.csv
# 2021-11-29 15:43:03 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:43:03 [INFO]-System configs
# 2021-11-29 15:43:03 [INFO]-
# +----+----------------+------------------------------------------------------------------------+
# |    | keys           | values                                                                 |
# |----+----------------+------------------------------------------------------------------------|
# |  0 | root_dir       | /home/zm324/workspace                                                  |
# |  1 | log_dir        | logs/                                                                  |
# |  2 | result_dir     | results/                                                               |
# |  3 | process_dir    | /home/zm324/workspace/processes/                                       |
# |  4 | checkpoint_dir | checkpoints/                                                           |
# |  5 | dataset_dir    | datasets/                                                              |
# |  6 | run_dir        | /home/zm324/workspace/runs/VBCAR_default_20211129_154303_murihu        |
# |  7 | tune_dir       | /home/zm324/workspace/tune_results/                                    |
# |  8 | device         | gpu                                                                    |
# |  9 | seed           | 2020                                                                   |
# | 10 | metrics        | ['ndcg', 'precision', 'recall', 'map']                                 |
# | 11 | k              | [5, 10, 20]                                                            |
# | 12 | valid_metric   | ndcg                                                                   |
# | 13 | valid_k        | 10                                                                     |
# | 14 | result_file    | /home/zm324/workspace/results/vbcar_result.csv                         |
# | 15 | save_mode      | average                                                                |
# | 16 | model_run_id   | VBCAR_default_20211129_154303_murihu                                   |
# | 17 | log_file       | /home/zm324/workspace/logs/VBCAR_default_20211129_154303_murihu        |
# | 18 | model_save_dir | /home/zm324/workspace/checkpoints/VBCAR_default_20211129_154303_murihu |
# +----+----------------+------------------------------------------------------------------------
# 2021-11-29 15:43:03 [INFO]-
# 2021-11-29 15:43:03 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:43:03 [ERROR]-Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# 2021-11-29 15:43:03 [ERROR]-wandb: Currently logged in as: mengzaiqiao (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/mengzaiqiao/VBCAR/runs/4wyinuxe" target="_blank">fallen-glade-4</a></strong> to <a href="https://wandb.ai/mengzaiqiao/VBCAR" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# 2021-11-29 15:43:04 [INFO]-Get a gpu with the most available memory : 2
# 2021-11-29 15:43:04 [INFO]-Initializing test engine ...
# 2021-11-29 15:43:04 [INFO]-Get a gpu with the most available memory : 2
# 2021-11-29 15:43:06 [INFO]-Setting device for torch_engine cuda:2
# 2021-11-29 15:43:06 [INFO]-
# VBCAR(
#   (user_emb): Embedding(23093, 64)
#   (item_emb): Embedding(14565, 64)
#   (fc_u_1_mu): Linear(in_features=512, out_features=256, bias=True)
#   (fc_u_2_mu): Linear(in_features=256, out_features=128, bias=True)
#   (fc_i_1_mu): Linear(in_features=512, out_features=256, bias=True)
#   (fc_i_2_mu): Linear(in_features=256, out_features=128, bias=True)
#
# 2021-11-29 15:43:06 [INFO]-
# 2021-11-29 15:43:07 [INFO]-Initialize Sampler!
# 2021-11-29 15:43:07 [INFO]-Preparing training triples ...
# 2021-11-29 15:43:09 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:43:09 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:43:09 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:43:09 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:43:09 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 100%|##########| 1000000/1000000 [01:43<00:00, 9670.92it/s]
# 2021-11-29 15:45:11 [INFO]-done!
#   0%|          | 0/80 [00:00<?, ?it/s]Epoch 0 starts !
# 2021-11-29 15:45:12 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:46:39 [INFO]-[Training Epoch 0], log_like_loss 8.090019000228494 kl_loss: 0.966013843069959 alpha: 0.001 lr: 0.001
# 2021-11-29 15:46:39 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:46:39 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:46:39 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:46:39 [INFO]-Execute [train_an_epoch] method costing 86631.74 ms
#   1%|1         | 1/80 [01:39<2:10:50, 99.37s/it]Epoch 1 starts !
# 2021-11-29 15:46:52 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:48:51 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:48:51 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:48:51 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:48:51 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:48:51 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:48:51 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:48:51 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:48:51 [ERROR]-wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# 2021-11-29 15:48:51 [INFO]-Current testEngine.best_valid_performance 0
# 2021-11-29 15:48:51 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:48:51 [INFO]-performance on validation at epoch 0
# 2021-11-29 15:48:51 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.388115  |
# |  1 | precision@10 | 0.360187  |
# |  2 | recall@10    | 0.120564  |
# |  3 | map@10       | 0.0741507 |
# +----+--------------+-----------
# 2021-11-29 15:48:51 [INFO]-
# 2021-11-29 15:48:51 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:48:51 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:48:51 [INFO]-performance on testing at epoch 0
# 2021-11-29 15:48:51 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.389701  |
# |  1 | precision@10 | 0.361224  |
# |  2 | recall@10    | 0.120357  |
# |  3 | map@10       | 0.0746329 |
# +----+--------------+-----------
# 2021-11-29 15:48:51 [INFO]-
# 2021-11-29 15:48:51 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:48:51 [INFO]-Execute [train_eval_worker] method costing 119103.62 ms
# 2021-11-29 15:50:08 [INFO]-[Training Epoch 1], log_like_loss 7.132687772624195 kl_loss: 2.0089772935025394 alpha: 0.001 lr: 0.001
# 2021-11-29 15:50:08 [INFO]-Execute [train_an_epoch] method costing 195777.88 ms
#   2%|2         | 2/80 [05:08<2:51:49, 132.17s/it]Epoch 2 starts !
# 2021-11-29 15:50:20 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:52:32 [INFO]-Current testEngine.best_valid_performance 0.38811520859754606
# 2021-11-29 15:52:32 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:52:32 [INFO]-performance on validation at epoch 1
# 2021-11-29 15:52:32 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.404144  |
# |  1 | precision@10 | 0.373855  |
# |  2 | recall@10    | 0.126139  |
# |  3 | map@10       | 0.0793062 |
# +----+--------------+-----------
# 2021-11-29 15:52:32 [INFO]-
# 2021-11-29 15:52:32 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:52:32 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:52:32 [INFO]-performance on testing at epoch 1
# 2021-11-29 15:52:32 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.403856  |
# |  1 | precision@10 | 0.373518  |
# |  2 | recall@10    | 0.124577  |
# |  3 | map@10       | 0.0791197 |
# +----+--------------+-----------
# 2021-11-29 15:52:32 [INFO]-
# 2021-11-29 15:52:32 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:52:32 [INFO]-Execute [train_eval_worker] method costing 131577.68 ms
# 2021-11-29 15:53:52 [INFO]-[Training Epoch 2], log_like_loss 9.636042823233214e+16 kl_loss: 8.861746858572587 alpha: 0.001 lr: 0.001
# 2021-11-29 15:53:52 [INFO]-Execute [train_an_epoch] method costing 211116.38 ms
#   4%|3         | 3/80 [08:52<3:25:02, 159.77s/it]Epoch 3 starts !
# 2021-11-29 15:54:05 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:56:12 [INFO]-number of epochs that have no update 1
# 2021-11-29 15:56:12 [INFO]-Execute [train_eval_worker] method costing 127707.86 ms
# 2021-11-29 15:57:32 [INFO]-[Training Epoch 3], log_like_loss 944867216865984.4 kl_loss: 14.805341728031635 alpha: 0.001 lr: 0.001
# 2021-11-29 15:57:32 [INFO]-Execute [train_an_epoch] method costing 207484.18 ms
#   5%|5         | 4/80 [12:33<3:45:39, 178.15s/it]Epoch 4 starts !
# 2021-11-29 15:57:46 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 15:59:56 [INFO]-number of epochs that have no update 2
# 2021-11-29 15:59:56 [INFO]-Execute [train_eval_worker] method costing 130079.35 ms
# 2021-11-29 16:01:15 [INFO]-[Training Epoch 4], log_like_loss 448889036495.12256 kl_loss: 14.546570738777518 alpha: 0.001 lr: 0.001
# 2021-11-29 16:01:15 [INFO]-Execute [train_an_epoch] method costing 209506.17 ms
#   6%|6         | 5/80 [16:16<3:59:39, 191.73s/it]Epoch 5 starts !
# 2021-11-29 16:01:29 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:03:39 [INFO]-number of epochs that have no update 3
# 2021-11-29 16:03:39 [INFO]-Execute [train_eval_worker] method costing 129922.99 ms
# 2021-11-29 16:05:00 [INFO]-[Training Epoch 5], log_like_loss 10280850712.75586 kl_loss: 14.273427767679095 alpha: 0.001 lr: 0.001
# 2021-11-29 16:05:00 [INFO]-Execute [train_an_epoch] method costing 210534.30 ms
#   8%|7         | 6/80 [20:00<4:08:13, 201.26s/it]Epoch 6 starts !
# 2021-11-29 16:05:13 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:07:23 [INFO]-number of epochs that have no update 4
# 2021-11-29 16:07:23 [INFO]-Execute [train_eval_worker] method costing 129991.67 ms
# 2021-11-29 16:08:43 [INFO]-[Training Epoch 6], log_like_loss 994082351.0915813 kl_loss: 13.7392303859815 alpha: 0.001 lr: 0.001
# 2021-11-29 16:08:43 [INFO]-Execute [train_an_epoch] method costing 209970.28 ms
#   9%|8         | 7/80 [23:42<4:12:39, 207.67s/it]Epoch 7 starts !
# 2021-11-29 16:08:55 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:11:04 [INFO]-number of epochs that have no update 5
# 2021-11-29 16:11:04 [INFO]-Execute [train_eval_worker] method costing 128392.14 ms
# 2021-11-29 16:12:24 [INFO]-[Training Epoch 7], log_like_loss 3569867.74669075 kl_loss: 13.111353387124836 alpha: 0.001 lr: 0.001
# 2021-11-29 16:12:24 [INFO]-Execute [train_an_epoch] method costing 208819.45 ms
#  10%|#         | 8/80 [27:24<4:14:06, 211.76s/it]Epoch 8 starts !
# 2021-11-29 16:12:37 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:14:36 [INFO]-number of epochs that have no update 6
# 2021-11-29 16:14:36 [INFO]-Execute [train_eval_worker] method costing 119747.76 ms
# 2021-11-29 16:15:54 [INFO]-[Training Epoch 8], log_like_loss 60057.771443128586 kl_loss: 12.494478547014296 alpha: 0.001 lr: 0.001
# 2021-11-29 16:15:54 [INFO]-Execute [train_an_epoch] method costing 197042.09 ms
#  11%|#1        | 9/80 [30:53<4:09:51, 211.15s/it]Epoch 9 starts !
# 2021-11-29 16:16:06 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:18:10 [INFO]-number of epochs that have no update 7
# 2021-11-29 16:18:10 [INFO]-Execute [train_eval_worker] method costing 123627.16 ms
# 2021-11-29 16:19:26 [INFO]-[Training Epoch 9], log_like_loss 25489.269715655595 kl_loss: 11.974463100545108 alpha: 0.001 lr: 0.001
# 2021-11-29 16:19:26 [INFO]-Execute [train_an_epoch] method costing 200226.33 ms
#  12%|#2        | 10/80 [34:27<4:07:03, 211.76s/it]Epoch 10 starts !
# 2021-11-29 16:19:39 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:21:41 [INFO]-number of epochs that have no update 8
# 2021-11-29 16:21:41 [INFO]-Execute [train_eval_worker] method costing 121332.50 ms
# 2021-11-29 16:22:57 [INFO]-[Training Epoch 10], log_like_loss 36569631.79116286 kl_loss: 14.514889602549374 alpha: 0.001 lr: 0.001
# 2021-11-29 16:22:57 [INFO]-Execute [train_an_epoch] method costing 197886.70 ms
#  14%|#3        | 11/80 [37:58<4:03:28, 211.72s/it]Epoch 11 starts !
# 2021-11-29 16:23:11 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:25:13 [INFO]-number of epochs that have no update 9
# 2021-11-29 16:25:13 [INFO]-Execute [train_eval_worker] method costing 122387.51 ms
# 2021-11-29 16:26:29 [INFO]-[Training Epoch 11], log_like_loss 105008.15133296326 kl_loss: 14.212198839522898 alpha: 0.001 lr: 0.001
# 2021-11-29 16:26:29 [INFO]-Execute [train_an_epoch] method costing 198148.91 ms
#  15%|#5        | 12/80 [41:30<4:00:02, 211.80s/it]Epoch 12 starts !
# 2021-11-29 16:26:43 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:28:44 [INFO]-number of epochs that have no update 10
# 2021-11-29 16:28:44 [INFO]-Execute [train_eval_worker] method costing 120970.81 ms
# 2021-11-29 16:30:00 [INFO]-[Training Epoch 12], log_like_loss 3165.46304048039 kl_loss: 14.172361050732434 alpha: 0.001 lr: 0.001
# 2021-11-29 16:30:00 [INFO]-Execute [train_an_epoch] method costing 197222.72 ms
#  16%|#6        | 13/80 [45:00<3:55:53, 211.24s/it]Epoch 13 starts !
# 2021-11-29 16:30:13 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:32:26 [INFO]-number of epochs that have no update 11
# 2021-11-29 16:32:26 [INFO]-Execute [train_eval_worker] method costing 132974.59 ms
# 2021-11-29 16:33:47 [INFO]-[Training Epoch 13], log_like_loss 10174.283548450097 kl_loss: 15.274008329957724 alpha: 0.001 lr: 0.001
# 2021-11-29 16:33:47 [INFO]-Execute [train_an_epoch] method costing 213699.95 ms
#  18%|#7        | 14/80 [48:47<3:57:26, 215.85s/it]Epoch 14 starts !
# 2021-11-29 16:34:00 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:35:59 [INFO]-number of epochs that have no update 12
# 2021-11-29 16:35:59 [INFO]-Execute [train_eval_worker] method costing 119495.39 ms
# 2021-11-29 16:37:16 [INFO]-[Training Epoch 14], log_like_loss 440.75964028574526 kl_loss: 15.708447212353349 alpha: 0.001 lr: 0.001
# 2021-11-29 16:37:16 [INFO]-Execute [train_an_epoch] method costing 195999.52 ms
#  19%|#8        | 15/80 [52:15<3:51:22, 213.57s/it]Epoch 15 starts !
# 2021-11-29 16:37:28 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:39:29 [INFO]-number of epochs that have no update 13
# 2021-11-29 16:39:29 [INFO]-Execute [train_eval_worker] method costing 121248.56 ms
# 2021-11-29 16:40:46 [INFO]-[Training Epoch 15], log_like_loss 14.001367800403386 kl_loss: 15.888286521658301 alpha: 0.001 lr: 0.001
# 2021-11-29 16:40:46 [INFO]-Execute [train_an_epoch] method costing 197995.64 ms
#  20%|##        | 16/80 [55:45<3:46:48, 212.64s/it]Epoch 16 starts !
# 2021-11-29 16:40:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:42:58 [INFO]-Current testEngine.best_valid_performance 0.4041436041212958
# 2021-11-29 16:42:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:42:58 [INFO]-performance on validation at epoch 15
# 2021-11-29 16:42:58 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.421066 |
# |  1 | precision@10 | 0.400489 |
# |  2 | recall@10    | 0.137473 |
# |  3 | map@10       | 0.086286 |
# +----+--------------+----------
# 2021-11-29 16:42:58 [INFO]-
# 2021-11-29 16:42:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:42:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:42:58 [INFO]-performance on testing at epoch 15
# 2021-11-29 16:42:58 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.420757  |
# |  1 | precision@10 | 0.399955  |
# |  2 | recall@10    | 0.136335  |
# |  3 | map@10       | 0.0858112 |
# +----+--------------+-----------
# 2021-11-29 16:42:58 [INFO]-
# 2021-11-29 16:42:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:42:58 [INFO]-Execute [train_eval_worker] method costing 119525.89 ms
# 2021-11-29 16:44:15 [INFO]-[Training Epoch 16], log_like_loss 4.599328151438385 kl_loss: 14.8230502596125 alpha: 0.001 lr: 0.001
# 2021-11-29 16:44:15 [INFO]-Execute [train_an_epoch] method costing 196484.98 ms
#  21%|##1       | 17/80 [59:14<3:42:01, 211.45s/it]Epoch 17 starts !
# 2021-11-29 16:44:27 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:46:40 [INFO]-Current testEngine.best_valid_performance 0.421066125385523
# 2021-11-29 16:46:40 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:46:40 [INFO]-performance on validation at epoch 16
# 2021-11-29 16:46:40 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.430608  |
# |  1 | precision@10 | 0.408392  |
# |  2 | recall@10    | 0.140392  |
# |  3 | map@10       | 0.0890981 |
# +----+--------------+-----------
# 2021-11-29 16:46:40 [INFO]-
# 2021-11-29 16:46:40 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:46:40 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:46:40 [INFO]-performance on testing at epoch 16
# 2021-11-29 16:46:40 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.431169  |
# |  1 | precision@10 | 0.408813  |
# |  2 | recall@10    | 0.139455  |
# |  3 | map@10       | 0.0889641 |
# +----+--------------+-----------
# 2021-11-29 16:46:40 [INFO]-
# 2021-11-29 16:46:40 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:46:40 [INFO]-Execute [train_eval_worker] method costing 133241.29 ms
# 2021-11-29 16:48:02 [INFO]-[Training Epoch 17], log_like_loss 4.317744819447398 kl_loss: 8.644735908135772 alpha: 0.001 lr: 0.001
# 2021-11-29 16:48:02 [INFO]-Execute [train_an_epoch] method costing 214634.84 ms
#  22%|##2       | 18/80 [1:03:01<3:43:18, 216.11s/it]Epoch 18 starts !
# 2021-11-29 16:48:14 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:50:24 [INFO]-Current testEngine.best_valid_performance 0.43060771959909766
# 2021-11-29 16:50:24 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:50:24 [INFO]-performance on validation at epoch 17
# 2021-11-29 16:50:24 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.439547  |
# |  1 | precision@10 | 0.415929  |
# |  2 | recall@10    | 0.14295   |
# |  3 | map@10       | 0.0917461 |
# +----+--------------+-----------
# 2021-11-29 16:50:24 [INFO]-
# 2021-11-29 16:50:24 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:50:24 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:50:24 [INFO]-performance on testing at epoch 17
# 2021-11-29 16:50:24 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.439712  |
# |  1 | precision@10 | 0.415664  |
# |  2 | recall@10    | 0.141281  |
# |  3 | map@10       | 0.0914831 |
# +----+--------------+-----------
# 2021-11-29 16:50:24 [INFO]-
# 2021-11-29 16:50:24 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:50:24 [INFO]-Execute [train_eval_worker] method costing 130441.65 ms
# 2021-11-29 16:51:45 [INFO]-[Training Epoch 18], log_like_loss 4.162615893408656 kl_loss: 3.302946754032746 alpha: 0.001 lr: 0.001
# 2021-11-29 16:51:45 [INFO]-Execute [train_an_epoch] method costing 211301.05 ms
#  24%|##3       | 19/80 [1:06:45<3:41:58, 218.34s/it]Epoch 19 starts !
# 2021-11-29 16:51:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:53:57 [INFO]-Current testEngine.best_valid_performance 0.4395474806502354
# 2021-11-29 16:53:57 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:53:57 [INFO]-performance on validation at epoch 18
# 2021-11-29 16:53:57 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.449699  |
# |  1 | precision@10 | 0.425068  |
# |  2 | recall@10    | 0.145778  |
# |  3 | map@10       | 0.0945969 |
# +----+--------------+-----------
# 2021-11-29 16:53:57 [INFO]-
# 2021-11-29 16:53:57 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:53:57 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:53:57 [INFO]-performance on testing at epoch 18
# 2021-11-29 16:53:57 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.448965  |
# |  1 | precision@10 | 0.424111  |
# |  2 | recall@10    | 0.144189  |
# |  3 | map@10       | 0.0941537 |
# +----+--------------+-----------
# 2021-11-29 16:53:57 [INFO]-
# 2021-11-29 16:53:57 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:53:57 [INFO]-Execute [train_eval_worker] method costing 119126.35 ms
# 2021-11-29 16:55:13 [INFO]-[Training Epoch 19], log_like_loss 4.067353853024542 kl_loss: 2.7908946415409446 alpha: 0.001 lr: 0.001
# 2021-11-29 16:55:13 [INFO]-Execute [train_an_epoch] method costing 195899.25 ms
#  25%|##5       | 20/80 [1:10:13<3:35:20, 215.34s/it]Epoch 20 starts !
# 2021-11-29 16:55:26 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:57:24 [INFO]-Current testEngine.best_valid_performance 0.44969875884692245
# 2021-11-29 16:57:24 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:57:24 [INFO]-performance on validation at epoch 19
# 2021-11-29 16:57:24 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.459865  |
# |  1 | precision@10 | 0.43438   |
# |  2 | recall@10    | 0.148909  |
# |  3 | map@10       | 0.0977422 |
# +----+--------------+-----------
# 2021-11-29 16:57:24 [INFO]-
# 2021-11-29 16:57:24 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:57:24 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:57:24 [INFO]-performance on testing at epoch 19
# 2021-11-29 16:57:24 [INFO]-
# +----+--------------+-----------+
# |    | metrics      |    values |
# |----+--------------+-----------|
# |  0 | ndcg@10      | 0.460032  |
# |  1 | precision@10 | 0.434127  |
# |  2 | recall@10    | 0.147563  |
# |  3 | map@10       | 0.0975832 |
# +----+--------------+-----------
# 2021-11-29 16:57:24 [INFO]-
# 2021-11-29 16:57:24 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 16:57:24 [INFO]-Execute [train_eval_worker] method costing 118024.47 ms
# 2021-11-29 16:58:40 [INFO]-[Training Epoch 20], log_like_loss 3.9959821673110127 kl_loss: 2.882041266420856 alpha: 0.001 lr: 0.001
# 2021-11-29 16:58:40 [INFO]-Execute [train_an_epoch] method costing 194278.41 ms
#  26%|##6       | 21/80 [1:13:40<3:29:17, 212.83s/it]Epoch 21 starts !
# 2021-11-29 16:58:53 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:00:52 [INFO]-Current testEngine.best_valid_performance 0.4598654012804868
# 2021-11-29 17:00:52 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:00:52 [INFO]-performance on validation at epoch 20
# 2021-11-29 17:00:52 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.471798 |
# |  1 | precision@10 | 0.445722 |
# |  2 | recall@10    | 0.152884 |
# |  3 | map@10       | 0.101525 |
# +----+--------------+----------
# 2021-11-29 17:00:52 [INFO]-
# 2021-11-29 17:00:52 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:00:52 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:00:52 [INFO]-performance on testing at epoch 20
# 2021-11-29 17:00:52 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.470899 |
# |  1 | precision@10 | 0.443728 |
# |  2 | recall@10    | 0.150956 |
# |  3 | map@10       | 0.101107 |
# +----+--------------+----------
# 2021-11-29 17:00:52 [INFO]-
# 2021-11-29 17:00:52 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:00:52 [INFO]-Execute [train_eval_worker] method costing 118891.55 ms
# 2021-11-29 17:02:09 [INFO]-[Training Epoch 21], log_like_loss 3.9371078023687005 kl_loss: 2.9751993445679545 alpha: 0.001 lr: 0.001
# 2021-11-29 17:02:09 [INFO]-Execute [train_an_epoch] method costing 196429.48 ms
#  28%|##7       | 22/80 [1:17:09<3:24:33, 211.61s/it]Epoch 22 starts !
# 2021-11-29 17:02:22 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:04:23 [INFO]-Current testEngine.best_valid_performance 0.47179753076152303
# 2021-11-29 17:04:23 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:04:23 [INFO]-performance on validation at epoch 21
# 2021-11-29 17:04:23 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.483177 |
# |  1 | precision@10 | 0.456529 |
# |  2 | recall@10    | 0.156812 |
# |  3 | map@10       | 0.105254 |
# +----+--------------+----------
# 2021-11-29 17:04:23 [INFO]-
# 2021-11-29 17:04:23 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:04:23 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:04:23 [INFO]-performance on testing at epoch 21
# 2021-11-29 17:04:23 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.483145 |
# |  1 | precision@10 | 0.455955 |
# |  2 | recall@10    | 0.155264 |
# |  3 | map@10       | 0.104961 |
# +----+--------------+----------
# 2021-11-29 17:04:23 [INFO]-
# 2021-11-29 17:04:23 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:04:23 [INFO]-Execute [train_eval_worker] method costing 121473.19 ms
# 2021-11-29 17:05:39 [INFO]-[Training Epoch 22], log_like_loss 3.8916418603621423 kl_loss: 3.070236441679299 alpha: 0.001 lr: 0.001
# 2021-11-29 17:05:39 [INFO]-Execute [train_an_epoch] method costing 197877.71 ms
#  29%|##8       | 23/80 [1:20:39<3:20:32, 211.10s/it]Epoch 23 starts !
# 2021-11-29 17:05:51 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:08:01 [INFO]-Current testEngine.best_valid_performance 0.48317658222092763
# 2021-11-29 17:08:01 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:08:01 [INFO]-performance on validation at epoch 22
# 2021-11-29 17:08:01 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.495602 |
# |  1 | precision@10 | 0.46743  |
# |  2 | recall@10    | 0.160723 |
# |  3 | map@10       | 0.109546 |
# +----+--------------+----------
# 2021-11-29 17:08:01 [INFO]-
# 2021-11-29 17:08:01 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:08:01 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:08:01 [INFO]-performance on testing at epoch 22
# 2021-11-29 17:08:01 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.494674 |
# |  1 | precision@10 | 0.46672  |
# |  2 | recall@10    | 0.15912  |
# |  3 | map@10       | 0.108817 |
# +----+--------------+----------
# 2021-11-29 17:08:01 [INFO]-
# 2021-11-29 17:08:01 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:08:01 [INFO]-Execute [train_eval_worker] method costing 129490.53 ms
# 2021-11-29 17:09:21 [INFO]-[Training Epoch 23], log_like_loss 3.853018052643165 kl_loss: 3.122663964983076 alpha: 0.001 lr: 0.001
# 2021-11-29 17:09:21 [INFO]-Execute [train_an_epoch] method costing 209320.00 ms
#  30%|###       | 24/80 [1:24:20<3:19:58, 214.26s/it]Epoch 24 starts !
# 2021-11-29 17:09:33 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:11:29 [INFO]-Current testEngine.best_valid_performance 0.4956022348021551
# 2021-11-29 17:11:29 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:11:29 [INFO]-performance on validation at epoch 23
# 2021-11-29 17:11:29 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.508784 |
# |  1 | precision@10 | 0.480343 |
# |  2 | recall@10    | 0.165559 |
# |  3 | map@10       | 0.114068 |
# +----+--------------+----------
# 2021-11-29 17:11:29 [INFO]-
# 2021-11-29 17:11:29 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:11:29 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:11:29 [INFO]-performance on testing at epoch 23
# 2021-11-29 17:11:29 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.507114 |
# |  1 | precision@10 | 0.478965 |
# |  2 | recall@10    | 0.16386  |
# |  3 | map@10       | 0.113212 |
# +----+--------------+----------
# 2021-11-29 17:11:29 [INFO]-
# 2021-11-29 17:11:29 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:11:29 [INFO]-Execute [train_eval_worker] method costing 116218.57 ms
# 2021-11-29 17:12:46 [INFO]-[Training Epoch 24], log_like_loss 3.82090985449031 kl_loss: 3.2307132612913847 alpha: 0.001 lr: 0.001
# 2021-11-29 17:12:46 [INFO]-Execute [train_an_epoch] method costing 192621.09 ms
#  31%|###1      | 25/80 [1:27:45<3:13:49, 211.45s/it]Epoch 25 starts !
# 2021-11-29 17:12:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:14:59 [INFO]-Current testEngine.best_valid_performance 0.5087839396332915
# 2021-11-29 17:14:59 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:14:59 [INFO]-performance on validation at epoch 24
# 2021-11-29 17:14:59 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.520144 |
# |  1 | precision@10 | 0.490776 |
# |  2 | recall@10    | 0.16947  |
# |  3 | map@10       | 0.11827  |
# +----+--------------+----------
# 2021-11-29 17:14:59 [INFO]-
# 2021-11-29 17:14:59 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:14:59 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:14:59 [INFO]-performance on testing at epoch 24
# 2021-11-29 17:14:59 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.519245 |
# |  1 | precision@10 | 0.490002 |
# |  2 | recall@10    | 0.167932 |
# |  3 | map@10       | 0.117652 |
# +----+--------------+----------
# 2021-11-29 17:14:59 [INFO]-
# 2021-11-29 17:14:59 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:14:59 [INFO]-Execute [train_eval_worker] method costing 121141.06 ms
# 2021-11-29 17:16:16 [INFO]-[Training Epoch 25], log_like_loss 3.79658514354378 kl_loss: 3.2170832289848477 alpha: 0.001 lr: 0.001
# 2021-11-29 17:16:16 [INFO]-Execute [train_an_epoch] method costing 197739.98 ms
#  32%|###2      | 26/80 [1:31:15<3:09:53, 210.98s/it]Epoch 26 starts !
# 2021-11-29 17:16:28 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:18:27 [INFO]-Current testEngine.best_valid_performance 0.5201444184680998
# 2021-11-29 17:18:27 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:18:27 [INFO]-performance on validation at epoch 25
# 2021-11-29 17:18:27 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.531807 |
# |  1 | precision@10 | 0.501313 |
# |  2 | recall@10    | 0.173317 |
# |  3 | map@10       | 0.122501 |
# +----+--------------+----------
# 2021-11-29 17:18:27 [INFO]-
# 2021-11-29 17:18:27 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:18:27 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:18:27 [INFO]-performance on testing at epoch 25
# 2021-11-29 17:18:27 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.531154 |
# |  1 | precision@10 | 0.50111  |
# |  2 | recall@10    | 0.172201 |
# |  3 | map@10       | 0.121849 |
# +----+--------------+----------
# 2021-11-29 17:18:27 [INFO]-
# 2021-11-29 17:18:27 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:18:27 [INFO]-Execute [train_eval_worker] method costing 119153.87 ms
# 2021-11-29 17:19:43 [INFO]-[Training Epoch 26], log_like_loss 3.7766582518815994 kl_loss: 3.2352452704217285 alpha: 0.001 lr: 0.001
# 2021-11-29 17:19:43 [INFO]-Execute [train_an_epoch] method costing 194906.40 ms
#  34%|###3      | 27/80 [1:34:43<3:05:30, 210.02s/it]Epoch 27 starts !
# 2021-11-29 17:19:56 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:21:55 [INFO]-Current testEngine.best_valid_performance 0.5318071462436104
# 2021-11-29 17:21:55 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:21:55 [INFO]-performance on validation at epoch 26
# 2021-11-29 17:21:55 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.543877 |
# |  1 | precision@10 | 0.512587 |
# |  2 | recall@10    | 0.178257 |
# |  3 | map@10       | 0.127008 |
# +----+--------------+----------
# 2021-11-29 17:21:55 [INFO]-
# 2021-11-29 17:21:55 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:21:55 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:21:55 [INFO]-performance on testing at epoch 26
# 2021-11-29 17:21:55 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.542809 |
# |  1 | precision@10 | 0.511821 |
# |  2 | recall@10    | 0.176156 |
# |  3 | map@10       | 0.126043 |
# +----+--------------+----------
# 2021-11-29 17:21:55 [INFO]-
# 2021-11-29 17:21:55 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:21:55 [INFO]-Execute [train_eval_worker] method costing 119196.98 ms
# 2021-11-29 17:23:11 [INFO]-[Training Epoch 27], log_like_loss 3.7575124581344426 kl_loss: 3.2605931530706584 alpha: 0.001 lr: 0.001
# 2021-11-29 17:23:11 [INFO]-Execute [train_an_epoch] method costing 194985.81 ms
#  35%|###5      | 28/80 [1:38:10<3:01:17, 209.18s/it]Epoch 28 starts !
# 2021-11-29 17:23:23 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:25:22 [INFO]-Current testEngine.best_valid_performance 0.543876652432851
# 2021-11-29 17:25:22 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:25:22 [INFO]-performance on validation at epoch 27
# 2021-11-29 17:25:22 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.55536  |
# |  1 | precision@10 | 0.523235 |
# |  2 | recall@10    | 0.182512 |
# |  3 | map@10       | 0.131507 |
# +----+--------------+----------
# 2021-11-29 17:25:22 [INFO]-
# 2021-11-29 17:25:22 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:25:22 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:25:22 [INFO]-performance on testing at epoch 27
# 2021-11-29 17:25:22 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.55521  |
# |  1 | precision@10 | 0.523692 |
# |  2 | recall@10    | 0.180914 |
# |  3 | map@10       | 0.130732 |
# +----+--------------+----------
# 2021-11-29 17:25:22 [INFO]-
# 2021-11-29 17:25:22 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:25:22 [INFO]-Execute [train_eval_worker] method costing 119223.95 ms
# 2021-11-29 17:26:38 [INFO]-[Training Epoch 28], log_like_loss 3.742198860272765 kl_loss: 3.264176858589053 alpha: 0.001 lr: 0.001
# 2021-11-29 17:26:38 [INFO]-Execute [train_an_epoch] method costing 195133.80 ms
#  36%|###6      | 29/80 [1:41:37<2:57:15, 208.54s/it]Epoch 29 starts !
# 2021-11-29 17:26:50 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:28:53 [INFO]-Current testEngine.best_valid_performance 0.555360486446058
# 2021-11-29 17:28:53 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:28:53 [INFO]-performance on validation at epoch 28
# 2021-11-29 17:28:53 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.566542 |
# |  1 | precision@10 | 0.53386  |
# |  2 | recall@10    | 0.186804 |
# |  3 | map@10       | 0.135865 |
# +----+--------------+----------
# 2021-11-29 17:28:53 [INFO]-
# 2021-11-29 17:28:53 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:28:53 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:28:53 [INFO]-performance on testing at epoch 28
# 2021-11-29 17:28:53 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.565296 |
# |  1 | precision@10 | 0.53254  |
# |  2 | recall@10    | 0.184837 |
# |  3 | map@10       | 0.135018 |
# +----+--------------+----------
# 2021-11-29 17:28:53 [INFO]-
# 2021-11-29 17:28:53 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:28:53 [INFO]-Execute [train_eval_worker] method costing 123126.95 ms
# 2021-11-29 17:30:09 [INFO]-[Training Epoch 29], log_like_loss 3.7296644672751427 kl_loss: 3.31019100244157 alpha: 0.001 lr: 0.001
# 2021-11-29 17:30:09 [INFO]-Execute [train_an_epoch] method costing 198744.62 ms
#  38%|###7      | 30/80 [1:45:08<2:54:17, 209.14s/it]Epoch 30 starts !
# 2021-11-29 17:30:20 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:32:19 [INFO]-Current testEngine.best_valid_performance 0.5665424771166634
# 2021-11-29 17:32:19 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:32:19 [INFO]-performance on validation at epoch 29
# 2021-11-29 17:32:19 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.57688  |
# |  1 | precision@10 | 0.54327  |
# |  2 | recall@10    | 0.190399 |
# |  3 | map@10       | 0.140026 |
# +----+--------------+----------
# 2021-11-29 17:32:19 [INFO]-
# 2021-11-29 17:32:19 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:32:19 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:32:19 [INFO]-performance on testing at epoch 29
# 2021-11-29 17:32:19 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.576068 |
# |  1 | precision@10 | 0.542248 |
# |  2 | recall@10    | 0.188695 |
# |  3 | map@10       | 0.139022 |
# +----+--------------+----------
# 2021-11-29 17:32:19 [INFO]-
# 2021-11-29 17:32:19 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:32:19 [INFO]-Execute [train_eval_worker] method costing 118170.67 ms
# 2021-11-29 17:33:35 [INFO]-[Training Epoch 30], log_like_loss 3.7181211670394987 kl_loss: 3.304693025071174 alpha: 0.001 lr: 0.001
# 2021-11-29 17:33:35 [INFO]-Execute [train_an_epoch] method costing 194167.91 ms
#  39%|###8      | 31/80 [1:48:34<2:50:02, 208.21s/it]Epoch 31 starts !
# 2021-11-29 17:33:47 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:35:55 [INFO]-Current testEngine.best_valid_performance 0.576879726014309
# 2021-11-29 17:35:55 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:35:55 [INFO]-performance on validation at epoch 30
# 2021-11-29 17:35:55 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.587181 |
# |  1 | precision@10 | 0.552231 |
# |  2 | recall@10    | 0.194211 |
# |  3 | map@10       | 0.144329 |
# +----+--------------+----------
# 2021-11-29 17:35:55 [INFO]-
# 2021-11-29 17:35:55 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:35:55 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:35:55 [INFO]-performance on testing at epoch 30
# 2021-11-29 17:35:55 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.586437 |
# |  1 | precision@10 | 0.552095 |
# |  2 | recall@10    | 0.192558 |
# |  3 | map@10       | 0.143198 |
# +----+--------------+----------
# 2021-11-29 17:35:55 [INFO]-
# 2021-11-29 17:35:55 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:35:55 [INFO]-Execute [train_eval_worker] method costing 128501.18 ms
# 2021-11-29 17:37:15 [INFO]-[Training Epoch 31], log_like_loss 3.7072418238967657 kl_loss: 3.2924575861543417 alpha: 0.001 lr: 0.001
# 2021-11-29 17:37:15 [INFO]-Execute [train_an_epoch] method costing 208607.79 ms
#  40%|####      | 32/80 [1:52:14<2:49:34, 211.96s/it]Epoch 32 starts !
# 2021-11-29 17:37:27 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:39:35 [INFO]-Current testEngine.best_valid_performance 0.5871811265494327
# 2021-11-29 17:39:35 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 17:39:35 [INFO]-performance on validation at epoch 31
# 2021-11-29 17:39:35 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.596999 |
# |  1 | precision@10 | 0.561348 |
# |  2 | recall@10    | 0.197918 |
# |  3 | map@10       | 0.148389 |
# +----+--------------+----------
# 2021-11-29 17:39:35 [INFO]-
# 2021-11-29 17:39:35 [INFO]---------------------------------------------------------------------------------
# ...
# |  3 | map@10       | 0.222544 |
# +----+--------------+----------
# 2021-11-29 20:06:48 [INFO]-
# 2021-11-29 20:06:48 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:06:48 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:06:48 [INFO]-performance on testing at epoch 71
# 2021-11-29 20:06:48 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.746785 |
# |  1 | precision@10 | 0.69926  |
# |  2 | recall@10    | 0.261821 |
# |  3 | map@10       | 0.221432 |
# +----+--------------+----------
# 2021-11-29 20:06:48 [INFO]-
# 2021-11-29 20:06:48 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:06:48 [INFO]-Execute [train_eval_worker] method costing 138287.53 ms
# 2021-11-29 20:08:14 [INFO]-[Training Epoch 72], log_like_loss 3.6051158506888896 kl_loss: 3.145201190141961 alpha: 0.001 lr: 0.001
# 2021-11-29 20:08:14 [INFO]-Execute [train_an_epoch] method costing 223693.09 ms
#  91%|#########1| 73/80 [4:23:14<27:24, 234.93s/it]Epoch 73 starts !
# 2021-11-29 20:08:27 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:10:47 [INFO]-Current testEngine.best_valid_performance 0.7472012552096128
# 2021-11-29 20:10:47 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:10:47 [INFO]-performance on validation at epoch 72
# 2021-11-29 20:10:47 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.748222 |
# |  1 | precision@10 | 0.700209 |
# |  2 | recall@10    | 0.263188 |
# |  3 | map@10       | 0.223125 |
# +----+--------------+----------
# 2021-11-29 20:10:47 [INFO]-
# 2021-11-29 20:10:47 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:10:47 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:10:47 [INFO]-performance on testing at epoch 72
# 2021-11-29 20:10:47 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.747846 |
# |  1 | precision@10 | 0.699603 |
# |  2 | recall@10    | 0.262012 |
# |  3 | map@10       | 0.221888 |
# +----+--------------+----------
# 2021-11-29 20:10:47 [INFO]-
# 2021-11-29 20:10:47 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:10:47 [INFO]-Execute [train_eval_worker] method costing 140211.96 ms
# 2021-11-29 20:12:12 [INFO]-[Training Epoch 73], log_like_loss 3.6038163332268596 kl_loss: 3.134265484288335 alpha: 0.001 lr: 0.001
# 2021-11-29 20:12:12 [INFO]-Execute [train_an_epoch] method costing 225345.35 ms
#  92%|#########2| 74/80 [4:27:13<23:36, 236.05s/it]Epoch 74 starts !
# 2021-11-29 20:12:26 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:14:45 [INFO]-Current testEngine.best_valid_performance 0.7482219907972179
# 2021-11-29 20:14:45 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:14:45 [INFO]-performance on validation at epoch 73
# 2021-11-29 20:14:45 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.748817 |
# |  1 | precision@10 | 0.700289 |
# |  2 | recall@10    | 0.263081 |
# |  3 | map@10       | 0.223397 |
# +----+--------------+----------
# 2021-11-29 20:14:45 [INFO]-
# 2021-11-29 20:14:45 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:14:45 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:14:45 [INFO]-performance on testing at epoch 73
# 2021-11-29 20:14:45 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.749115 |
# |  1 | precision@10 | 0.70111  |
# |  2 | recall@10    | 0.262482 |
# |  3 | map@10       | 0.22275  |
# +----+--------------+----------
# 2021-11-29 20:14:45 [INFO]-
# 2021-11-29 20:14:45 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:14:45 [INFO]-Execute [train_eval_worker] method costing 139067.45 ms
# 2021-11-29 20:16:11 [INFO]-[Training Epoch 74], log_like_loss 3.604005330707878 kl_loss: 3.131433148868382 alpha: 0.001 lr: 0.001
# 2021-11-29 20:16:11 [INFO]-Execute [train_an_epoch] method costing 225066.27 ms
#  94%|#########3| 75/80 [4:31:11<19:43, 236.68s/it]Epoch 75 starts !
# 2021-11-29 20:16:24 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:18:30 [INFO]-Current testEngine.best_valid_performance 0.7488169378623669
# 2021-11-29 20:18:30 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:18:30 [INFO]-performance on validation at epoch 74
# 2021-11-29 20:18:30 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.750655 |
# |  1 | precision@10 | 0.701798 |
# |  2 | recall@10    | 0.263923 |
# |  3 | map@10       | 0.224321 |
# +----+--------------+----------
# 2021-11-29 20:18:30 [INFO]-
# 2021-11-29 20:18:30 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:18:30 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:18:30 [INFO]-performance on testing at epoch 74
# 2021-11-29 20:18:30 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.750312 |
# |  1 | precision@10 | 0.702327 |
# |  2 | recall@10    | 0.263283 |
# |  3 | map@10       | 0.223358 |
# +----+--------------+----------
# 2021-11-29 20:18:30 [INFO]-
# 2021-11-29 20:18:30 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:18:30 [INFO]-Execute [train_eval_worker] method costing 126407.78 ms
# 2021-11-29 20:19:52 [INFO]-[Training Epoch 75], log_like_loss 3.6036337479017675 kl_loss: 3.1130428176838905 alpha: 0.001 lr: 0.001
# 2021-11-29 20:19:52 [INFO]-Execute [train_an_epoch] method costing 208634.50 ms
#  95%|#########5| 76/80 [4:34:53<15:29, 232.27s/it]Epoch 76 starts !
# 2021-11-29 20:20:06 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:22:25 [INFO]-Current testEngine.best_valid_performance 0.7506549946626205
# 2021-11-29 20:22:25 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:22:25 [INFO]-performance on validation at epoch 75
# 2021-11-29 20:22:25 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.750962 |
# |  1 | precision@10 | 0.702501 |
# |  2 | recall@10    | 0.264297 |
# |  3 | map@10       | 0.224433 |
# +----+--------------+----------
# 2021-11-29 20:22:25 [INFO]-
# 2021-11-29 20:22:25 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:22:25 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:22:25 [INFO]-performance on testing at epoch 75
# 2021-11-29 20:22:25 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.751069 |
# |  1 | precision@10 | 0.702581 |
# |  2 | recall@10    | 0.263256 |
# |  3 | map@10       | 0.223976 |
# +----+--------------+----------
# 2021-11-29 20:22:25 [INFO]-
# 2021-11-29 20:22:25 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:22:25 [INFO]-Execute [train_eval_worker] method costing 139572.43 ms
# 2021-11-29 20:23:53 [INFO]-[Training Epoch 76], log_like_loss 3.60256158397533 kl_loss: 3.1138756202999502 alpha: 0.001 lr: 0.001
# 2021-11-29 20:23:53 [INFO]-Execute [train_an_epoch] method costing 227745.13 ms
#  96%|#########6| 77/80 [4:38:54<11:44, 234.87s/it]Epoch 77 starts !
# 2021-11-29 20:24:07 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:26:15 [INFO]-Current testEngine.best_valid_performance 0.7509617066142271
# 2021-11-29 20:26:15 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:26:15 [INFO]-performance on validation at epoch 76
# 2021-11-29 20:26:15 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.752346 |
# |  1 | precision@10 | 0.703889 |
# |  2 | recall@10    | 0.265078 |
# |  3 | map@10       | 0.225415 |
# +----+--------------+----------
# 2021-11-29 20:26:15 [INFO]-
# 2021-11-29 20:26:15 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:26:15 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:26:15 [INFO]-performance on testing at epoch 76
# 2021-11-29 20:26:15 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.7525   |
# |  1 | precision@10 | 0.704502 |
# |  2 | recall@10    | 0.264225 |
# |  3 | map@10       | 0.224416 |
# +----+--------------+----------
# 2021-11-29 20:26:15 [INFO]-
# 2021-11-29 20:26:15 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:26:15 [INFO]-Execute [train_eval_worker] method costing 127887.46 ms
# 2021-11-29 20:27:38 [INFO]-[Training Epoch 77], log_like_loss 3.6024122489616275 kl_loss: 3.1105560816358775 alpha: 0.001 lr: 0.001
# 2021-11-29 20:27:38 [INFO]-Execute [train_an_epoch] method costing 211683.13 ms
#  98%|#########7| 78/80 [4:42:40<07:44, 232.24s/it]Epoch 78 starts !
# 2021-11-29 20:27:53 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:29:58 [INFO]-Current testEngine.best_valid_performance 0.752345539407595
# 2021-11-29 20:29:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:29:58 [INFO]-performance on validation at epoch 77
# 2021-11-29 20:29:58 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.75318  |
# |  1 | precision@10 | 0.704445 |
# |  2 | recall@10    | 0.265215 |
# |  3 | map@10       | 0.22588  |
# +----+--------------+----------
# 2021-11-29 20:29:58 [INFO]-
# 2021-11-29 20:29:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:29:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:29:58 [INFO]-performance on testing at epoch 77
# 2021-11-29 20:29:58 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.753781 |
# |  1 | precision@10 | 0.705768 |
# |  2 | recall@10    | 0.264773 |
# |  3 | map@10       | 0.225271 |
# +----+--------------+----------
# 2021-11-29 20:29:58 [INFO]-
# 2021-11-29 20:29:58 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:29:58 [INFO]-Execute [train_eval_worker] method costing 125711.69 ms
# 2021-11-29 20:31:23 [INFO]-[Training Epoch 78], log_like_loss 3.602037862641737 kl_loss: 3.1076295662205666 alpha: 0.001 lr: 0.001
# 2021-11-29 20:31:23 [INFO]-Execute [train_an_epoch] method costing 210173.36 ms
#  99%|#########8| 79/80 [4:46:24<03:49, 229.68s/it]Epoch 79 starts !
# 2021-11-29 20:31:36 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:33:42 [INFO]-Current testEngine.best_valid_performance 0.7531802625205901
# 2021-11-29 20:33:42 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:33:42 [INFO]-performance on validation at epoch 78
# 2021-11-29 20:33:42 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.753968 |
# |  1 | precision@10 | 0.705611 |
# |  2 | recall@10    | 0.265792 |
# |  3 | map@10       | 0.226449 |
# +----+--------------+----------
# 2021-11-29 20:33:42 [INFO]-
# 2021-11-29 20:33:42 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:33:42 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:33:42 [INFO]-performance on testing at epoch 78
# 2021-11-29 20:33:42 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.755029 |
# |  1 | precision@10 | 0.706691 |
# |  2 | recall@10    | 0.265451 |
# |  3 | map@10       | 0.225995 |
# +----+--------------+----------
# 2021-11-29 20:33:42 [INFO]-
# 2021-11-29 20:33:42 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:33:42 [INFO]-Execute [train_eval_worker] method costing 125162.82 ms
# 2021-11-29 20:35:06 [INFO]-[Training Epoch 79], log_like_loss 3.6017527990043163 kl_loss: 3.11320967040956 alpha: 0.001 lr: 0.001
# 2021-11-29 20:35:06 [INFO]-Execute [train_an_epoch] method costing 209078.31 ms
# 100%|##########| 80/80 [4:50:07<00:00, 217.59s/it]
# 2021-11-29 20:35:19 [INFO]-Program running time:17533 seconds
# 2021-11-29 20:37:11 [INFO]-Current testEngine.best_valid_performance 0.7539675762372408
# 2021-11-29 20:37:11 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:37:11 [INFO]-performance on validation at epoch 79
# 2021-11-29 20:37:11 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.754461 |
# |  1 | precision@10 | 0.706122 |
# |  2 | recall@10    | 0.266036 |
# |  3 | map@10       | 0.226752 |
# +----+--------------+----------
# 2021-11-29 20:37:11 [INFO]-
# 2021-11-29 20:37:11 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:37:11 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:37:11 [INFO]-performance on testing at epoch 79
# 2021-11-29 20:37:11 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@10      | 0.754858 |
# |  1 | precision@10 | 0.706446 |
# |  2 | recall@10    | 0.265202 |
# |  3 | map@10       | 0.225919 |
# +----+--------------+----------
# 2021-11-29 20:37:11 [INFO]-
# 2021-11-29 20:37:11 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:37:11 [INFO]-Execute [train_eval_worker] method costing 111902.26 ms
# 2021-11-29 20:39:57 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:39:57 [INFO]-performance on test
# 2021-11-29 20:39:57 [INFO]-
# +----+--------------+----------+
# |    | metrics      |   values |
# |----+--------------+----------|
# |  0 | ndcg@5       | 0.806542 |
# |  1 | precision@5  | 0.782954 |
# |  2 | recall@5     | 0.156453 |
# |  3 | map@5        | 0.141793 |
# |  4 | ndcg@10      | 0.754858 |
# |  5 | precision@10 | 0.706446 |
# |  6 | recall@10    | 0.265202 |
# |  7 | map@10       | 0.225919 |
# |  8 | ndcg@20      | 0.705825 |
# |  9 | precision@20 | 0.603753 |
# | 10 | recall@20    | 0.419519 |
# | 11 | map@20       | 0.331085 |
# +----+--------------+----------
# 2021-11-29 20:39:57 [INFO]-
# 2021-11-29 20:39:57 [INFO]---------------------------------------------------------------------------------
# 2021-11-29 20:39:57 [INFO]-/home/zm324/workspace/results/vbcar_result.csv  already exists, appending result to it
# 2021-11-29 20:39:57 [INFO]-Execute [test_eval_worker] method costing 163847.35 ms
# 2021-11-29 20:39:57 [INFO]-Execute [test_eval] method costing 277978.75 ms
